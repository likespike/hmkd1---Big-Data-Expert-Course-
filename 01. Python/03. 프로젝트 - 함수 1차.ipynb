# %%
# 수정사항

# %%
import pickle

category_income = {1:'급여', 2:'부캐', 3:'투자', 4:'용돈', 5:'당근'}
category_spending = {1:'식비', 2:'식자재', 3:'취미', 4:'핸드폰비', 5:'넷플릭스'}

with open('category_income.txt', 'wb') as f:
    pickle.dump(category_income, f)


with open('category_spending.txt', 'wb') as f:
      pickle.dump(category_spending, f)

# %%
### # 개인비서 ❤👍👍 - 계산기 음식추천 카페추천 가계부 날씨 등

# 12/4 카테고리 감자 1000  (출력은 자동으로 format으로 , 바꾸어 주기)


# time() 사용
  # 가계부 사용자에게 도움이 되도록 시간을 나타내기 위해 사용

# 가계부 작성시 수입, 지출 등에서 문자 입력보다 숫자 입력이 편하기에 리스트가 아닌 딕셔너리로 구현해 보았음

# text 파일 사용
  # 프로그램 종료-재시작 후에도, 데이터와 새로 입력한 항목 등이 사라지지 않도록 txt 파일 사용

# pickle() 사용
   # txt 파일에는 문자열 밖에 저장되지 않는 것 같아 시퀀스나 맵핑, 복합 자료형을 그대로 저장하고 불러올 수 있도록 pickle()을 사용함 (binary - packing, unpacking 방법)

# try-except 예외처리 사용
  # input으로 문자 데이터를 받을시, int()관련 코드 에러를 넘기기 위해 사용
  # pickle.load()는 readline()처럼 한 줄씩 밖에 출력하지 않아, 전체 결과를 보려면 while()으로 돌려야하고, 끝 라인에서 아직 중단 방법을 찾지 못하여 'Ran out of input' 에러 발생함 -> 예외처리로 일단 넘김


# 수정 사항
# 1차 - try-except 예외처리 아예 없앰, 여러 예외처리 가능성 없애거나, 반복문 짧고 심플하게 하여 해결
# 2차 - 함수로 만들기
# 3차 - 클래스로 만들기



import time
import pickle




class Income_Speding:
    def __init__(self, category, category_text, in_sp_han):
        self.category = category
        self.category_text = category_text
        self.in_sp_han = in_sp_han
    
    
    def i_s(self):
        
        with open(self.category_text, 'rb') as f:
            self.category = pickle.load(f)   


        while 1:
            print(self.category)
            i1 = input('원하시는 항목 번호를 선택해 주세요(항목 추가: a / 이전 단계: p)> ') # 'a', 'p' 등의 문자열이 먹어야 하기 때문에 int() X

        #             elif i1.isdigit() == True and int(i1) == list(category_income.keys())[int(i1)-1]: # list로 하니까 range out 에러 발생
            if i1.isdigit() == True and int(i1) in self.category.keys():   #  'p'등 입력시, 앞의 조건으로 인해 int() 에러 생기기 전에 아래 조건으로 넘어감

                while 1:

                    amount1 = input('\n금액을 입력해 주세요 (이전 단계: p)> ')

                    if amount1.isdigit() == True:
                        data = [[t.tm_year, t.tm_mon, t.tm_mday], list(self.category.values())[int(i1)-1], int(amount1), self.in_sp_han]             # 금액 입력 부분에서 q p 등 처리해야 함

                        with open('financial_ledger.txt','ab') as f:
                            pickle.dump(data,f)

                        print("\n기록했습니다.\n")
                        break                

                    elif amount1 == 'p':
                        print("이전 단계로 돌아갑니다.")                            
                        break

                    else:
                        print("잘못 입력하셨습니다.")
                        continue


            elif i1 == 'a':

                while 1:
                    add1 = input('추가할 항목을 입력해 주세요(이전 단계: p)> ')

                    if add1.strip() != "" and add1 != 'p' and add1 not in self.category.values(): # ""과 strip()을 써서 enter나 스페이스 입력 등에 대해 대처함, 'p'는 제외시킴

                        for i in list(self.category.keys()): # dictionary 마지막에 추가하기 위해 for 반복문 이용
                            i += 1

                        self.category[i] = add1

                        with open(self.category_text,'wb') as f: # 추가한 항목을 프로그램 재실행 때도 그대로 불러올 있도록 txt 파일로 저장 / # wb로 덮어쓰기해서 프로그램 재시작시 추가 항목 유지(ab로 하면 첫 번째 줄만 계속 불러옴, 추가시마다 라인 누적)
                            pickle.dump(self.category, f)           # dic과 str은 + 연산자 쓸 수 없음

                        print(self.category)

                        while 1:

                            amount2 = input('금액을 입력해 주세요(이전 단계: p)> ')

                            if amount2.isdigit() == True:
                                data = [[t.tm_year, t.tm_mon, t.tm_mday], add1, int(amount2), self.in_sp_han]

                                with open('financial_ledger.txt','ab') as f: #txt 파일에 정보 저장함 (추후 검색 및 분석 가능하도록)
                                    pickle.dump(data, f)

                                print("\n기록했습니다.\n")
                                break                                

                            elif amount2 == 'p':
                                print("이전 단계로 돌아갑니다.")
                                break

                            else:
                                print("잘못 입력하셨습니다.")
                                continue


                    elif add1 in self.category.values():
                        print('항목이 있습니다.')


                    elif add1 == 'p':
                        print('\n이전 단계로 돌아갑니다.\n')
                        break


                    else:
                        print("잘못 입력하셨습니다.")


            elif i1 == 'p':
                print('\n이전 단계로 돌아갑니다.\n')      # 예외 처리 때문에 'p' 작동 위해 아래 elif보다 위에 위치해야 함
                break


            else:
                print('잘못 입력하셨습니다.')
                continue
                


t = time.localtime() # struct time sequence object를 사용하려면 변수 할당 뒤 변수.tm_year 이런식으로 사용해야 함 (아니면 time.localtime().tm_year)
week = ['월요일', '화요일','수요일','목요일','금요일','토요일','일요일']


print('안녕하세요. 박주경님, "부자되려면 가계부부터 써!!" 시작하겠습니다.\n')
print(f'오늘은 {t.tm_year}년 {t.tm_mon}월 {t.tm_mday}일 {week[t.tm_wday]} {t.tm_hour}시 {t.tm_min}분 {t.tm_sec}초입니다.\n')




while 1:
    print('1.수입', '2.지출', '3.검색 및 분석', '(종료: q)')
    i = input('원하시는 항목 번호를 선택하여 주세요> ')


    
# 수입 항목
    if i == '1':
        IS1 = Income_Speding('category_income', 'category_income.txt', '수입')
        IS1.i_s()
     
    
    
# 지출 항목
    if i == '2':
        IS2 = Income_Speding('category_spending', 'category_spending.txt', '지출')
        IS2.i_s()
        

     
    
# 날짜 - 세부내역과 총합   # 카테고리 - 카테고리별 세부내역과 총합   # 분석 max   # 월별 카테고리 비교 - 지출의 증감   # 카테고리별 금액                
# 검색 및 분석 항목

    elif i == '3':      

        while 1:
            print('1.수입 현황, 2.지출 현황, 3.내역별 검색, 4.날짜별 검색, (이전 단계: p)')
            
            i3 = input('원하시는 항목 번호를 선택해 주세요> ')


            if i3.isdigit() == True and int(i3) == 1:   # 앞의 조건으로 인해 'p' 문자열이 뒤의 int()에 걸리지 않아 에러 안남

                while 1:

                    i3_income = input('"전체"나 원하는 지출 내역을 입력해 주세요> ')

                    if i3_income.strip() == "":     # 공백, 스페이스 공백 거르기
                        continue

                    else:

                        break            

                with open('financial_ledger.txt','rb') as f:

                    try:

                        while 1:

                            data = pickle.load(f)

                            if i3_income == '전체' and data[3] == '수입':
                                print(data)

                            elif i3_income in data[1] and data[3] == '수입':
                                print(data)

                            else:
                                continue

                    except:
                        print("\n(출력 완료)\n")
                        continue # break를 쓰면


            if i3.isdigit() == True and int(i3) == 2:

                while 1:

                    i3_spending = input('"전체"나 원하는 지출 내역을 입력해 주세요> ')

                    if i3_spending.strip() == "" :      # 공백, 스페이스 공백 거르기
                        continue

                    else:

                        break            

                with open('financial_ledger.txt','rb') as f:

                    try:

                        while 1:

                            data = pickle.load(f)

                            if i3_spending == '전체' and data[3] == '지출':
                                print(data)

                            elif i3_spending in data[1] and data[3] == '지출':

                                print(data)

                            else:

                                continue

                    except:
                        print("\n(출력 완료)\n")
                        continue


            if i3.isdigit() == True and int(i3) == 3:
                while 1:
                    i3_detail = input('검색할 내역을 입력해 주세요> ')

                    if i3_detail.strip() == "" :      # 공백, 스페이스 공백 거르기
                        continue

                    else:

                        break

                with open('financial_ledger.txt','rb') as f:

                    try:

                        while 1:

                            data = pickle.load(f)

                            if i3_detail in data[1]:
                                  print(data)

                    except:
                        print("\n(출력 완료)\n")
                        continue


            if i3.isdigit() == True and int(i3) == 4:
                while 1:
                    print('1.년도별 검색, 2.월별 검색, 3.일별 검색, (이전 단계: p)')

                    i3_date = input('원하시는 항목 번호를 선택해 주세요> ')

                    if i3_date.isdigit() == True and int(i3_date) in (1,2,3):


                        if int(i3_date) == 1:

                            while 1:

                                i3_year = input('년도 네 자리를 입력해 주세요> ')
                                
                                if i3_year.isdigit() == True and int(len(i3_year)) == 4:
                                    
                                    with open('financial_ledger.txt','rb') as f:

                                        try:

                                            while 1:

                                                data = pickle.load(f)

                                                if int(i3_year) == data[0][0]:
                                                    print(data)
                                                    
                                                else:
                                                    continue
                                                    

                                        except:                                            
                                            print("\n(출력 완료)\n")
                                            break
                                            
                                            

                                else:
                                    print("\n잘못 입력하셨습니다.\n")


                        if int(i3_date) == 2:
                            
                            while 1:
                                
                                i3_mon = input('달을 입력해 주세요> ')
                                
                                if i3_mon.isdigit() == True and 0 <int(i3_mon) <13:

                                    with open('financial_ledger.txt','rb') as f:
                                        
                                        try:
                                            
                                            while 1:
                                                
                                                data = pickle.load(f)

                                                if int(i3_mon) == data[0][1]:
                                                    print(data)

                                                else:
                                                    continue
                                        
                                        except:
                                            print("\n(출력 완료)\n")
                                            break
                                            
                                
                                else:
                                    print("\n잘못 입력하셨습니다.\n")

                        if int(i3_date) == 3:
                            
                            while 1:
                                
                                i3_day = input("해당 날짜를 '3/19'와 같이 입력해 주세요> ")
                                i3_day = i3_day.lstrip('0')
                                i3_day = i3_day.split('/')   # 0을 없애고 / 기준으로 리스트 만들기                                
                                                                                            
                                with open('financial_ledger.txt','rb') as f:
                                    
                                    try:
                                        
                                        while 1:
                                            
                                            data = pickle.load(f)

                                            if int(i3_day[0]) == data[0][1] and int(i3_day[1]) == data[0][2]:
                                                print(data)

                                            else:
                                                continue
                                                
                                    except:
                                        print("\n(출력 완료)\n")
                                        break
                                        
                                        
                    elif i3_date == 'p':
                            print('\n이전 단계로 돌아갑니다.\n')
                            break
                            
                    else:
                        print("\n잘못 입력하셨습니다.\n")
                        continue

            elif i3 == 'p':
                print('\n이전 단계로 돌아갑니다.\n')
                break                            


            else:
                print('\n잘못 입력하셨습니다.')



                
    elif i == 'q':
        print("종료합니다.")
        break
        
        
    else:
        continue
# Out:
# 안녕하세요. 박주경님, "부자되려면 가계부부터 써!!" 시작하겠습니다.
#
# 오늘은 2023년 3월 22일 수요일 20시 39분 1초입니다.
#
# 1.수입 2.지출 3.검색 및 분석 (종료: q)
# 원하시는 항목 번호를 선택하여 주세요> 1
# {1: '급여', 2: '부캐', 3: '투자', 4: '용돈', 5: '당근', 6: '주은돈'}
# 원하시는 항목 번호를 선택해 주세요(항목 추가: a / 이전 단계: p)> 2
#
# 금액을 입력해 주세요 (이전 단계: p)> 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10316\1347673832.py in <module>
#     161     if i == '1':
#     162         IS1 = Income_Speding('category_income', 'category_income.txt', '수입')
# --> 163         IS1.i_s()
#     164
#     165
#
# ~\AppData\Local\Temp\ipykernel_10316\1347673832.py in i_s(self)
#      76             if i1.isdigit() == True and int(i1) in self.category.keys():   #  'p'등 입력시, 앞의 조건으로 인해 int() 에러 생기기 전에 아래 조건으로 넘어감
#      77
# ---> 78                 IS1.ori_amount()
#      79
#      80
#
# ~\AppData\Local\Temp\ipykernel_10316\1347673832.py in ori_amount(self)
#      46
#      47             if amount1.isdigit() == True:
# ---> 48                 data = [[t.tm_year, t.tm_mon, t.tm_mday], list(self.category.values())[int(i1)-1], int(amount1), self.in_sp_han]             # 금액 입력 부분에서 q p 등 처리해야 함
#      49
#      50                 with open('financial_ledger.txt','ab') as f:
#
# NameError: name 'i1' is not defined

# %%
i3_day = input("해당 날짜를 '3/19'와 같이 입력해 주세요> ")
i3_day = i3_day.lstrip('0')
i3_day = i3_day.split('/')   # 0을 없애고 / 기준으로 리스트 만들기
i3_day = [i3_day[0], i3_day[1].lstrip("0")]
print(i3_day)
# Out:
# 해당 날짜를 '3/19'와 같이 입력해 주세요> rkrk
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_456\1636702401.py in <module>
#       2 i3_day = i3_day.lstrip('0')
#       3 i3_day = i3_day.split('/')   # 0을 없애고 / 기준으로 리스트 만들기
# ----> 4 i3_day = [i3_day[0], i3_day[1].lstrip("0")]
#       5 print(i3_day)
#
# IndexError: list index out of range

# %%
import pickle

with open('category_income.txt', 'rb') as f:
    category = pickle.load(f)
    print(category)
# Out:
# {1: '급여', 2: '부캐', 3: '투자', 4: '용돈', 5: '당근'}

# %%
import pickle

i3_year='2022'

with open('financial_ledger.txt','rb') as f:
    try:
        while 1:
            data = pickle.load(f)
            
            if int(i3_year) == data[0][0]:
                print(data)
    
    except:
        pass

# %%
서비스 개요 - 목적, 용도, 고객
주요 - POP, POD (제품군의 공통적인 좋은 점 / 타사 제품 비교시 더 우월한 점) - prin points 집어주고 - 어떻게 해결
데모
구현 기술

# %%
종속 변수 Y = 답이라 함
독립 변수 X

y = ax + b

x값을 주었더니 y값이 되었더나 - 데이터 계속 줌
학습 - 알고리즘

파라미터

AI > 머신러닝 > 딥러닝

AI
아래 두 개가 아닌 것이 rule based programming
머신러닝 - 기계학습
딥러닝 - 인공 신경망


답까지 변수 다 주는 것 - 지도 학습
변수만 주는 것(답을 모를 때) - 비지도 학습
알파고 - 강화 학습

변수의 개수, 가중치
이것을 구해서 답을 구해주는 것 -> 모델 예측, 모델링
검증해야 함 - 모델 평가
검증할 때는 다른 데이터 써야 한다(모델링한 데이터 말고)

그래서 데이터를 나눠서
훈션 세트
테스트 세트

전처리에서 하는 것
0-1사이
표준화(standard scaler)
