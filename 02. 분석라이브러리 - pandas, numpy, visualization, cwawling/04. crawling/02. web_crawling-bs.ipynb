# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# Beautiful Soup Documentation
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# #### <class 'bs4.element.ResultSet'>
# - find_all로 검색하면 태그가 한 개여도 무조건 ResultSet임
#
# #### <class 'bs4.element.Tag'>
# - find로 검색하면 태그가 한 개이기에 무조건 Tag임
# - soup.body 이런 식도 첫 번쨰 데이터만 조회하기에 무조건 Tag임

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<div></div>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
with open('wtest1.html', 'w') as f:
    f.write(html_doc)

# %%
soup = BeautifulSoup(html_doc)
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <div>
#   </div>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
soup.title
# Out:
# bs4.element.Tag

# %%
soup.title.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6868\296722761.py in <module>
# ----> 1 soup.title.name
#       2 type(soup.title)
#
# AttributeError: 'NoneType' object has no attribute 'name'

# %%
soup.title.parent
# Out:
# <head><title>The Dormouse's story</title></head>

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
# p태그 첫 번째 데이터

soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
# a태그 첫 번째 데이터

soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find('a')
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.a['class']
# Out:
# ['sister']

# %%
soup.a['href']
# Out:
# 'http://example.com/elsie'

# %%
soup.a['id']
# Out:
# 'link1'

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find_all(class_='sister')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find_all(id='link3')
# Out:
# [<a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.p['class']
# Out:
# ['title']

# %%
soup.find('p')
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.find(class_='story')
# Out:
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>

# %%
print(type(soup.find_all('p')))
soup.find_all('p')
soup.find_all('p')
# Out:
# <class 'bs4.element.ResultSet'>
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
for link in soup.find_all('a'):
    print(link.get('href'))

print()

# 제너레이터 표현식 - list()함수나 for문으로 봐야 함
print(type(link.get('href') for link in soup.find_all('a')))

print((link.get('href') for link in soup.find_all('a')))          # 제너레이터 표현식은 ()로 감싸주는 것이 정석임
print(link.get('href') for link in soup.find_all('a'))            # 원래 괄호로 둘러 쌓여야 하는데, print() 안에 있어서 유효
print((link.get('href') for link in soup.find_all('a')), '\n')    # 개행을 넣으니까, 원래대로 ()로 감싸줘야 함
print((link.get('href') for link in soup.find_all('a')), '\n')    # 이렇게 정석대로 ()로 감싸주는게 좋음

print(list(link.get('href') for link in soup.find_all('a')), '\n')    # list() 안에 단독으로 있어서 괄호로 안감싸줘도 됨

# 리스트 컴프리헨션 (list comprehenshion)
print(type([list(link.get('href') for link in soup.find_all('a'))]))
print([link.get('href') for link in soup.find_all('a')])
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie
#
# <class 'generator'>
# <generator object <genexpr> at 0x00000256321B2F20>
# <generator object <genexpr> at 0x00000256321B2F20>
# <generator object <genexpr> at 0x00000256321B2F20>
#
# <generator object <genexpr> at 0x00000256321B2F20>
#
# ['http://example.com/elsie', 'http://example.com/lacie', 'http://example.com/tillie']
#
# <class 'list'>
# ['http://example.com/elsie', 'http://example.com/lacie', 'http://example.com/tillie']

# %%
soup.find_all()
# Out:
# [<html><head><title>The Dormouse's story</title></head>
#  <body>
#  <div></div>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p>
#  </body></html>,
#  <head><title>The Dormouse's story</title></head>,
#  <title>The Dormouse's story</title>,
#  <body>
#  <div></div>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# ...

# %% [markdown]
# #### string vs. get_text() vs. text
# - BeautifulSoup 객체에서 text 속성, get_text() 메서드, string 속성은 모두 HTML 또는 XML 문서에서 텍스트 데이터를 추출하는 데 사용
# - text 속성은 해당 태그에서 모든 텍스트 데이터를 가져오며,
# - get_text() 메서드도 동일한 결과를 반환합니다.
# - string 속성은 해당 태그에서 첫 번째로 발견된 문자열 데이터만 가져옵니다.

# %%
html = '''
<html>
<body>
<div>
Hello,world!
</div>
<div>
<p>
Hello,<b>world!</b>
</p>
</div>        
</body>
</html>
'''

# %%
soup = BeautifulSoup(html)
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <div>
#    Hello,world!
#   </div>
#   <div>
#    <p>
#     Hello,
#     <b>
#      world!
#     </b>
#    </p>
#   </div>
#  </body>
# </html>

# %%
print(soup.div.text)
# Out:
# Hello,world!

# %%
print(soup.div.get_text())
# Out:
# Hello,world!

# %%
print(soup.div.string)
# Out:
# Hello,world!

# %%
# text 속성

print(soup.p.text)
soup.p.text
# Out:
# Hello,world!
# '\nHello,world!\n'

# %%
print(soup.p.get_text())

soup.p.get_text()
# Out:
# Hello,world!
# '\nHello,world!\n'

# %%
soup.p.get_text(strip=True)
# Out:
# 'Hello,world!'

# %%
print(soup.p.string)    # Tag에 감싸져 있지 않음
print(soup.p.b.string)
# Out:
# None
# world!

# %%
soup.b.string
# Out:
# 'world!'

# %%
# body에 있는 모든 text

import re

print(type(soup))
print(type(soup.body))
print(type(soup.body.text))

bs = soup.body.text
print(bs)
bs
# Out:
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.element.Tag'>
# <class 'str'>
#
#
# Hello,world!
#
#
#
# Hello,world!
# '\n\nHello,world!\n\n\n\nHello,world!\n\n\n'

# %%
# Q. 정규표현식을 사용하여 아래와 같이 출력하세요.
# Hello,world!
# Hello,world!

# %%
bs1 = re.finditer('.+', bs)
print(bs1)
print(type(bs1))

for i in bs1:
    print(i.group())
# Out:
# ...
# <class 'callable_iterator'>
# Hello,world!
# Hello,world!

# %%
texts = re.findall('[^\s]+', bs)
print(type(texts), '\n')

for t in texts:
    print(t)
# Out:
# <class 'list'>
#
# Hello,world!
# Hello,world!

# %%
# 아래와 같이 출력하세요.

# Hello,world! Hello,world!

# %%
print(' '.join(re.findall('.+', bs)))
# Out:
# Hello,world! Hello,world!

# %%
# for문 돌리는 것들은 다 맨 마지막에 공백이 있긴 함 - 주의할 것!

bs1 = re.finditer('.+', bs)

for i in bs1:
    print(i.group(),end=' ')
# Out:
# Hello,world! Hello,world!

# %%
li = ''

for t in texts:
    li += t
    li += ' '
    
print(li)
li.rstrip()    # 오른쪽 공백 제거
# Out:
# Hello,world! Hello,world!
# 'Hello,world! Hello,world!'

# %%
for t in texts:
    re.sub('\n', '', t)
    print(t, end=' ')    # 함수에서 출력값 끝에 들어가는 기본 값인 개행문자('\n') 대신 빈 문자열('')을 출력하도록 설정
# Out:
# Hello,world! Hello,world!

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<div></div>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

soup = BeautifulSoup(html_doc)
print(type(soup), '\n')
print(soup.prettify())
# Out:
# <class 'bs4.BeautifulSoup'>
#
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <div>
#   </div>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
print(type(soup), '\n')
print(soup, '\n')

bs = str(soup)
print(type(bs), '\n')
print(bs)
# Out:
# <class 'bs4.BeautifulSoup'>
#
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <div></div>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>
#
# <class 'str'>
#
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <div></div>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# ...

# %%
# 영어 텍스트만 출력

print(' '.join(re.findall('[A-Za-z]+', str(soup))))
# Out:
# html head title The Dormouse s story title head body div div p class title b The Dormouse s story b p p class story Once upon a time there were three little sisters and their names were a class sister href http example com elsie id link Elsie a a class sister href http example com lacie id link Lacie a and a class sister href http example com tillie id link Tillie a and they lived at the bottom of a well p p class story p body html

# %%
p = re.findall('[a-zA-Z]+', bs)
m = ' '.join(p)
m
# Out:
# 'html head title The Dormouse s story title head body div div p class title b The Dormouse s story b p p class story Once upon a time there were three little sisters and their names were a class sister href http example com elsie id link Elsie a a class sister href http example com lacie id link Lacie a and a class sister href http example com tillie id link Tillie a and they lived at the bottom of a well p p class story p body html'

# %%
print(soup.get_text(strip=True),'\n')
print('<------------------------------------------------------------------------------->')
print(soup.text)
# Out:
# The Dormouse's storyThe Dormouse's storyOnce upon a time there were three little sisters; and their names wereElsie,LacieandTillie;
# and they lived at the bottom of a well....
#
# <------------------------------------------------------------------------------->
# The Dormouse's story
#
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
texts = soup.find_all('body')
print(type(texts))

li = ''
for t in texts:
    li += t.text

print(li)
# Out:
# <class 'bs4.element.ResultSet'>
#
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
print(soup.find('body').text)    # 사실 body가 한 개이기에 find로 하면 위처럼 루프를 돌리지 않아도 동일한 결과를 얻을 수 있음
# Out:
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...
# str

# %%
li
# Out:
# "\n\nThe Dormouse's story\nOnce upon a time there were three little sisters; and their names were\nElsie,\nLacie and\nTillie;\nand they lived at the bottom of a well.\n...\n"

# %%
# 개행을 정규표현식으로 제거
print(' '.join(re.findall('.+', li)))
# Out:
# The Dormouse's story Once upon a time there were three little sisters; and their names were Elsie, Lacie and Tillie; and they lived at the bottom of a well. ...

# %%
print(re.sub('\n',' ',li).strip())
# Out:
# The Dormouse's story Once upon a time there were three little sisters; and their names were Elsie, Lacie and Tillie; and they lived at the bottom of a well. ...

# %%
texts = re.findall('[^\s]+', li)
li=''
for text in texts:
    li += text
    li += ' '
    
print(li.rstrip())
# Out:
# The Dormouse's story Once upon a time there were three little sisters; and their names were Elsie, Lacie and Tillie; and they lived at the bottom of a well. ...

# %%
texts = re.findall('[^\s]+', soup.text)    # Dormouse 반본 여부 보기(github)
li=''
for text in texts:
    li += text
    li += ' '
    
print(li)
# Out:
# The Dormouse's story The Dormouse's story Once upon a time there were three little sisters; and their names were Elsie, Lacie and Tillie; and they lived at the bottom of a well. ...

# %%
print(re.findall('.+',li))
# Out:
# ["The Dormouse's story", 'Once upon a time there were three little sisters; and their names were', 'Elsie,', 'Lacie and', 'Tillie;', 'and they lived at the bottom of a well.', '...']

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
print(soup.title.string)
# Out:
# The Dormouse's story

# %% [markdown]
# bs
#
# https://hi-guten-tag.tistory.com/8

# %% [markdown]
# #### html.parser vs. lxml
# - 파이썬에서 HTML 및 XML 문서를 파싱(parsing)하는 라이브러리
# - html.parser는 HTML 문서를 파싱하는 데에 적합한 파서. 파이썬의 기본 라이브러리로 제공되며 파이썬 내부적으로 구현되어 있으며, 외부 종속성이 없으므로 파이썬과 함께 설치되는 패키지만 사용할 수 있습니다.
# - lxml은 C 언어로 작성된 파이썬 외부 라이브러리로서 HTML 및 XML 문서를 파싱하는 데에 적합하며, 파서 성능이 매우 우수합니다.
# - HTML 문서를 파싱하는 경우에는 html.parser를 사용하는 것이 간단하고 편리하며, 대부분의 경우에는 충분한 성능을 제공합니다. 그러나 대용량의 XML 문서나 매우 복잡한 HTML 문서를 파싱해야 하는 경우에는 lxml을 사용하는 것이 더 효율적입니다.

# %% [markdown]
# urllib + bs

# %%
# lxml은 파이썬에서 XML과 HTML 문서를 파싱하고 조작하기 위한 빠르고 유연한 라이브러리

# !pip install lxml

# %%
import urllib.request as rq

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'

html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
# print(bs)

# %%
text1 = bs.find('p')
print(text1,'\n')

text2=bs.find('p').string
print(text2,'\n')

text3 = bs.find('p').get_text()
print(text3)
# Out:
# <p class="airs_info_inner"><i class="airs_info_icon_airs">AiRS</i><span class="airs_info_text"><b>추천</b>으로 구성된 뉴스를 제공합니다.</span></p>
#
# None
#
# AiRS추천으로 구성된 뉴스를 제공합니다.

# %%
texts = bs.find_all('p')

for t in texts:
    print(t.text)
# Out:
# AiRS추천으로 구성된 뉴스를 제공합니다.
# 오전 11시~오후 12시까지 집계한 결과입니다.
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.

# %%
texts = bs.find_all('p')
text_list = list(map(lambda x: x.text, texts))
print(text_list)
# Out:
# ['AiRS추천으로 구성된 뉴스를 제공합니다.', '오후 4시~오후 5시까지 집계한 결과입니다.', '본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.']

# %% [markdown]
# bs4에서 headers는
#
# headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
# - HTTP 요청을 보낼 때 요청 헤더를 설정하는 데 사용됩니다.
# - 일반적으로 웹 사이트에서 데이터를 스크래핑하려면, 해당 웹 사이트에서 HTTP 요청을 받을 때 자신이 웹 브라우저인 것처럼 보이도록 요청 헤더를 설정해야 합니다.
# - 이를 통해 웹 사이트는 봇이나 크롤러와 같은 자동화된 스크래핑 도구에서 요청을 보내는 것으로 인식하는 것을 방지할 수 있습니다.

# %% [markdown]
# #### 인코딩 에러를 해결
# chardet.detect(response.content)['encoding']은 response.content의 인코딩 방식을 자동으로 감지하여 반환하며 이 값을 encoding 변수에 저장한 후, response.content를 이 encoding 방식으로 디코딩하여 html 변수에 저장하고 출력

# %%
import chardet    # charset(character set) detection
import requests

# HTTP 요청에서 사용될 헤더 정보를 설정합니다. -> 헤더 정보는 어떻게 설정하나? 임의로?
# headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
headers = {'User-Agent': 'Mozilla/5.0'}

# 웹사이트에서 스크래핑할 URL을 지정합니다.
url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'

# 지정된 url에 HTTP GET 요청을 전달
response = requests.get(url, headers=headers)

# HTTP 요청이 성공적으로 전달되었다면, 웹사이트의 HTML 코드를 출력합니다.

print (chardet.detect(response.content), '\n')

if response.status_code == 200:
    encoding = chardet.detect(response.content)['encoding']
    print(response.content.decode(encoding))    # 웹사이트의 HTML 코드를 포함하는 이진(binary) 데이터를 반환
    # print(response.text)    # 웹사이트의 HTML 코드를 문자열 형태로 변환
else:
    print('HTTP request failed.')

# %%
# Q. response 값에서 한글만 출력하세요.

' '.join(re.findall('[가-힣]+', response.text))
# Out:
# '정치 네이버 뉴스 국회 행정 국방 외교 등 정치 분야 뉴스 제공 네이버 정치 네이버 뉴스 네이버 뉴스 네이버 뉴스 국회 행정 국방 외교 등 정치 분야 뉴스 제공 정치 홈 네이버 뉴스 광고적용 태그 추가 메인 메뉴로 바로가기 본문으로 바로가기 검색 뉴스 연예 스포츠 날씨 프리미엄 언론사별 정치 선택됨 경제 사회 생활 문화 과학 세계 랭킹 신문보기 오피니언 팩트체크 전체 언론사 전체 언론사 뉴스스탠드 뉴스스탠드 라이브러리 라이브러리 월 전체 언론사 전체 언론사 뉴스스탠드 뉴스스탠드 라이브러리 라이브러리 기사목록 정치 대통령실 국회 정당 북한 행정 국방 외교 정치일반 언론사 구독하기 네이버 프리미엄콘텐츠 안내 헤드라인 뉴스 헤드라인 뉴스와 각 기사묶음 타이틀은 기사 내용을 기반으로 자동 추출 됩니다 닫기 윤 대통령 지지율 올라 주 만에 반등 리얼미터 윤석열 대통령의 지지율이 주만에 반등했다는 여론조사 결과가 일 나왔다 지난주 박 일간 미국 국빈 방문이 지지율에 긍정적인 영향을 미친 것으로 분석 경향신문 서울경제 방미 효과 국정수행 긍정평가 주만에 최대 상승폭 이데일리 대통령 국정운영 긍정평가 전주 리얼미터 중앙일보 지지율 오른 방미 효과 주만에 반등 리얼미터 개의 관련뉴스 더보기 김기현 워싱턴 선언 두고 한국형 확장억제 구체화 때와 차원 달라 김기현 국민의힘 대표는 일 윤석열 대통령의 방미를 두고 워싱턴 선언 윤 대통령의 상하원 합동연설 등을 통해 북핵위협에 대한 대응 자유민주 가치 동 헤럴드경제 연합뉴스 김기현 방미 한미 양국관계 새 이정표 수립 최대 성과 거둬 김기현 국빈 방미 한미 새 이정표 수립 최대 성과 뉴스 방미 북핵대응 가치동맹 최대 성과 양국 새 이정표 수립 개의 관련뉴스 더보기 전략핵잠수함 한반도 전개 적법 판단에 황당무계한 궤변 북한 선전매체 조선중앙통신은 월 일 미 전략핵잠수함의 조선반도 전개가 조선반도의 비핵화에 관한 공동선언 에 위반되지 않으며 법적으로 아무런 문제도 파이낸셜뉴스 전략핵잠 전개 적법 판단에 황당무계한 궤변 북 미국 한반도
# ...

# %%
# url = 'https://news.naver.com'는 headers 안써도 됨

# %%
import requests as rq

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'

r = rq.get(url, headers=headers)
html=r.text
bs = BeautifulSoup(html, 'lxml')
print(bs.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=1106" name="viewport"/>
# <meta content="정치 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="정치 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# ...

# %%
bs.find('div')
# Out:
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# ...

# %%
bs.find('div', id='header')
# Out:
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# ...

# %%
bs.find('div', id=True)
# Out:
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# ...

# %%
bs.find('a').text

bs.find_all('a')[0].text

bs.select_one('a').text
# Out:
# '메인 메뉴로 바로가기'

# %%
bs.find('div', id=True).find('a').text
# Out:
# '메인 메뉴로 바로가기'

# %%
bs.div.find('a', href=True).get_text()
# Out:
# '메인 메뉴로 바로가기'

# %%
bs.select_one("[tabindex = '1']").text
# Out:
# '메인 메뉴로 바로가기'

# %%
lists = bs.find('div', id=True).find_all('a')
for i in lists:
    print(i.text)
# Out:
# 메인 메뉴로 바로가기
# 본문으로 바로가기
# 검색
# NAVER
# 뉴스
# TV연예
# 스포츠
# 날씨
# 프리미엄
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 정치
# 대통령실
# 국회/정당
# 북한
# 행정
# 국방/외교
# 정치일반
#
#
# 안내헤드라인 뉴스
#
#
#
# 북한 "워싱턴 선언 부정적 후과"…중·러 반발 집중 조명
# 북 매체, 중러 '워싱턴선언' 비판 조명…"부정적 후과 우려해"
# 북한, 워싱턴선언에 "진영대결 부추기고 조선반도 긴장 악화"
# “국제사회는 강한 우려”…北, 중러 ‘워싱턴선언’ 비판 조명
# 8개의 관련뉴스 더보기
#
#
#
# 김기현 "尹방미, 북핵대응·경제협력 등 최대 성과"
# 김기현 “윤 대통령 국빈 방문, 최고의 성과…한미관계 새 이정표 수립”
# 김기현 "尹 국빈 방미, 한미 새 이정표 수립 최대 성과"
# 與 "尹 방미, 북핵대응·가치동맹 최대 성과…양국 새 이정표 수립"
# 17개의 관련뉴스 더보기
#
#
#
# 박광온 “정부는 중대재해법 존중을…민주, 학부모 주 4일제 현실화할 것”
# 박광온 “일하는 국민에 희망을…학부모 주4일제 적극 검토”
# 박광온 "사람 중심으로 국정운영 대전환"‥민주 "주 4.5일제 문 열겠다"
# 野 박광온 “주 4.5일제 향해 담대하게 나아갈 것”
# 22개의 관련뉴스 더보기
#
#
#
# 윤재옥, 한미 핵협의그룹에 "자체 핵무장 보다 더 큰 이익"
# 윤재옥 "워싱턴 선언, 우리 자체 핵무장보다 더 큰 이익될 것"
# 윤재옥 "워싱턴 선언, 자체 핵무장보다 더 큰 이익"
# 與 “워싱턴 선언, 업그레이드한 제2의 한미상호방위조약”
# 4개의 관련뉴스 더보기
# 與 윤리위 첫 회의...김재원 징계 논의 여부 주목
#
#
#
# ...

# %%
import urllib.request as rq

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'

html = rq.urlopen(url)    # 이건 왜 헤더없이 되나?
bs = BeautifulSoup(html, 'lxml')
texts = bs.find_all('p')
print(texts)
# Out:
# [<p class="airs_info_inner"><i class="airs_info_icon_airs">AiRS</i><span class="airs_info_text"><b>추천</b>으로 구성된 뉴스를 제공합니다.</span></p>, <p class="section_sub_txt">오후 5시~오후 6시까지 집계한 결과입니다.</p>, <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>]

# %%
for t in texts:
    t = t.get_text()
    print(t, '\n')
# Out:
# AiRS추천으로 구성된 뉴스를 제공합니다.
#
# 오후 5시~오후 6시까지 집계한 결과입니다.
#
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.

# %%
url = 'https://news.naver.com'
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <title id="browserTitleArea">
#    네이버 뉴스
#   </title>
#   <script>
#    function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
#   </script>
#   <script>
#    (function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
#   </script>
#   <script>
#    var g_ssc = 'news.v3_media' || null;
# ...

# %%
# Q. p 태그 데이터를 모두 불러와서 한글만 출력

' '.join(re.findall('[가-힣]+', str(bs.find_all('p'))))
# Out:
# '세 차례 기간 연장이 이뤄졌던 감사원의 감사가 주요 항목 모두 문제 없다는 결론으로 마무리됐다 는 국민감사를 통해 는 각종 억측과 왜곡으로부터 명예를 회복했다 고 밝혔다 앞서 감사원은 지난해 일 오전 대구축산물도매시장과 붙어 있는 대구도축장 계류장 도축라인 시작인 이 계류장에는 이 넘는 어미돼지 모돈 와 먹이 경쟁에 밀려 고기 로서 상품 가치가 떨어지는 새끼돼지 위축돈 로 가득 차 있었다 윤석열 대통령은 일 수단 교민 구출과 관련 이번 작전의 성공은 우리 외교역량의 성과다 라며 우리 정부가 미국 아랍에미리트 사우디아라비아 등 우방국들과 상호 협력 하면서 신뢰를 쌓아왔기에 가능했다고 노동절인 오늘 배달 플랫폼 노동자들이 기본 배달료 인상 등을 요구하며 집회를 개최했습니다 민주노총 서비스연맹 배달플랫폼 노동조합은 서울 송파구 배달의민족 본사 앞에서 조합원 여 명이 모인 가운데 민주노총 노조탄압이 건설노동자 분신 불러 한국노총 윤 정권 반노동 정책에 맞서 투쟁 공노총 공무원의 노동절 휴일 보장하라 노동절인 일 양대 노총을 비롯한 노동자 단체들이 서울 도심에서 동시다발 집회를 열 세상을 바라보고 해석하는 시각이 남다른 세대 년대 중반 년대 초반 출생 세대 그들이 바라보는 세상은 어떤 모습일까요 머니 는 세대 기자들이 직접 발로 뛰며 그들의 시각으로 취재한 기사로 꾸미는 제주도에 있을 때 먹었던 흑돼지와 냉면이 최애 음식이라고 말할 수 있어요 두 번째는 아무래도 한국인의 소울 푸드인 김치찌개죠 무슨 일이 있어도 김치찌개만 먹으면 기분 전환이 되는 느낌이랄까 세 번째로는 순댓국 노동절인 오늘 청주에서도 정부의 노동정책을 규탄하는 대규모 집회가 열렸습니다 민주노총 충북본부 조합원 천 백여명은 오늘 오후 국립현대미술관 청주관 앞에서 집회를 열고 주 시간 노동제 와 주휴수당의 폐 파산 위기에 처한 퍼스트리퍼블릭 은행이 매각 절차에 돌입했다 퍼스트리퍼블릭은 미국 위 규모 은행으로 인수자가 확정되면 실리콘밸리은행 시그니처 은행에 이어 세 번째로 문을 정부의 통신 시 인하 압
# ...

# %%
# 더 자연스러움

texts = bs.find_all('p')
for t in texts:
    print(t.string)
# Out:
# 세 차례 기간 연장이 이뤄졌던 감사원의 KBS 감사가 주요 항목 모두 문제 없다는 결론으로 마무리됐다. KBS는 "국민감사를 통해 KBS는 각종 억측과 왜곡으로부터 명예를 회복했다"고 밝혔다. 앞서 감사원은 지난해
# 1일 오전 대구축산물도매시장과 붙어 있는 대구도축장 계류장. 도축라인 시작인 이 계류장에는 200㎏이 넘는 어미돼지(모돈)와 먹이 경쟁에 밀려 ‘고기’로서 상품 가치가 떨어지는 새끼돼지(위축돈)로 가득 차 있었다.
# JEONJU, North Jeolla Province -- For those who enjoy the cinematic experience without such stringent requirements as a d
# 윤석열 대통령은 1일 수단 교민 구출과 관련, "이번 작전의 성공은 우리 외교역량의 성과다"라며 "우리 정부가 미국, 아랍에미리트(UAE), 사우디아라비아 등 우방국들과 상호 협력 하면서 신뢰를 쌓아왔기에 가능했다고
# 노동절인 오늘 배달 플랫폼 노동자들이 기본 배달료 인상 등을 요구하며 집회를 개최했습니다. 민주노총 서비스연맹 배달플랫폼 노동조합은 서울 송파구 '배달의민족' 본사 앞에서 조합원 150여 명이 모인 가운데 '5.1
# 민주노총 "노조탄압이 건설노동자 분신 불러" 한국노총 "윤 정권 반노동 정책에 맞서 투쟁" 공노총 "공무원의 노동절 휴일 보장하라" 노동절인 1일 양대 노총을 비롯한 노동자 단체들이 서울 도심에서 동시다발 집회를 열
# 세상을 바라보고 해석하는 시각이 남다른 Z세대(1990년대 중반~2000년대 초반 출생 세대). 그들이 바라보는 세상은 어떤 모습일까요. 머니S는 Z세대 기자들이 직접 발로 뛰며 그들의 시각으로 취재한 기사로 꾸미는
# “제주도에 있을 때 먹었던 흑돼지와 냉면이 최애 음식이라고 말할 수 있어요. 두 번째는 아무래도 한국인의 소울 푸드인 김치찌개죠. 무슨 일이 있어도 김치찌개만 먹으면 기분 전환이 되는 느낌이랄까? 세 번째로는 순댓국
# ...

# %% [markdown]
# requests + bs

# %% [markdown]
# #### 과제1_0501.
# 'https://news.naver.com/'에서 title 내용을 세 가지 방법으로 출력하세요.

# %%
import requests

url = 'https://news.naver.com/'

requests.get(url)

bs = BeautifulSoup(requests.get(url).text)

print(bs.title.text)
print(bs(id='browserTitleArea')[0].text)
print(bs.find(id='browserTitleArea').text)
print(bs.find('title').text)
print(bs.select_one('title').text)
print(bs.select('title')[0].text)
# Out:
# 네이버 뉴스
# 네이버 뉴스
# 네이버 뉴스
# 네이버 뉴스
# 네이버 뉴스
# 네이버 뉴스

# %%
bs.find('title').get_text()
bs.find('title').text
bs.find('title').string
# Out:
# '네이버 뉴스'

# %%
# requests
from bs4 import BeautifulSoup
import requests
import re

url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=105"
res = requests.get(url).text
soup = BeautifulSoup(res)
wf = soup.find('wf').text
text = ''.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',wf))

print(wf)
text
# Out:
# <![CDATA[○ (강수) 5일(금)은 강원도에 비가 내리겠으며, 강원영동은 6일(토) 오전까지 이어지겠습니다.○ (기온) 5일(금)~7일(일) 아침 기온은 6~17도로 평년(최저기온 6~12도)과 비슷하거나 조금 높겠고, 낮 기온은 13~23도로 평년(최고기온 17~25도)보다 조금 낮겠습니다.          8일(월)~11일(목) 아침 기온은 3~14도로 평년(최저기온 6~12도)과 비슷하거나 조금 낮겠고, 낮 기온은 16~24도로 평년(최고기온 17~24도)과 비슷하겠습니다.○ (해상) 동해중부해상의 물결은 5일(금)~6일(토)은 1.0~3.0m로 높게 일겠습니다.○ (주말전망) 6일(토)~7일(일)은 대체로 흐리겠으나, 6일(토) 오전에 강원영동은 비가 내리겠습니다. 아침 기온은 6~17도, 낮 기온은 13~22도가 되겠습니다.* 6일(토)은 저기압의 위치와 이동 속도에 따라 강수 구역이 변경될 가능성이 있으니, 앞으로 발표되는 최신 예보를 참고하기 바랍니다.]]>
# '(강수) 5일(금)은 강원도에 비가 내리겠으며, 강원영동은 6일(토) 오전까지 이어지겠습니다.(기온) 5일(금)~7일(일) 아침 기온은 6~17도로 평년(최저기온 6~12도)과 비슷하거나 조금 높겠고, 낮 기온은 13~23도로 평년(최고기온 17~25도)보다 조금 낮겠습니다. 8일(월)~11일(목) 아침 기온은 3~14도로 평년(최저기온 6~12도)과 비슷하거나 조금 낮겠고, 낮 기온은 16~24도로 평년(최고기온 17~24도)과 비슷하겠습니다.(해상) 동해중부해상의 물결은 5일(금)~6일(토)은 1.0~3.0m로 높게 일겠습니다.(주말전망) 6일(토)~7일(일)은 대체로 흐리겠으나, 6일(토) 오전에 강원영동은 비가 내리겠습니다. 아침 기온은 6~17도, 낮 기온은 13~22도가 되겠습니다. 6일(토)은 저기압의 위치와 이동 속도에 따라 강수 구역이 변경될 가능성이 있으니, 앞으로 발표되는 최신 예보를 참고하기 바랍니다.'

# %%
''.join(re.findall('[^A-Z0-9]?[0-9가-힣]',wf))
# Out:
# '(강수 5일(금)은 강원도에 비가 내리겠으며 강원영동은 6일(토 오전까지 이어지겠습니다(기온 5일(금~7일(일 아침 기온은 6~17도로 평년(최저기온 6~12도)과 비슷하거나 조금 높겠고 낮 기온은 13~23도로 평년(최고기온 17~25도)보다 조금 낮겠습니다 8일(월~11일(목 아침 기온은 3~14도로 평년(최저기온 6~12도)과 비슷하거나 조금 낮겠고 낮 기온은 16~24도로 평년(최고기온 17~24도)과 비슷하겠습니다(해상 동해중부해상의 물결은 5일(금~6일(토)은 1.0~3.0m로 높게 일겠습니다(주말전망 6일(토~7일(일)은 대체로 흐리겠으나 6일(토 오전에 강원영동은 비가 내리겠습니다 아침 기온은 6~17도 낮 기온은 13~22도가 되겠습니다 6일(토)은 저기압의 위치와 이동 속도에 따라 강수 구역이 변경될 가능성이 있으니 앞으로 발표되는 최신 예보를 참고하기 바랍니다'

# %%
import urllib

API = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"

# 매개변수를 URL 인코딩합니다.
values = {'stnld':'105'}    # 서울은 109

params = urllib.parse.urlencode(values)

# 요청 전용 URL을 생성합니다.
url = API + '?' + params
print('url = ', url)

res = urllib.request.urlopen(url)
soup = BeautifulSoup(res, 'html.parser')    # 여기도 parser 생략하면 안됨, bytes와 상관이 있을까?
wf = soup.find('wf').string
text = ' '.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?', wf))
text
# Out:
# url =  http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnld=105
# '(강수)  4일( 목)  전남권과  경남권,  제주도에  비가  오겠습니다. (기온)  5일( 금) ~6일( 토)  아침  기온은  14~ 18도로  평년( 최저기온  9~ 14도) 보다  높겠고,  그  밖의  날의  아침  기온은  8~ 15도로  평년과  비슷하겠습니다.  7일( 일)  낮  기온은  18~ 22도로  평년( 최고기온  21~ 25도) 보다  낮겠고,  그  밖의  날의  낮  기온은  18~ 25도로  평년( 최고기온  20~ 25도) 과  비슷하겠습니다. (주말전망)  6일( 토) ~7일( 일)  전국이  대체로  흐리겠습니다.  아침  기온은  11~ 18도,  낮  기온은  18~ 23도가  되겠습니다.  4일( 목) 부터  7일( 일)  사이  기압골의  발달  정도와  이동  속도에  따라  강수시점과  구역이  변경될  가능성이  있으니,  앞으로  발표되는  최신  예보를  반드시  참고하기  바랍니다.'

# %% [markdown]
# 연습: urllib

# %% [markdown]
# #### 과제2_0501.
# "http://www.naver.com" 사이트에서 span 태그에 연결된 한글만을 불필요한 공백을 제거한 후 출력하세요.

# %%
import urllib
import re

url = "http://www.naver.com"

bs = BeautifulSoup(urllib.request.urlopen(url))
bs_span = bs.find_all('span')

for result in bs_span:
    print(' '.join(re.findall('[가-힣]+', result.text)), end=' ')
# Out:
# 뉴스스탠드 바로가기 주제별캐스트 바로가기 타임스퀘어 바로가기 쇼핑캐스트 바로가기 로그인 바로가기 매일 쓰는 브라우저 보안이 걱정된다면 안전하고 빠른 최신 브라우저 웨일로 업데이트 하세요 매일 쓰는 브라우저 보안이 걱정된다면 다운로드 네이버 쥬니어네이버 해피빈 검색  한글 입력기  자동완성 레이어     삭제 설정이 초기화 된다면 도움말을 확인해주세요 설정이 초기화 된다면 도움말을 확인해주세요 도움말 도움말 자동저장 끄기 자동저장 끄기  회 로또당첨번호 동행복권 제공 동행복권 제공        원 원            바로가기 바로가기   추가   추가    추가  자세히보기  도움말 신고 도움말 신고 자동완성 끄기 자동완성 끄기 쇼핑 쇼핑   도쿄     리스트형 썸네일형 설정 이전 다음 닫기 닫기 이전 다음                         닫기 닫기 이전 다음 다음 닫기 닫기 이전 다음 닫기 닫기 주제별로 분류된 다양한 글 모음 개의 글 이전 다음    재생 재생시간 재생시간 홍순국의 일요골프 홍순국의 일요골프   재생 재생시간 재생시간 네이버스포츠 네이버스포츠  시간 전 네이버스포츠 네이버스포츠  시간 전 네이버스포츠 네이버스포츠  시간 전 네이버스포츠 네이버스포츠   재생 재생시간 재생시간 시간 전 크보연구소 네이버스포츠 크보연구소 네이버스포츠  시간 전 네이버스포츠 네이버스포츠   재생 재생시간 재생시간 시간 전 김형준의 야구야구 김형준의 야구야구  시간 전 네이버스포츠 네이버스포츠   재생 재생시간 재생시간 시간 전 스태츠퍼폼 스태츠퍼폼  시간 전 네이버스포츠 네이버스포츠   재생 재생시간 재생시간 시간 전 서형욱의 뽈리 서형욱의 뽈리  시간 전 네이버스포츠 네이버스포츠   재생 재생시간 재생시간 일 전     재생 재생시간 재생시간 일 전 종합스포츠채널 종합스포츠채널   재생 재생시간 재생시간 일 전 내일은 위닝샷 내일은 위닝샷   재생 재생시간 재생시간 일 전 광주 광주  개월 전 네이버스포츠 네이버스포츠  개월 전 네이버스포츠 네
# ...

# %%
texts = bs.find_all('span')
lt = ''
for t in texts:
    t = t.get_text()
    lt += t 
lt = str(lt)
# print(lt)
lt = re.findall('[가-힣]+',lt)
lt = ' '.join(lt)
lt

# %% [markdown]
# #### 과제3_0501.
# "http://www.naver.com" 사이트에서 span 태그에 연결된 문자 + 숫자를 불필요한 공백을 제거한 후 출력하세요.

# %%
import urllib
import re

url = "http://www.naver.com"

bs = BeautifulSoup(urllib.request.urlopen(url))
bs_span = bs.find_all('span')

for result in bs_span:
    print(''.join(re.findall('[^\W]+', result.text)), end=' ')
# Out:
# 뉴스스탠드바로가기 주제별캐스트바로가기 타임스퀘어바로가기 쇼핑캐스트바로가기 로그인바로가기 매일쓰는브라우저보안이걱정된다면안전하고빠른최신브라우저웨일로업데이트하세요 매일쓰는브라우저보안이걱정된다면 다운로드 네이버 쥬니어네이버 해피빈 검색  한글입력기  자동완성레이어  txt  txt date삭제 설정이초기화된다면도움말을확인해주세요 설정이초기화된다면도움말을확인해주세요 도움말 도움말 자동저장끄기 자동저장끄기  5회로또당첨번호 동행복권제공 동행복권제공 6789101112 6789101112 14 txtcurrency currency 89 89 6원 6원  txt 7message 7message 78 78 7  txt 5 5 바로가기 바로가기 txt  추가 txt  date추가 queryintend  intend 추가  자세히보기  도움말신고 도움말 신고 자동완성끄기 자동완성끄기 쇼핑 쇼핑LIVE 100 250 영등포동3가 영등포동3가     리스트형 썸네일형 설정 이전 다음 닫기 닫기 이전 다음                         닫기 닫기 이전 다음 다음 닫기 닫기 이전 다음 닫기 닫기 주제별로분류된다양한글모음 651개의글 이전 다음   3일전 인플루언서미나  인플루언서미나  5일전 인플루언서이과장  인플루언서이과장  3일전 인플루언서예뚱이  인플루언서예뚱이  5일전 인플루언서Tom편집장  인플루언서Tom편집장  1주일전 인플루언서생존홈트  인플루언서생존홈트  1주일전 썸랩  썸랩  6일전 인플루언서양천구권우성  인플루언서양천구권우성  3주일전 인플루언서발악  인플루언서발악   재생 재생시간0134 재생시간 19시간전 동상이몽2_너는내운명  동상이몽2_너는내운명  방송연예 2일전 인플루언서권우성  인플루언서권우성  4일전 인플루언서숙주나물  인플루언서숙주나물  경제비즈니스 4일전 인플루언서쫑  인플루언서쫑  3일전 인플루언서잭  인플루언서잭  1주일전 인플루언서노바디  인플루언서노바디  1주일전 인플루언서이지  인플루언서이지  5일전 인플루언서빅사이즈웨딩드레스 
# ...

# %%
bs_span
# Out:
# [<span>뉴스스탠드 바로가기</span>,
#  <span>주제별캐스트 바로가기</span>,
#  <span>타임스퀘어 바로가기</span>,
#  <span>쇼핑캐스트 바로가기</span>,
#  <span>로그인 바로가기</span>,
#  <span class="_1syGnXOL _3VkgqBXB" data-clk="dropbanner1b" style="padding-right: 20px; font-size: 17px; color: black"><span>매일 쓰는 브라우저 보안이 걱정된다면, </span><strong>안전하고 빠른 최신 브라우저 웨일로 업데이트 하세요.</strong></span>,
#  <span>매일 쓰는 브라우저 보안이 걱정된다면, </span>,
#  <span style="background-color: #0436c7">다운로드</span>,
#  <span class="blind">네이버</span>,
#  <span class="blind">쥬니어네이버</span>,
#  <span class="blind">해피빈</span>,
#  <span class="blind">검색</span>,
#  <span class="ico_search_submit"></span>,
#  <span class="blind">한글 입력기</span>,
#  <span class="ico_keyboard"></span>,
#  <span class="blind">자동완성 레이어</span>,
#  <span class="ico_arr"></span>,
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span><span>@txt@</span></span>,
#  <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>,
#  <span>@txt@</span>,
# ...

# %% [markdown]
# #### 과제4_0501.
# "http://www.naver.com" 사이트에서 a 태그에 id가 있는 경우에 대하여 연결된 문자 + 숫자를 아래와 같이 출력하세요.
# - 해당되는 조건에 맞게 출력
# - 한글만 열방향으로 출력
# - 불필요한 공백을 제거한 후 한글만 한 줄에 출력

# %%
# A.
import urllib.request as rq
import re

url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
texts = bs.find_all('a',id=True)
texts
# Out:
# [<a class="_2aeXMlrb BMgpjddw" data-clk="dropdownload1b" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn"><span style="background-color: #0436c7">다운로드</span></a>,
#  <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">네이버를 시작페이지로</a>,
#  <a class="btn_keyboard" href="#" id="ke_kbd_btn" onclick="return false;" role="button"><span class="blind">한글 입력기</span><span class="ico_keyboard"></span></a>,
#  <a aria-pressed="false" class="btn_arw _btn_arw fold" data-atcmp-element="" href="#" id="nautocomplete" role="button" tabindex="2"><span class="blind">자동완성 레이어</span><span class="ico_arr"></span></a>,
#  <a class="btn_set" data-clk="tca.like" href="#" id="NM_THEME_EDIT_SET" role="button">관심주제 설정</a>,
#  <a class="content_top" href="#wrap" id="NM_scroll_top_btn"><span class="blind">TOP</span></a>]

# %%
for text in texts:
    print(' '.join(re.findall('[가-힣0-9]+', text.text)))
# Out:
# 다운로드
# 네이버를 시작페이지로
# 한글 입력기
# 자동완성 레이어
# 관심주제 설정

# %%
for text in texts:
    print(' '.join(re.findall('[가-힣]+', text.text)), end=' ')
# Out:
# 다운로드 네이버를 시작페이지로 한글 입력기 자동완성 레이어 관심주제 설정

# %%
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
text = bs.find('div').get_text()
text
# Out:
# ' 뉴스스탠드 바로가기 주제별캐스트 바로가기 타임스퀘어 바로가기 쇼핑캐스트 바로가기 로그인 바로가기 '

# %%
url = 'https://news.naver.com/'
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
print(bs.find_all('p'))
# Out:
# [<p class="cjs_d">지난달 29일 중국 남서부 쓰촨성 성도 청두시의 마오예런허춘톈 백화점. 건물 외벽 1층의 설화수(Sulwhasoo) 매장 로고 위로 K팝 걸그룹 블랙핑크 멤버 로제의 영상이 나오고 있었다. 로제가 지난해 8월 아모레</p>, <p class="cjs_d">여름이 얼마 남지 않았다. 벌써 기온이 높은 날에 에어컨을 켜는 가정들이 있는데, 지난 여름 이후 청소하지 않은 에어컨을 바로 사용하면 건강에 좋지 않다. 그동안 안에서 증식하던 곰팡이와 레지오넬라균 등이 공중으로 </p>, <p class="cjs_d">인스타그램엔 하루에 9천500만 장의 사진이 올라온다. 이중 상당수는 자신의 모습이 담긴 셀카다. 사람들은 왜 셀카를 찍을까. 흔히 생각하는 바와는 달리, 자신을 과시하고 싶어 셀카를 찍는 것만은 아니라는 연구 결과</p>, <p class="cjs_d">서울 은평구에서도 임대인이 빌라 전세보증금을 돌려주지 않는다는 신고가 접수돼 경찰이 수사에 나선 것으로 확인됐다. 서울 서부경찰서는 임대인 A씨가 보증금을 돌려주지 않는다는 세입자들의 신고를 받고 수사 중이라고 1일</p>, <p class="cjs_d">러시아가 우크라이나에 대규모 미사일 공습을 퍼부은 이튿날, 우크라이나는 러시아군 유류저장고를 파괴하며 반격에 나섰습니다. 우크라이나가 공언해 온 '봄철 대반격'이 임박했다는 관측이 나옵니다. #우크라이나 #러시아 #</p>, <p class="cjs_d">“비상연락망을 확인하고, 고위험군인 주변인에게 연락할 것.” 성폭력 피해자 연대 활동을 하면서 매해 3~4월과 10~11월에 강조하는 일이다. 봄과 가을에는 계절성 우울증 등 여러 요인이 겹쳐 자살 고위험군인 피해자</p>, <p class="cjs_d">인터넷방송 플랫폼 '아프리카TV'가 역대급 '별풍선' 매출을 올렸음에도, 광고시장 환경 변화로 인해 아쉬운 성적표를 받아들였다. 올 1분기 시청자들의 '기부경제 선물'로 높은 매출을 올린 아프리카TV에게 광고 매출 </
# ...

# %%
# find()) : 하나의 요소만 가져 옴
print(bs.find('p'))
# Out:
# <p class="cjs_d">지난달 29일 중국 남서부 쓰촨성 성도 청두시의 마오예런허춘톈 백화점. 건물 외벽 1층의 설화수(Sulwhasoo) 매장 로고 위로 K팝 걸그룹 블랙핑크 멤버 로제의 영상이 나오고 있었다. 로제가 지난해 8월 아모레</p>

# %%
# limit : 태그의 양을 제한

print(bs.find_all('p', limit=1), '\n')
print(bs.find_all('p', limit=3))
# Out:
# [<p class="cjs_d">지난달 29일 중국 남서부 쓰촨성 성도 청두시의 마오예런허춘톈 백화점. 건물 외벽 1층의 설화수(Sulwhasoo) 매장 로고 위로 K팝 걸그룹 블랙핑크 멤버 로제의 영상이 나오고 있었다. 로제가 지난해 8월 아모레</p>]
#
# [<p class="cjs_d">지난달 29일 중국 남서부 쓰촨성 성도 청두시의 마오예런허춘톈 백화점. 건물 외벽 1층의 설화수(Sulwhasoo) 매장 로고 위로 K팝 걸그룹 블랙핑크 멤버 로제의 영상이 나오고 있었다. 로제가 지난해 8월 아모레</p>, <p class="cjs_d">여름이 얼마 남지 않았다. 벌써 기온이 높은 날에 에어컨을 켜는 가정들이 있는데, 지난 여름 이후 청소하지 않은 에어컨을 바로 사용하면 건강에 좋지 않다. 그동안 안에서 증식하던 곰팡이와 레지오넬라균 등이 공중으로 </p>, <p class="cjs_d">인스타그램엔 하루에 9천500만 장의 사진이 올라온다. 이중 상당수는 자신의 모습이 담긴 셀카다. 사람들은 왜 셀카를 찍을까. 흔히 생각하는 바와는 달리, 자신을 과시하고 싶어 셀카를 찍는 것만은 아니라는 연구 결과</p>]

# %% [markdown]
# url = 'https://news.naver.com/' 사이트 p태그에서 class가 cjs_ht인 데이터를 출력하세요.

# %%
import requests as rq

url = 'https://news.naver.com/'

r = rq.get(url)
html = r.text
bs = BeautifulSoup(html, 'lxml')

# print(bs.find_all('p', class_='cjs_ht'))
print(bs.find_all('p', {'class':'cjs_ht'}))
# Out:
# [<p class="cjs_ht">
#
#
#
#                                 방송 모아보기 클릭 시<br/>해당 방송사 뉴스를 볼 수 있으며<br/><span class="comp_ico_live">LIVE</span> 표시가 된 경우 생중계로<br/>시청 가능합니다.
#
#
#                     </p>]

# %%
# Q. texts = bs.find.all('p', {'class':'cjs_d'})
texts = bs.find_all('p', {'class':'cjs_d'})

for text in texts:
    print(text.text,'\n')
# Out:
# 지역 공공병원이 의사를 모집하지 못해 의료공백이 심각(부산일보 2월 24일 자 1면 등 보도)한 가운데 4차 공고 끝에 겨우 성공하는가 했던 경남 산청군보건의료원 내과 전문의 채용이 결국 무산됐다. 벌써 1년 넘도록
#
# 지난 4월 21일 국회에서 상속세 과세체계 개편과 관련한 토론회가 열렸다. 더불어민주당 정책위원회 수석부의장인 김병욱·송기헌·유동수 의원이 주최했다. 토론회 명칭은 ‘상속세 유산취득세 방식 긍정적 검토 토론회’다.
#
# 겉모습은 꼰대지만 누구보다 맛에 진심인 이우석 먹고놀기연구소 소장이 풀어내는 쉬운 미식, 이번에는 호불호가 갈리기 십상인 매운탕 편으로 찾아왔습니다. 이우석 먹고놀기연구소 소장은 "횟집에서 회 뜨고 남은 생선으로 끓
#
# 와이지엔터, 1분기 영업익 167%↑ 주요 엔터사 2분기도 호실적 전망 국내 주요 4대 엔터사를 보는 증권가의 눈높이가 높아지고 있다. 주요 아티스트들의 활동이 본격화되는 데 이어 올해만 10팀의 신인 아티스트가 데
#
# 대낮에 음주운전을 한 20대가 차로 40대 부부를 덮쳐 부인이 숨졌습니다. 전북 완주경찰서에 따르면 오늘 오후 4시 10분쯤 완주군 봉동읍 도로에서 20대 A 씨가 몰던 승용차가 길을 가던 B 씨 부부를 들이받았습니
#
# 더불어민주당의 '2021년 전당대회 돈봉투 의혹'을 수사하는 검찰이 송영길 전 대표에 이어 당시 경선캠프 관계자들에 대한 강제수사에 나섰다. 돈봉투 살포 의혹뿐만 아니라 송 전 대표 개인 차원의 자금 살포 의혹으로
#
# 길가던 40대 부부가 음주 운전 차량에 치여 한 명이 숨졌습니다. 오늘(1일) 오후 4시쯤 완주군 봉동읍 한 도로에서 갓길을 걷던 40대 부부가 음주 상태인 20대가 몰던 승용차에 치여 부인이 숨졌습니다. 경찰은 붙
#
# 최근 문재인 전 대통령이 자신이 책방지기로 직접 일하는 ‘평산책방’을 연 가운데, 문 전 대통령의 딸 다혜 씨가 “책방지기는 그간 아버지가 가졌던 여러 직함 중 가장 어울리는 이름”이라고 말했습니다. 다혜 씨는 지난
#
# ...

# %%
# Q. texts = bs.find_all('p', {'class':'cjs_d'})에서 한글만 출력하세요(p태그별로 열방향)
texts = bs.find_all('p', {'class':'cjs_d'})

for text in texts:
    print(' '.join(re.findall('[가-힣]+', text.text)), '\n')
# Out:
# 지역 공공병원이 의사를 모집하지 못해 의료공백이 심각 부산일보 월 일 자 면 등 보도 한 가운데 차 공고 끝에 겨우 성공하는가 했던 경남 산청군보건의료원 내과 전문의 채용이 결국 무산됐다 벌써 년 넘도록
#
# 지난 월 일 국회에서 상속세 과세체계 개편과 관련한 토론회가 열렸다 더불어민주당 정책위원회 수석부의장인 김병욱 송기헌 유동수 의원이 주최했다 토론회 명칭은 상속세 유산취득세 방식 긍정적 검토 토론회 다
#
# 겉모습은 꼰대지만 누구보다 맛에 진심인 이우석 먹고놀기연구소 소장이 풀어내는 쉬운 미식 이번에는 호불호가 갈리기 십상인 매운탕 편으로 찾아왔습니다 이우석 먹고놀기연구소 소장은 횟집에서 회 뜨고 남은 생선으로 끓
#
# 와이지엔터 분기 영업익 주요 엔터사 분기도 호실적 전망 국내 주요 대 엔터사를 보는 증권가의 눈높이가 높아지고 있다 주요 아티스트들의 활동이 본격화되는 데 이어 올해만 팀의 신인 아티스트가 데
#
# 대낮에 음주운전을 한 대가 차로 대 부부를 덮쳐 부인이 숨졌습니다 전북 완주경찰서에 따르면 오늘 오후 시 분쯤 완주군 봉동읍 도로에서 대 씨가 몰던 승용차가 길을 가던 씨 부부를 들이받았습니
#
# 더불어민주당의 년 전당대회 돈봉투 의혹 을 수사하는 검찰이 송영길 전 대표에 이어 당시 경선캠프 관계자들에 대한 강제수사에 나섰다 돈봉투 살포 의혹뿐만 아니라 송 전 대표 개인 차원의 자금 살포 의혹으로
#
# 길가던 대 부부가 음주 운전 차량에 치여 한 명이 숨졌습니다 오늘 일 오후 시쯤 완주군 봉동읍 한 도로에서 갓길을 걷던 대 부부가 음주 상태인 대가 몰던 승용차에 치여 부인이 숨졌습니다 경찰은 붙
#
# 최근 문재인 전 대통령이 자신이 책방지기로 직접 일하는 평산책방 을 연 가운데 문 전 대통령의 딸 다혜 씨가 책방지기는 그간 아버지가 가졌던 여러 직함 중 가장 어울리는 이름 이라고 말했습니다 다혜 씨는 지난
#
# ...

# %%
texts = bs.find_all('p', {'class':"cjs_d"})
for t in texts:
    t = str(t)
    t = re.findall('[가-힣]+',t)
    t = ' '.join(t)
    print(t,'\n')
# Out:
# 지역 공공병원이 의사를 모집하지 못해 의료공백이 심각 부산일보 월 일 자 면 등 보도 한 가운데 차 공고 끝에 겨우 성공하는가 했던 경남 산청군보건의료원 내과 전문의 채용이 결국 무산됐다 벌써 년 넘도록
#
# 지난 월 일 국회에서 상속세 과세체계 개편과 관련한 토론회가 열렸다 더불어민주당 정책위원회 수석부의장인 김병욱 송기헌 유동수 의원이 주최했다 토론회 명칭은 상속세 유산취득세 방식 긍정적 검토 토론회 다
#
# 겉모습은 꼰대지만 누구보다 맛에 진심인 이우석 먹고놀기연구소 소장이 풀어내는 쉬운 미식 이번에는 호불호가 갈리기 십상인 매운탕 편으로 찾아왔습니다 이우석 먹고놀기연구소 소장은 횟집에서 회 뜨고 남은 생선으로 끓
#
# 와이지엔터 분기 영업익 주요 엔터사 분기도 호실적 전망 국내 주요 대 엔터사를 보는 증권가의 눈높이가 높아지고 있다 주요 아티스트들의 활동이 본격화되는 데 이어 올해만 팀의 신인 아티스트가 데
#
# 대낮에 음주운전을 한 대가 차로 대 부부를 덮쳐 부인이 숨졌습니다 전북 완주경찰서에 따르면 오늘 오후 시 분쯤 완주군 봉동읍 도로에서 대 씨가 몰던 승용차가 길을 가던 씨 부부를 들이받았습니
#
# 더불어민주당의 년 전당대회 돈봉투 의혹 을 수사하는 검찰이 송영길 전 대표에 이어 당시 경선캠프 관계자들에 대한 강제수사에 나섰다 돈봉투 살포 의혹뿐만 아니라 송 전 대표 개인 차원의 자금 살포 의혹으로
#
# 길가던 대 부부가 음주 운전 차량에 치여 한 명이 숨졌습니다 오늘 일 오후 시쯤 완주군 봉동읍 한 도로에서 갓길을 걷던 대 부부가 음주 상태인 대가 몰던 승용차에 치여 부인이 숨졌습니다 경찰은 붙
#
# 최근 문재인 전 대통령이 자신이 책방지기로 직접 일하는 평산책방 을 연 가운데 문 전 대통령의 딸 다혜 씨가 책방지기는 그간 아버지가 가졌던 여러 직함 중 가장 어울리는 이름 이라고 말했습니다 다혜 씨는 지난
#
# ...

# %%
url = 'https://news.daum.net/politics'

r = rq.get(url)
html = r.text
bs = BeautifulSoup(html)
print(bs.find_all('h2'), '\n')
print(bs.find('h2', id='mainContent'), '\n')
print(bs.find('h2', id='mainContent').text)
# Out:
# [<h2 class="screen_out">뉴스 메인메뉴</h2>, <h2 class="screen_out" id="mainContent">정치</h2>, <h2 class="tit_direct">바로가기</h2>, <h2 class="screen_out">서비스 이용정보</h2>]
#
# <h2 class="screen_out" id="mainContent">정치</h2>
#
# 정치

# %%
url = 'https://serieson.naver.com/v3/movie/ranking/realtime'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'html.parser')
print(bs.find('span',class_='Title_title__s9o0D').text)
# Out:
# 던전 앤 드래곤: 도적들의 명예

# %%
import requests
from bs4 import BeautifulSoup

url = "https://serieson.naver.com/v3/movie/ranking/realtime"

# HTTP GET 요청을 보냅니다.
response = requests.get(url)

# HTTP 요청이 성공적으로 전달되었다면, 웹사이트의 HTML 코드를 가져옵니다.
if response.status_code == 200:
    # HTML 코드를 파싱합니다.
    soup = BeautifulSoup(response.text, "html.parser")
# print(soup)
soup.find("span", class_="Title_title__s9o0D").text
# Out:
# '던전 앤 드래곤: 도적들의 명예'

# %% [markdown]
# #### 과제5_0501.
# 네이버 영화 랭킹 실시간 조회 데이터를 가져와서 Top 10 영화를 아래와 같이 출력하세요.<br><br>
#
# 1: 던전 앤 드래곤: 도적들의 명예
#
# 2: 존 윅
#
# 3: 존 윅 3: 파라벨룸

# %%
url = "https://serieson.naver.com/v3/movie/ranking/realtime"

soup = BeautifulSoup(requests.get(url).text)

numbers = soup.find_all('em', {'class':'RankingNumber_rank__zZLNC'}, limit=10)
texts = soup.find_all('span', {'class':'Title_title__s9o0D'}, limit=10)

number = [number.text for number in numbers]
text = [text.text for text in texts]
    
for i in zip(number, text):
    print(f'{i[0]}:{i[1]}')
# Out:
# 1:존 윅 3: 파라벨룸
# 2:던전 앤 드래곤: 도적들의 명예
# 3:존 윅 - 리로드
# 4:앤트맨과 와스프: 퀀텀매니아
# 5:존 윅
# 6:파벨만스
# 7:날씨의 아이
# 8:앤트맨과 와스프: 퀀텀매니아(세트: 1~3편)
# 9:상견니
# 10:아바타: 물의 길(부가영상 제공)

# %%
import requests
from bs4 import BeautifulSoup
req = requests.get("https://serieson.naver.com/v3/movie/ranking/realtime")
html = req.content.decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
list = soup.find_all("span", class_="Title_title__s9o0D")
print(len(list))
for i, l in enumerate(list[:10]):
    print(f'{i+1}: {l.text}')
# Out:
# 100
# 1: 던전 앤 드래곤: 도적들의 명예
# 2: 존 윅 - 리로드
# 3: 존 윅 3: 파라벨룸
# 4: 앤트맨과 와스프: 퀀텀매니아
# 5: 아바타: 물의 길(부가영상 제공)
# 6: 존 윅
# 7: 파벨만스
# 8: 앤트맨과 와스프: 퀀텀매니아(세트: 1~3편)
# 9: 극장판 짱구는 못말려: 수수께끼! 꽃피는 천하떡잎학교
# 10: 너의 이름은.

# %% [markdown]
# #### 과제6_0501.
# url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100' 사이트에서 뉴스기사 제목을 출력하세요.

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'

headers = {'User-Agent': 'Mozilla/5.0'}

r = rq.get(url, headers=headers)
html = r.text
bs = BeautifulSoup(html, 'lxml')

# lines =  bs.select('body > div > main > section > div > div > ul > li > strong > a')

# body = '\n'.join([line.text for line in lines])
# print(body)

# %%
texts = bs.find_all('div', {'class':'cluster_text'})

for text in texts:
    print(text.a.text)
    
print(len(texts))
# Out:
# 김재원, 자숙 한달만에 최고위 복귀... 자진사퇴엔 “아직 생각 안해봐”
# 김재원, 한 달만에 최고위 출석 "심려끼쳐 죄송, 열심히 하겠다"
# 최고위 복귀 김재원, ‘자진사퇴’엔 “아직 생각 안해봐”
# '설화' 김재원 최고위 복귀…'자진사퇴'엔 "아직 생각 안 해봐"
# 김의겸 "尹, 150조 내고 '아메리칸 파이' 불러…백악관, 정말 비싼 노래방"
# 김의겸 "尹, 백악관 노래방서 150조짜리 한곡 부르고 온 것"
# "'핵 공유 호소인'" "미국 위한 최악 정상회담"…야당, 윤 방미 맹비난
# "'핵공유 호소인'" "느낌적 방미 성과?"…野, 尹방미 맹비난(종합)
# 김재원·태영호 징계절차 착수한 與윤리위…8일 소명 청취 [종합]
# 국민의힘, 김재원·태영호 징계 절차 개시…다음 주 징계 유력
# '징계수위는?'…총선 앞두고 김재원·태영호에 칼 빼든 與
# 국민의힘 윤리위, '실언 논란' 김재원·태영호 징계절차 개시
# 공천에 영향?‥'당무 개입 논란 번지나?
# 태영호 "이진복, 한일관계·공천 문제 언급한 사실 없어…유감"
# [단독] "대통령실 '공천' 거론하며 한일관계 옹호" 압박?
# 태영호 “MBC 보도 유감…이진복, 한일관계·공천문제 언급한 적 없어”
# 박대출 "방송법 국회 통과하면 대통령이 거부권 행사해야"
# “KBS 라디오 친야 일색”…국힘 “‘방송법 개정안’ 대통령 거부권을”
# "전세사기를 왜 혈세로 구제?" "특별법 문턱 높아" 반발 여론도 둘로 갈렸다
# 미추홀은 되고 동탄은 제외?…'지원대상 6개요건' 국회논의 주목
# 박진 "전술핵 재배치, '北비핵화 요구'와 어긋나"
# 박진 “전술핵 재배치 사실상 어렵다”
# 규제샌드박스 승인 4~5개월서 2개월로 단축…'패스트트랙' 도입
# 수원특례시, '수원형 규제샌드박스 TF(태스크포스)구성'
# 尹지지율 4주 만에 반등 34.5%…“미국 국빈 방문 영향”
# 방미 효과에 尹지지율 반등 모멘텀…상승세로 이어질까[數싸움]
# ...

# %%
html = """
<ul>
  <li><a href="hoge.html">hoge</li>
  <li><a href="https://example.com/fuga">fuga*</li>
  <li><a href="https://example.com/foo">foo*</li>
  <li><a href="http://example.com/aaa">aaa</li>
</ul>
"""

soup = BeautifulSoup(html)

# 정규 표현식으로 href에서 https인 것 추출하기
li = soup.find_all(href=re.compile(r'^https://'))
print(li, '\n')

for e in li: print(e.attrs['href'])
# Out:
# [<a href="https://example.com/fuga">fuga*</a>, <a href="https://example.com/foo">foo*</a>]
#
# https://example.com/fuga
# https://example.com/foo

# %% [markdown]
# ### CSS 선택자
# - 원하는 정보만 선별하여 수집하고 싶을 때 css선택자를 활용할 수 있음
# - (CSS 선택자 설명 추가)
# - F12 >> 수집하고 싶은 부분 클릭 >> 태그 선택 >> copy Selector
# - BeautifulSoup의 select_one, select 활용

# %%
# select_one()

r = rq.get(url)
html = r.text
bs = BeautifulSoup(html, 'lxml')

line = bs.select_one ('body > div.container-doc.cont-category > main > section > div.main-sub > div.box_g.box_news_major > ul > li:nth-child(1) > strong > a')
# line = bs.select_one ('body > div > main > section > div > div > ul > li > strong > a')

print(line.text)
# Out:
# 용혜인 "'초단시간 노동자 권리찾기법' 발의 추진"

# %%
# select()

url = 'https://news.daum.net/politics#1'

r = rq.get(url)
html = r.text
bs = BeautifulSoup(html, 'lxml')

# body > div.container-doc.cont-category > main > section > div.main-sub > div.box_g.box_news_major > ul > li:nth-child(2) > strong > a
lines =  bs.select('body > div > main > section > div > div > ul > li > strong > a')

body = '\n'.join([line.text for line in lines])
print(body)
body
# Out:
# 尹 지지율 4주 만에 반등 34.5%..'미국 국빈 방문 영향'
# 송영길 측 회계담당자, 수사 직전 파리 방문…"가족 요청"
# 증평역 설치 100주년…군청 앞에 기념 표지판 제막
# 천아용인 모였다…이준석 “1000원밥? 똑바로 하면 2만원 내고도 온다”
# 용혜인 "'초단시간 노동자 권리찾기법' 발의 추진"
# 나라 곳간 우려는 뒷전... 재정소요 법안 '비용추계서 제출' 유명무실
# 5월 임시국회 시작…여야, '노란봉투법' 충돌 예고
# 민주당 “맞벌이 학부모 위한 주 4일제 적극 검토”
# 尹대통령, 한총리와 주례회동 취소…"방미 직후 사정 등 고려"
# 노동절에 노동자 갈라치는 대통령…“고용세습 뿌리 뽑겠다”
# '尹 지지율 4주 만에 반등 34.5%..\'미국 국빈 방문 영향\'\n송영길 측 회계담당자, 수사 직전 파리 방문…"가족 요청"\n증평역 설치 100주년…군청 앞에 기념 표지판 제막\n천아용인 모였다…이준석 “1000원밥? 똑바로 하면 2만원 내고도 온다”\n용혜인 "\'초단시간 노동자 권리찾기법\' 발의 추진"\n나라 곳간 우려는 뒷전... 재정소요 법안 \'비용추계서 제출\' 유명무실\n5월 임시국회 시작…여야, \'노란봉투법\' 충돌 예고\n민주당 “맞벌이 학부모 위한 주 4일제 적극 검토”\n尹대통령, 한총리와 주례회동 취소…"방미 직후 사정 등 고려"\n노동절에 노동자 갈라치는 대통령…“고용세습 뿌리 뽑겠다”'

# %%
# Q. 한글만 출력하세요 (개행없이)

' '.join(re.findall('[가-힣]+', body))
# Out:
# '지지율 주 만에 반등 미국 국빈 방문 영향 송영길 측 회계담당자 수사 직전 파리 방문 가족 요청 증평역 설치 주년 군청 앞에 기념 표지판 제막 천아용인 모였다 이준석 원밥 똑바로 하면 만원 내고도 온다 용혜인 초단시간 노동자 권리찾기법 발의 추진 나라 곳간 우려는 뒷전 재정소요 법안 비용추계서 제출 유명무실 월 임시국회 시작 여야 노란봉투법 충돌 예고 민주당 맞벌이 학부모 위한 주 일제 적극 검토 대통령 한총리와 주례회동 취소 방미 직후 사정 등 고려 노동절에 노동자 갈라치는 대통령 고용세습 뿌리 뽑겠다'

# %%
texts = re.findall('[가-힣0-9]+',body)
print(' '.join(texts))
# Out:
# 지지율 4주 만에 반등 34 5 미국 국빈 방문 영향 송영길 측 회계담당자 수사 직전 파리 방문 가족 요청 증평역 설치 100주년 군청 앞에 기념 표지판 제막 천아용인 모였다 이준석 1000원밥 똑바로 하면 2만원 내고도 온다 용혜인 초단시간 노동자 권리찾기법 발의 추진 나라 곳간 우려는 뒷전 재정소요 법안 비용추계서 제출 유명무실 5월 임시국회 시작 여야 노란봉투법 충돌 예고 민주당 맞벌이 학부모 위한 주 4일제 적극 검토 대통령 한총리와 주례회동 취소 방미 직후 사정 등 고려 노동절에 노동자 갈라치는 대통령 고용세습 뿌리 뽑겠다

# %% [markdown]
# #### 과제7_0501.
# 네이버 뉴스 데이터 사회분야 데이터를 가져와서 다음을 수행하세요.
# - 첫 번째 뉴스 제목과  href를 출력
# - 뉴스 전체 제목과 href를 출력(열방향)

# %%
import requests as rq

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=102'

headers = {'User-Agent': 'Mozilla/5.0'}

r = rq.get(url, headers=headers)
html = r.text
bs = BeautifulSoup(html,'lxml')

print(bs.find('div', {'class':'cluster_text'}).a.string)
print(bs.find('div', {'class':'cluster_text'}).a['href'])
# Out:
# 부산시, 5일 영화의전당서 '어린이날 큰잔치' 개최
# https://n.news.naver.com/mnews/article/079/0003765371?sid=102

# %%
texts = bs.find_all('div', {'class':'cluster_text'})

for text in texts:
    print(text.a.string)
    print(text.a['href'])
# Out:
# 부산시, 5일 영화의전당서 '어린이날 큰잔치' 개최
# https://n.news.naver.com/mnews/article/079/0003765371?sid=102
# 부산시, 5일 영화의 전당에서 ‘어린이날 큰 잔치’
# https://n.news.naver.com/mnews/article/003/0011834631?sid=102
# 모든 어린이가 행복한 HAPPY DAY … ‘제50회 부산 어린이날 큰잔치’, 해운대 영화의 전당서 만나요
# https://n.news.naver.com/mnews/article/277/0005253265?sid=102
# 제50회 부산 어린이날 큰잔치…5일 해운대 영화의 전당
# https://n.news.naver.com/mnews/article/421/0006781242?sid=102
# [2보]대낮에 40대 부부 음주운전 車에 치여 아내 사망하고 남편 중상
# https://n.news.naver.com/mnews/article/087/0000967741?sid=102
# 음주운전 하다 부부 덮친 20대 “앞을 못 봤다”
# https://n.news.naver.com/mnews/article/081/0003358012?sid=102
# 대낮 음주차량, 길 가던 40대 부부 덮쳐...부인 사망
# https://n.news.naver.com/mnews/article/052/0001879794?sid=102
# 대낮 만취운전 20대, 길가던 40대 부부 들이받아 아내 사망
# https://n.news.naver.com/mnews/article/023/0003761089?sid=102
# 엠폭스 환자 늘어나는데…국민 절반 이상 치료제·백신 모른다
# https://n.news.naver.com/mnews/article/003/0011833654?sid=102
# 엠폭스 확진자 5명 늘어 누적 47명…"국내감염 추정"
# ...

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.daum.net/politics#1'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'lxml')
lines = bs.select('body > div > main > section > div > div > ul > li > strong > a')
for line in lines:
    print(line.text)
# Out:
# 北, '체육'으로 노동절 기념…김정은은 잠행·고위간부는 총출동
# 조정훈 “김건희 여사 왜 설치냐? 이건 ‘조선시대·꼰대’ 생각”
# '경남의 BTS' 찾습니다…도, 청년 페스티벌 참가자 모집
# [정치쇼] 신범철 "확장억제 '그릇' 만들어졌다…구체화 노력 중"
# 인천시, 정당현수막 '지정게시대 자율준수' 조례 추진
# 윤재옥 “‘돈 봉투 게이트’ 얄팍한 출두쇼로 덮을 수 없어”
# 천주교 사제들 시국기도회.."尹, 대한민국 헌법 준수하고 있나"
# “주요 의제는 한미일 외교안보 협의체…G7 전초전 될 것” [다시 뛰는 한일셔틀외교]
# 윤재옥 "송영길, 꼼수 출두쇼 그만하고 국민 앞에 사죄해야"
# 여당, 당무감사위원에 '허위사실 유포' 서명옥 내정 논란

# %%
texts = select('div', {'id':'timeline'})
for text in texts:
    print(text.a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7908\1971378901.py in <module>
# ----> 1 texts = select('div', {'id':'timeline'})
#       2 for text in texts:
#       3     print(text.a)
#
# NameError: name 'select' is not defined

# %%
# 제목 추출 #title_area > span
target = soup.select_one("#title_area > span")
print(target)
print("-"*100)
target = target.text # tag를 떼고 추출
print(target)
# Out:
# <span>‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”</span>
# ----------------------------------------------------------------------------------------------------
# ‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”

# %% [markdown]
# ####  과제1_0502.
# url = "https://n.news.naver.com/mnews/article/032/0003161880?sid=101" 사이트에서 연예, 날씨, 스포츠, 프레미엄을 찾아서 출력하세요.

# %%
import requests as rq

url = 'https://n.news.naver.com/mnews/article/032/0003161880?sid=101'

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

r = rq.get(url, headers=headers)
html = r.text
soup = BeautifulSoup(html,'lxml')
soup

texts = soup.find_all('span', {'class':'Nservice_subitem'})

# texts = [text.get_text() for text in texts]

for text in texts:
    print(text.text.strip())
# Out:
# 연예
# 스포츠
# 날씨
# 프리미엄

# %% [markdown]
# ####

# %%
# 본문 추출 : #dic_area
target = soup.select_one("#dic_area")
print(target)
print("-"*100)
target = target.text
print(target)
# Out:
# <div class="go_trans _article_content" id="dic_area">
# <strong class="media_end_summary">1차는 6만4650명 구매···평균 39만원어치 팔려<br/>서울시 “서울페이플러스 회원 가입은 전날 미리”</strong><span class="end_photo_org"><div class="nbd_im_w _LAZY_LOADING_WRAP">
# <div class="nbd_a _LAZY_LOADING_ERROR_HIDE" id="img_a1">
# <img class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=w647" id="img1"/>
# </div>
# ...

# %%
# 이미지 주소 추출 : #img1
target = soup.select_one("#img1")
print(target)
print("-"*100)
target = target["data-src"]
print(target)
# Out:
# <img class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=w647" id="img1"/>
# ----------------------------------------------------------------------------------------------------
# https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=w647

# %%
# 네이버 환율 가져오기 : #exchangeList > li.on > a.head.usd > div > span.value
from bs4 import BeautifulSoup
import urllib.request as req
# HTML 가져오기
url = "https://finance.naver.com/marketindex/"
res = req.urlopen(url)
# HTML 분석하기
soup = BeautifulSoup(res, "html.parser")
print(soup)
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindo.1.5.3.element-text-patch.js" type="text/javascript"></script>
# <div id="container" style="padding-bottom:0px;">
# <div class="market_include">
# <div class="market_data">
# <div class="market1">
# <div class="title">
# <h2 class="h_market1"><span>환전 고시 환율</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="exchangeList">
# <li class="on">
# <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
# <div class="head_info point_up">
# ...

# %%
import urllib.request as req


url = 'https://finance.naver.com/marketindex/'

res = req.urlopen(url)

soup = BeautifulSoup(res)
# Out:
# usd/krw = 1,340.10

# %%
# 원하는 데이터 추출하기

price = soup.select_one('#exchangeList > li.on > a.head.usd > div > span.value').string
print('usd/krw =', price)
# Out:
# usd/krw = 1,340.10

# %%
for child in bs.find('table', {'id':'giftList'}).children:
    print(child)

# %%
print(bs.find('img',{'src':'../img.gifts/img1.jpg'}).parent.previous_sibling.get_text())

# %%
for sibling in bs.find('table', {'id':'giftList'}).tr.next_siblings:
    print(child)

# %%
html="""
<head>
    <title>crawler</title>
</head>
<body>
    <p class="a" align="center"> text1</p>
    <p class="b" align="center"> text2</p>
    <p class="c" align="center"> text3</p>
    <div>
        <img src="/source" width="300" height="200">
    </div>
</body>
</html>
"""

# %%
soup = BeautifulSoup(html)
contents = soup.find('body')
for child in contents.children:
    print(child)
# Out:
# <p align="center" class="a"> text1</p>
#
#
# <p align="center" class="b"> text2</p>
#
#
# <p align="center" class="c"> text3</p>
#
#
# <div>
# <img height="200" src="/source" width="300"/>
# </div>

# %%
for child in contents.decendants:
    print(child)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9660\1705923953.py in <module>
# ----> 1 for child in contents.decendants:
#       2     print(child)
#
# TypeError: 'NoneType' object is not iterable

# %%
# 태그 객체

contents.div.img
soup.body.div.img
# Out:
# <img height="200" src="/source" width="300"/>

# %%
import urllib

response = urllib.request.urlopen('https://naver.com')
html = response.read()
soup = BeautifulSoup(html)
print(soup.find_all('a',{'class':'link_newsstand'}), '\n')
print(soup.find_all('a',{'class':'btn_sort'}), '\n')
# Out:
# [<a class="link_newsstand" data-clk="title" href="http://newsstand.naver.com/" target="_blank">뉴스스탠드</a>]
#
# [<a aria-controls="NM_NEWSSTAND_MY_LIST" aria-selected="false" class="btn_sort" data-clk="my" data-type="my" href="#" role="tab">구독한 언론사</a>, <a aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true" class="btn_sort" data-clk="all" data-type="all" href="#" role="tab">전체언론사</a>]

# %%
nlists = soup.findAll('a',{'class':{'link_newsstand','btn_sort'}})    # 버전3 메서드임 -> find_all이 버전 4

for n in nlists:
    print(n.get_text())
# Out:
# 뉴스스탠드
# 구독한 언론사
# 전체언론사

# %%
from urllib.request import urlopen

html = urlopen('https://naver.com')
bs = BeautifulSoup(html)

hlists = bs.findAll({'h1', 'h2', 'h3', 'h4', 'h5', 'h6'}, limit=5)

for h in hlists:
    print(h, '\n')
# Out:
# <h1 class="logo_default">
# <a class="logo_naver" data-clk="top.logo" href="/"><span class="blind">네이버</span></a>
# </h1>
#
# <h2 class="blind">뉴스스탠드</h2>
#
# <h2 class="blind">주제별 캐스트</h2>
#
# <h2 class="blind">Sign in</h2>
#
# <h2 class="blind">타임스퀘어</h2>

# %%
# 아마 집합 자료형을 쓰면 순서 상관없어서, 결과물도 웹사이트 순서대로 나오지 않을까??

hlists = bs.find_all({'h1', 'h2', 'h3', 'h4', 'h5', 'h6'}, text='뉴스스탠드')    # 집합 자료형임
hlists = bs.find_all(('h1', 'h2', 'h3', 'h4', 'h5', 'h6'), text='뉴스스탠드')
hlists = bs.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6'], text='뉴스스탠드')

print(hlists)
# Out:
# [<h2 class="blind">뉴스스탠드</h2>]
