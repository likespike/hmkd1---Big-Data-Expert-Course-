# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 선형 대수학 - 인풋과 아웃풋 사이의 관계, 인풋과 인풋 사이의 관계가
#
# 이러한 선형적인 것들로 이루어진 집합, 벡터, 행렬 -> 인공지능에 쓰임
#
# X -> Y 사이의 함수, 블랙박스 (매핑한다고 함)
#
# X, Y는 대부분 다차원임, 이런 다차원 자료를 표현할 때 가장 효과적으로 쓰이는 것이 벡터임
#
# 벡터와 벡터를 맵핑할 때, 관계를 정의할 때 행렬을 사용해서, 행렬의 곱을 사용함(연산)
#
# 벡터 - 크기와 방향이 있는 물리량 (벡터는 스칼라의 묶음임), 스칼라가 1차원, 한 직선 위에 놓여있는 것 = 1차원 물리량
# 스칼라 - 크가 자체만 존재함, 어떤 값임, R(실수임) = 0차원 물리량
#
# 벡터 a에 막대기 씌운 것 = norm = 벡터의 크기임 3,4 = 5
#
# 3의 제곱 9, 4의 제곱 16 -> 더하면 25 -> 루트 씌우면 -> 5
#
# 세타는 두 벡터 사이의 사잇각임
#
# 결국 벡터의 크기와 두 벡터 사이의 사잇각을 알면 내적을 구할 수 있다
#
# #### 이런 내적을 구하는 이유
# - 두 벡터의 내적이 0이라는 의미는 직교관계라는 의미이다. b 입장에서 봤을 때 a가 아무리 움직여도 모름
# - a1, a2는 일차 독립니다
#
# #### 행렬
# - 행렬은 벡터의 나열이다. 묶은 것

# %% [markdown]
# ### 추천 시스템의 유형
# 1. 콘텐츠 기반 필터링 (Content based filtering)
#
# 2. 협업 필터링 (Collaborative Filtering)
# - 최근접 이웃(Nearest Neighbor) 협업 필터링
#     - 사용자 기반
#     - 아이템 기반
# - 잠재 요인(Latent Factor) 협업 필터링

# %% [markdown]
# ### 콘텐츠 기반 필터링 실습 - TMDB 5000 영화 데이터 세트
# - https://www.kaggle.com/tmdb/tmdb-movie-metadata
# - tmdb_5000_credits.csv

# %%
# vote_average - 평균 평점
# vote_count - 평점 투표수
# popularity - 영화 인기 정도
# revenue - 총수입 (티켓만이 아닌 모든 수입요소)

import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

movies = pd.read_csv('/content/drive/Othercomputers/내 컴퓨터/hmkd1/dataset/tmdb_5000_movies.csv')
print(movies.shape)
movies.head(2)
# Out:
# (4803, 20)
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
movies.sort_values('vote_count', ascending=False).head(1)
# Out:
#        budget                                             genres  \
# 96  160000000  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
#
#                                  homepage     id  \
# 96  http://inceptionmovie.warnerbros.com/  27205
#
#                                              keywords original_language  \
# 96  [{"id": 1014, "name": "loss of lover"}, {"id":...                en
#
#    original_title                                           overview  \
# 96      Inception  Cobb, a skilled thief who commits corporate es...
#
#     popularity                               production_companies  \
# 96   167.58371  [{"name": "Legendary Pictures", "id": 923}, {"...
#
#                                  production_countries release_date    revenue  \
# 96  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2010-07-14  825532764
#
#     runtime                                   spoken_languages    status  \
# ...

# %%
print(movies.iloc[0].genres, '\n')
print(movies.iloc[0].keywords,'\n')
print(movies.iloc[0].production_companies,'\n')
print(movies.iloc[0].production_countries,'\n')
print(movies.iloc[0].spoken_languages,'\n')
# Out:
# [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]
#
# [{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]
#
# ...

# %%
movies_df = movies[['id', 'title', 'genres', 'vote_average', 'vote_count', 'popularity', 'keywords', 'overview']]
movies_df.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                               genres  vote_average  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...           7.2
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...           6.9
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...           6.3
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...           7.6
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...           6.1
#
#    vote_count  popularity                                           keywords  \
# 0       11800  150.437577  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1        4500  139.082615  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# ...

# %%
pd.set_option('max_colwidth', 100)
movies_df[['genres', 'keywords']][:1]
# Out:
#                                                                                                 genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {...
#
#                                                                                               keywords
# 0  [{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "sp...

# %%
print(type(movies_df.genres[0]))
movies_df.genres[0]
# Out:
# <class 'str'>
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
movies_df.genres[0][0]
# Out:
# '['

# %%
# literal 문자 그대로를 evaluate 평가하여 파이썬 객체로 변환하는 함수임(문자, 숫자, 튜플, 리스트, 딕셔너리 등의 파이썬 객체로)
# 해당 문자열이 리스트 형태이기에, 리스트 형태의 객체로 반환해줌

from ast import literal_eval
type(movies_df['genres'].apply(literal_eval)[0])
# Out:
# list

# %%
movies_df['genres'] = movies_df['genres'].apply(literal_eval)
movies_df['keywords'] = movies_df['keywords'].apply(literal_eval)

# %%
movies_df.genres[0][0]
# Out:
# {'id': 28, 'name': 'Action'}

# %%
movies_df.genres[0][0]['name']
# Out:
# 'Action'

# %%
# apply()함수는 각 컬럼의 리스트 안의 각 딕셔너리에도 각각 적용이 되는 듯

movies_df['genres'] = movies_df['genres'].apply(lambda x : [y['name']for y in x])
movies_df['keywords'] = movies_df['keywords'].apply(lambda x : [y['name']for y in x])
movies_df[['genres', 'keywords']]
# Out:
#                                              genres  \
# 0     [Action, Adventure, Fantasy, Science Fiction]
# 1                      [Adventure, Fantasy, Action]
# 2                        [Action, Adventure, Crime]
# 3                  [Action, Crime, Drama, Thriller]
# 4              [Action, Adventure, Science Fiction]
# ...                                             ...
# 4798                      [Action, Crime, Thriller]
# 4799                              [Comedy, Romance]
# 4800             [Comedy, Drama, Romance, TV Movie]
# 4801                                             []
# 4802                                  [Documentary]
#
#                                                                                                  keywords
# 0     [culture clash, future, space war, space colony, society, space travel, futuristic, romance, spa...
# 1     [ocean, drug abuse, exotic island, east india trading company, love of one's life, traitor, ship...
# ...

# %% [markdown]
# ### 장르 콘텐츠 유사도 측정
# - genres를 문자열로 변경한 뒤 이를 CountVectorizer로 피처 벡터화한 행렬 데이터 값을 코사인 유사도로 비교하는 것

# %%
from sklearn.feature_extraction.text import CountVectorizer

# CountVectorizer를 적용하기 위해 공백문자로 word 단위가 구분되는 문자열로 변환.
movies_df['genres_literal'] = movies_df['genres'].apply(lambda x : (' ').join(x))
count_vect = CountVectorizer(min_df=0, ngram_range=(1, 2))  # min_df=0 특성으로 선택할 단어의 최소 빈도가 0이므로 결국 모든 단어를 선택하는 것임
                                                            # ngram_range(1, 2) I love cats => 'I', 'love', 'cats', 'I' 'love', 'love cats'
genre_mat = count_vect.fit_transform(movies_df['genres_literal'])
print(genre_mat.shape)
# Out:
# (4803, 276)

# %%
movies_df.head(1)
# Out:
#       id   title                                         genres  vote_average  \
# 0  19995  Avatar  [Action, Adventure, Fantasy, Science Fiction]           7.2
#
#    vote_count  popularity  \
# 0       11800  150.437577
#
#                                                                                               keywords  \
# 0  [culture clash, future, space war, space colony, society, space travel, futuristic, romance, spa...
#
#                                                                                               overview  \
# 0  In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, ...
#
#                              genres_literal  weighted_vote
# 0  Action Adventure Fantasy Science Fiction       7.166301

# %%
# 코싸인 유사도 측정

from sklearn.metrics.pairwise import cosine_similarity

genre_sim = cosine_similarity(genre_mat, genre_mat)
print(genre_sim.shape)
print(genre_sim[:2])
# Out:
# (4803, 4803)
# [[1.         0.59628479 0.4472136  ... 0.         0.         0.        ]
#  [0.59628479 1.         0.4        ... 0.         0.         0.        ]]

# %%
# 자기 자신인 0번 레코드의 경우를 제외하고 3494가 높은 등의 의미임

genre_sim_sorted_ind = genre_sim.argsort()[:, ::-1]
print(genre_sim_sorted_ind[:1])
# Out:
# [[   0 3494  813 ... 3038 3037 2401]]

# %%
# 장르 유사도에 따라 영화를 추천하는 함수
# sorted_ind - 레코드별 장르 코사인 유사도 인덱스를 가지고 있음
# title_name - 고객이 선정한 추천 기준이 되는 영화 제목
# top_n - 추천할 영화 건수

def find_sim_movie(df, sorted_ind, title_name, top_n=10):
    # 인자로 입력된 movies_df DataFrame에서 'title' 칼럼이 입력된 title_name 값인 DataFrame 추출
    title_movie = df[df['title'] == title_name]

    # title_named을 가진 DataFrame의 index 객체를 ndarray로 반환하고
    # sorted_ind 인자로 입력된 genre_sim_sorted_ind 객체에서 유사도 순으로  top_n개의 index 추출
    title_index = title_movie.index.values
    similar_indexes = sorted_ind[title_index, :(top_n)]

    # 추출된 top_n index 출력. top_n index는 2차원 데이터임.
    # dataframe에서 index로 사용하기 위해서 1차원 array로 변경
    print(similar_indexes)
    similar_indexes = similar_indexes.reshape(-1)    # 여기는 있어야 함

    return df.iloc[similar_indexes]

# %%
movies_df[movies_df['title'] == 'The Godfather']
# Out:
#        id          title          genres  vote_average  vote_count  \
# 3337  238  The Godfather  [Drama, Crime]           8.4        5893
#
#       popularity  \
# 3337  143.659698
#
#                                                                                                  keywords  \
# 3337  [italy, love at first sight, loss of father, patriarch, organized crime, mafia, lawyer, italian ...
#
#                                                                                                  overview  \
# 3337  Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime fa...
#
#      genres_literal  weighted_vote
# 3337    Drama Crime       8.263591

# %%
print(movies_df[movies_df['title'] == 'The Godfather'].index.values)

genre_sim_sorted_ind = genre_sim.argsort()[:, ::-1]
print(genre_sim_sorted_ind[3337, :10])    # 아래와 같이 reshape 안해줘도 됨 -> 이미 1차원 배열로 반환됨
# genre_sim_sorted_ind[3337, :10].reshape(-1)
movies_df.iloc[genre_sim_sorted_ind[3337, :10]][['title', 'vote_average']]
# Out:
# [3337]
# [2731 1243 3636 1946 2640 4065 1847 4217  883 3866]
#                                                title  vote_average
# 2731                          The Godfather: Part II           8.3
# 1243                                    Mean Streets           7.2
# 3636                                   Light Sleeper           5.7
# 1946  The Bad Lieutenant: Port of Call - New Orleans           6.0
# 2640         Things to Do in Denver When You're Dead           6.7
# 4065                                      Mi America           0.0
# 1847                                      GoodFellas           8.2
# 4217                                            Kids           6.8
# 883                              Catch Me If You Can           7.7
# 3866                                     City of God           8.1

# %%
similar_movies = find_sim_movie(movies_df, genre_sim_sorted_ind, 'The Godfather', 10)
similar_movies[['title', 'vote_average']]
# Out:
# [[2731 1243 3636 1946 2640 4065 1847 4217  883 3866]]
#                                                title  vote_average
# 2731                          The Godfather: Part II           8.3
# 1243                                    Mean Streets           7.2
# 3636                                   Light Sleeper           5.7
# 1946  The Bad Lieutenant: Port of Call - New Orleans           6.0
# 2640         Things to Do in Denver When You're Dead           6.7
# 4065                                      Mi America           0.0
# 1847                                      GoodFellas           8.2
# 4217                                            Kids           6.8
# 883                              Catch Me If You Can           7.7
# 3866                                     City of God           8.1

# %%
# 평점을 추가해 좀 더 좋은 추천 시스템 만들기
# 그런데 고려해야 할 것이 평점에 평가 관객 수임

movies_df[['title', 'vote_average', 'vote_count']].sort_values('vote_average', ascending=False)[:10]
# Out:
#                          title  vote_average  vote_count
# 3519          Stiff Upper Lips          10.0           1
# 4247     Me You and Five Bucks          10.0           2
# 4045     Dancer, Texas Pop. 81          10.0           1
# 4662            Little Big Top          10.0           1
# 3992                 Sardaarji           9.5           2
# 2386            One Man's Hero           9.3           2
# 2970        There Goes My Baby           8.5           2
# 1881  The Shawshank Redemption           8.5        8205
# 2796     The Prisoner of Zenda           8.4          11
# 3337             The Godfather           8.4        5893

# %%
# v - 개별 영화에 평점을 투표한 횟수
# m - 평점을 부여하기 위한 최소 투표 횟수
# R - 개별 영화에 대한 평균 평점
# C - 전체 영화에 대한 평균 평점

C = movies_df.vote_average.mean()
m = movies_df.vote_count.quantile(0.6)
print('C', round(C, 3), 'm:', round(m,3))
# Out:
# C 6.092 m: 370.2

# %%
percentile = 0.6
m = movies_df['vote_count'].quantile(percentile)
C = movies_df['vote_average'].mean()

def weighted_vote_average(record):
    v = record['vote_count']
    R = record['vote_average']

    return ((v/(v+m)) * R) + ((m/(m+v)) * C)

movies_df['weighted_vote'] = movies_df.apply(weighted_vote_average, axis=1)

# %%
movies_df[['title', 'vote_average', 'weighted_vote', 'vote_count']].sort_values('weighted_vote', ascending=False)[:10]
# Out:
#                          title  vote_average  weighted_vote  vote_count
# 1881  The Shawshank Redemption           8.5       8.396052        8205
# 3337             The Godfather           8.4       8.263591        5893
# 662                 Fight Club           8.3       8.216455        9413
# 3232              Pulp Fiction           8.3       8.207102        8428
# 65             The Dark Knight           8.2       8.136930       12002
# 1818          Schindler's List           8.3       8.126069        4329
# 3865                  Whiplash           8.3       8.123248        4254
# 809               Forrest Gump           8.2       8.105954        7927
# 2294             Spirited Away           8.3       8.105867        3840
# 2731    The Godfather: Part II           8.3       8.079586        3338

# %%
# find_sim_movie 함수 수정

def find_sim_movie(df, sorted_ind, title_name, top_n=10):
    title_movie = df[df['title'] == title_name]
    title_index = title_movie.index.values

    # top_n의 2배에 해당하는 장르 유사성이 높은 인덱스 추출
    similar_indexes = sorted_ind[title_index, :(top_n*2)]
    # similar_indexes = similar_indexes.reshape(-1)
    # 기준 영화 인덱스는 제외
    similar_indexes = similar_indexes[similar_indexes != title_index]

    # top_n의 2배에 해당하는 후보군에서 weighted_vote가 높은 순으로 top_n만큼 추출
    return df.iloc[similar_indexes].sort_values('weighted_vote', ascending=False)[:top_n]

similar_movies = find_sim_movie(movies_df, genre_sim_sorted_ind, 'The Godfather', 10)
similar_movies[['title', 'vote_average', 'weighted_vote']]
# Out:
#                             title  vote_average  weighted_vote
# 2731       The Godfather: Part II           8.3       8.079586
# 1847                   GoodFellas           8.2       7.976937
# 3866                  City of God           8.1       7.759693
# 1663  Once Upon a Time in America           8.2       7.657811
# 883           Catch Me If You Can           7.7       7.557097
# 281             American Gangster           7.4       7.141396
# 4041              This Is England           7.4       6.739664
# 1149              American Hustle           6.8       6.717525
# 1243                 Mean Streets           7.2       6.626569
# 2839                     Rounders           6.9       6.530427
