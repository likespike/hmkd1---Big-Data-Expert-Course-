# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pylab as plt
import sympy
import scipy as sp

# %% [markdown]
# https://mathbang.net/13#gsc.tab=0

# %% [markdown]
# #### 차원
# - 움직이는 방향의 개수
#     - 점 : 0차원
#     - 선 : 1차원 (한 방향으로 움직임
#     - 면 : 2차원 (두 방향)
#     - 공 간 : 3차원 (좌우, 위아래, 앞뒤)

# %% [markdown]
# #### 함수
# 1. 정의
# - y = x+3 (x에 더하기 3을 하는 관계) / y = 2x+4 (x에 2를 곱하고 4를 더하는 관계)
# - x : 독립변수 / y : 종속변수
# - 독립변수와 종속변수가 어떠한 관계를 갖는지를 나타낸 식
# - 간단하게 y = f(x)
#     - y는 x를 넣었을 때 function(기계작동)한 값(출력물) = 'y는 x의 함수이다'
#     - x와 y 사이에 어떠한 관계가 있는지를 압축하고 있는 함수의 이름임
#     - y는 x의 함수라는건가? y는 x의 함수를 한 것의 결과라는 의미인가?? y가 x라는 놈의 함수 자체라는 건가(y=함수), y는 x의 함수를 한 결과라는 건가(f(x))
#     - x=1에서의 함숫값은 = f(1)=?
#     - 그럼 y는 함숫값
#     - f(x) = 2x => y=2x => y=f(x)
# - 함수 이름은 의미를 담아 짓는다
#     - 효용함수(Utility) : U(x) = 2X = 4
#         - 소비자가 느끼는 효용의 크기는 소비자가 소비하는 재화의 소비 량에 의해 결정됨
#     - 생산함수(Quantity, Labor) : Q(L) = 4L
#         - 사람 4명 투입하면 물건이 1개 만들어지는 관계임을 알 수 있음
# - 두 변수 x,y에 대하여 x가 정해지면 그에 따라 y의 값이 오직 하나로 결정될 때, y를 x의 함수라고 함
#     - y = 1000x일 때, 1000x는 f(x) => 그러면 y = f(x), 즉, y가 함수임
#     - 몸무게는 먹는 양의 function / 수학 점수는 깨봉시간의 function
# - 내가 변하면 상대방은 얼마나 변할까? (x -> y), 그걸 잘 표현해 주는 것이 '몇 배'
# 2. 종류?
# - 일차함수 : ax+b
#     - 3x에도 b=0이 숨어 있음
#     - $\frac{2x-3}{5} = \frac{2}{5}x - \frac{3}{5}$
#     - 일차함수는 평행이동만 생각하면 됨, b만큼 상하 이동(3이면 선인 전체 점들을 +3만큼 올리는 것임)
#     - y절편은 b이다

# %% [markdown]
# #### 무한대와 무한소
# - 무한대 : 끝없이 커지는 상태
# - 무한소 : 끝없이 작아지는 상태 -> 0에 근접, 그런데 0은 아님, 무한소의 0은 거의 없다, 거의 0이다임

# %% [markdown]
# ## 미분
# - 그냥 순간 기울기(변화량)라고 생각하라
# - 순간 기울기가 0이 되는 지점이 가장 중요하다 (최댓값이나 최솟값, 최적점과 연관이 되기 때문)
# - 가장 효율 좋은 것을 이야기하는 것이다. 가성비 (최댓값과 최솟값은 실제 다른 숫자일 수 있음 - 그냥 가장 비싼거 사면 된다. 비쌀 수록 좋은 제품이라 생각할 때) - 최대/최소/최적점
#
# - 두 점 간의 기울기, 두 점의 지나는 직선의 기울기 => 결국 접선의 기울기를 구하는 것
#     - 기울기 : 두 점을 연결한 진선 ($\frac{Y}{X}$)
#         - $\frac{y값의 증가량}{x값의 증가량}$ => (y인 너의 변화는 x인 나의 변화의 몇 배?)
#     - 접선의 기울기 : 한 점에서 접하는 직선 ($\frac{dY}{dX}$), 순간적인 변화율
# - x의 순간적인 변화율에 대하여 y의 순간적인 변화율을 구하는 것 (x의 변화율은 무한소만큼임)
# - 미분(잘게 쪼갬) -> 변화가 몇 배 -> 순간적인 변화가 몇 배 -> 순간변화율
# 최적화를 하기 위해서는 입력값이 변했을 때 함수의 출력값이 어떻게 달라지는지를 정량적으로 알아야 하며 이러한 과정이 미분이다.
#
# - 미분은 도함수를 구하는 것이다. 도함수는 순간기울기를 구해주는 함수이다
#
# 함수의 그래프상에 있는 한 점을 중심으로 그래프를 무한히 확대해 보면 그래프의 모양이 직선에 가까워지는데 이때의 기울기를 미분이라고 한다. 이 직선은 같은 점을 기준으로 그린 그래프의 접선과 같다.
# - x -> x의 0승은 1이다
# - 상수의 미분은 0, 변화가 없으니까, x의 0승이 숨어 있다
#
# 신경망에서 미분의 필요성 : https://gggggeun.tistory.com/120           https://gggggeun.tistory.com/121
#
# 미분 개념 : https://www.youtube.com/watch?v=kMZ3RJEaLE4
#
# #### 적분
# 1.의미
# - 잘게 부순 것을 쌓는다
#
# 2. 종류
# - 정적분 : 범위가 정해져 있으면
# - 부정적분 : 정해져 있지 않으면
# #### 지수법칙
# - 지수 : 수를 지시함, 즉 밑을 몇 번 곱해야 하는지 나타냄
# - 승수의 -는 음수라는 뜻이 아니라 역수라는 의미이다
#
# - 직선 보다는 사이클로이드 곡선이 더 공이 빨리 내려감 -> 제일 빠른 선 = 최솟값을 안다는 것 = 그것은 미적분을 안다는 것
# - 모든 움직임을 그래프 좌표 위에 나타냄
# - 움직이는 방향이 한 눈에 보이고, 고로 예측도 가능

# %% [markdown]
# - 결국은 컴퓨터다. 계산기, 사칙연산 등
# - 그 계산을 잘할 수 있도록 전처리 등 해주는 것이다.
# - feature vector, feature matrix이다. 숫자로 처리된 모든 데이터들(이미지든 텍스트든)
# - 모델에 따라 전처리 등의 유무, 방식 등이 다르다. 정해진다.
# - Feature engineering이 중요하다. 성능을 좌지우지한다. 즉, Feature-set은 모델의 눈이다.
#     - 띄어쓰기 단위? 글자 단위? 모음과 자음 단위? -> 숫자가 달리지고 -> 학습도 달라진다
#     - 데이터셋의 속성이나 특징들임 -> 선택, 추출, 전처리 -> 입력변수로
#
#
#
# 함수 이유
# - 모델이라는것이 함수니까 (인풋 -> 아웃풋)
# - 중간의 모델이 함수, 종류는 다양(머신러닝-결정트리?, 딥러닝)
# - 복잡해 보이지만, 사칙연산, 불린(조건?) 등으로 학습함 -> 그래서 숫자값만 넣을 수 있는 것임(인코딩)
# - 나오는 출력물, 즉 그 숫자에 대한 해석은 사람 몫이다
#
# 모델이 학습한다는 의미
# - 데이터를 주면서, 이 데이터처럼 동작해라고 하는 것
#     - 지도학습
#         - 입력값(대부분 벡터)과 출력값(스칼라, 벡터) 줌, 이렇게 입력했을 때 이런 출력이 나왔으면 좋겠어
#         - 모델이 입력값으로부터 결과값, 예측 값을 내면, 그것이 우리가 준 출력값(정답)과 비교함
#         - 학습 초기에는 엉망일 것임, 정답률 낮음
#         - 학습해 갈수록 더 잘 맞추기를 우리는 바란다
#         - 그러러면 비교해서, 그에 대한 영점 조정을 계속 해줌
#
#
# - 미분 이유
# - 모델이 학습할 때 그 과정에서 미분이 들어가기 때문임
# - 사람은 알지만, 컴퓨터가 알기는 어려움, 경사 하강법 등으로 우리가 학습률만 정해주면 그것에 따라 계속 기울기가 0이 될 때까지 조정해 감
# 그럼 모델이 어떻게 학습하나?
# - 학습데이터
# - "Learning rate"는 기계 학습 알고리즘에서 최적화 과정에서 사용되는 하이퍼파라미터 중 하나입니다. 학습 알고리즘이 모델의 가중치를 조정하기 위해 사용하는 오차 함수의 기울기를 계산한 후, 해당 기울기에 learning rate를 곱하여 새로운 가중치를 계산합니다. 이렇게 계산된 가중치는 모델의 오차 함수를 최소화하기 위한 최적의 가중치를 찾기 위해 반복적으로 조정됩니다.
#
# - 머신 러닝: 미분을 사용하여 머신 러닝 모델을 학습할 수 있습니다. 예를 들어, 미분을 사용하여 손실 함수의 기울기를 계산하고, 이를 사용하여 가중치를 업데이트하면서 모델을 학습할 수 있습니다.
#
# - 손실 함수(loss function)는 기계 학습에서 모델이 예측한 값과 실제 값 사이의 차이, 즉 오차를 정량화하는 함수입니다. 모델이 예측한 값이 실제 값과 비슷하다면 손실 함수는 작은 값을 반환하고, 예측 값이 실제 값과 차이가 크다면 큰 값을 반환합니다.
#
# 내적을 배우는 이유
# - 모델의 예측이 실제 값과 가장 가깝게 일치하는 상태가 됩니다.
# - 딥러닝해서 행렬 곱셈 연산을 내적으로 함 (입력데이터와 가중치를 곱함) -> 그 결과를 활성화 함수에 적용하여 다음 층으로 전달함

# %%
최대한 쉽게 이해하는게 좋다. 수학이라
1 개념이해하면 된다 (계산은 라이브러리가 다 해준다) - 지금 개념 이해하기 위해 연습하는 것이다

벡터 내적
벡터 - 크기와 방향(각도), 화살표 같음, 좌표(2,3)
내적 - 두 개의 벡터를 곱하는 연산으로, 두 벡터가 이루는 각도와 크기를 이용하여 값을 계산
유사도?
각도
코싸인 0이면 
코싸인 1이면 90도니까 유사도 없음, 0을 곱하니까 0 -> 유사도가 0

<벡터 놈> - 벡터 크기 계산하는 것 = 유클리드 놈
제곱해서 루트 다시 씌우는 것 (편차와 비슷함, 음수 없애려고, 그리고 오차 줄이려고)

행렬은 크게 스케일(부피, 크기)과 회전(방향)

주성분 분석 - 변수가 겹칠 때 주 성분 뽑아주는 것

행렬식은 - 이미지 분석과 주성분 분석에서 많이 쓰임

미분 - 다름, 차이(영어로), 결국 변화량을 계산하는 것임

적분 - 합치는 것(영어로), 전체를 보는 것, 부피를 보는 것

나는 10미터를 1초에 뛸 수 있음
1미터를 뛰는 데 0.1초가 걸림
레이스를 끝낼 때까지 10.0초가 걸림
나는 레이스에서 총 100미터를 뜀

순간 변화율이 속도임

2차 함수를 미분해서 기울기를 구한다 - 접선의 방정식

편미분
하나의 변수로 변하는 값이 정확함

역함수
입력과 출력을 반대로 바꾸는 함수

지수함수는 역함수와 연관이 있다

ReLU함수는 필터와 같다(걸러내고 싶은 것은 버리고, 아닌 것은 통과 시키고)

<로그함수>
곱하기를 더하기로 변환한다 (이해의 차원)
지수함수의 반대
스케일이 다른 숫자들을 비슷하게 맞춰줌 - 이걸 데이터에서는 가장 많이 씀
0부터 1사이의 작은 값을 확대시켜 보여준다 - 작은 값은 크게, 큰 값은 작게 보여준다 - 극단값을 좀 작게 보여준다

# %%
- 가중치를 계산하려면 미분할 수 있어야 한다. 순간 변화율 알 수 없으면 계산 불가능

- 도함수?를 적분하면(다 더해주면) 적분 구할 수 있음 (= 원래 함수로 되는 것)

- 미분과 적분, 지수와 로그

- 미분에서 적분한다는 의미

- 미분을 해야 가중치를 줄 수 있다?는 의미
# Out:
#   File "C:\Users\h\AppData\Local\Temp\ipykernel_5840\2449368086.py", line 1
#     - 가중차를 계산하려면 미분할 수 있어야 한다. 순간 변화율 알 수 없으면 계산 불가능
#            ^
# SyntaxError: invalid syntax

# %%
def f(x):
    return x**3 - 3 * x**2 + x

mpl.rc('font', family='Malgun Gothic')
mpl.rcParams['axes.unicode_minus'] = False    # 마이너스 단위 처리

x = np.linspace(-1, 3, 400)
y = f(x)
plt.figure(figsize=(10,6))
plt.plot(x, y)
plt.plot(0, 0, 'ro')
plt.plot(x, x, 'r:')
plt.plot(1, -1, 'go')
plt.plot(x, (3*1**2-6*1+1)*(x-1)-1, 'g--')

plt.xlim(-3.5, 5.5)
plt.ylim(-4, 2)
plt.xticks(np.arange(-3, 6))
plt.yticks(np.arange(-4, 2))

plt.annotate('', xy=(1, 0), xytext=(0, 0), arrowprops=dict(facecolor='gray'))
plt.annotate('', xy=(1, 1), xytext=(1, 0), arrowprops=dict(facecolor='gray'))

plt.annotate('', xy=(2, -1), xytext=(1, -1), arrowprops=dict(facecolor='gray'))
plt.annotate('', xy=(2, -3), xytext=(2, -1), arrowprops=dict(facecolor='gray'))

plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("함수의 기울기")
plt.show()

# %%
# delta - 입력 변수의 작은 변화를 의미함
# 값이 작을수록 f(x)의 변화량이 작아져서 정확한 최솟값을 찾기가 더 쉬워짐

def f(x):
    return(x**3 - x)

plt.figure(figsize=(15, 5))
delta = [2.0, 0.2, 0.01]

x = np.linspace(0.5-delta[0], 0.5+delta[0], 200)
y = f(x)

plt.subplot(131)

plt.ylim(-3.0/8.0-delta[0], -3.0/8.0+delta[0])
plt.xlim(0.5-delta[0], 0.5+delta[0])
plt.plot(x, y, 'b-', lw=1, c='k')
plt.scatter([0.5], [-3.0/8.0])
plt.xlabel('x',fontsize=14)
plt.ylabel('y',fontsize=14)
plt.grid()
plt.title('delta = %.4f' % delta[0], fontsize=14)


x = np.linspace(0.5-delta[1], 0.5+delta[1], 200)
y = f(x)

plt.subplot(132)

plt.ylim(-3.0/8.0-delta[1], -3.0/8.0+delta[1])
plt.xlim(0.5-delta[1], 0.5+delta[1])
plt.plot(x, y, 'b-', lw=1, c='k')
plt.scatter([0.5], [-3.0/8.0])
plt.xlabel('x',fontsize=14)
plt.ylabel('y',fontsize=14)
plt.grid()
plt.title('delta = %.4f' % delta[1], fontsize=14)

x = np.linspace(0.5-delta[2], 0.5+delta[2], 200)
y = f(x)

plt.subplot(133)

plt.ylim(-3.0/8.0-delta[2], -3.0/8.0+delta[2])
plt.xlim(0.5-delta[2], 0.5+delta[2])
plt.plot(x, y, 'b-', lw=1, c='k')
plt.scatter([0.5], [-3.0/8.0])
plt.xlabel('x',fontsize=14)
plt.ylabel('y',fontsize=14)
plt.grid()
plt.title('delta = %.4f' % delta[2], fontsize=14)

plt.show()
# Out:
# C:\Users\h\AppData\Local\Temp\ipykernel_5840\2469641370.py:14: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(x, y, 'b-', lw=1, c='k')
# C:\Users\h\AppData\Local\Temp\ipykernel_5840\2469641370.py:29: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(x, y, 'b-', lw=1, c='k')
# C:\Users\h\AppData\Local\Temp\ipykernel_5840\2469641370.py:43: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(x, y, 'b-', lw=1, c='k')

# %% [markdown]
# ### 접선의 방정식
#
# - 함수 f(x)에서 x의 값을 dx만큼 변화시켰을 때 f(x)의 변화량 (f(x+dx)-f(x))는 f'(x)dx와 같다.
# - 미분 : y=f(x)라는 그래프상의 점(a,f(a))가 있을 때 그 점에서 그은 접선의 기울기는 f'(a)이며 a에서의 순간 변화율을 의미
# - 적분 : 도함수 f'(x)의 하방 면적은 원 함수 f(x)의 y의 값이다. ex) f(x) = $x^2$

# %%
def f(x):
    return(x**2)
def g(x):
    return(2*x - 1)    # 접선이 -1을 지나기에 -1 넣어줌

x = np.linspace(-3,3,100)
fig = plt.figure(figsize=(5,5))
plt.scatter([1],[1],c='k')
plt.plot(x, f(x), 'b-', lw=1, c='k')
plt.plot(x, g(x), 'b-', lw=1, c='b')
plt.plot([x.min(), x.max()], [0,0], lw=2, c='k')
plt.plot([0,0], [g(x).min(), f(x).max()], lw=2, c='k')
plt.ylim(-1,3)
plt.xlim(-2,2)
plt.grid(lw=1)

plt.show()
# Out:
# C:\Users\h\AppData\Local\Temp\ipykernel_5840\3993043779.py:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(x, f(x), 'b-', lw=1, c='k')
# C:\Users\h\AppData\Local\Temp\ipykernel_5840\3993043779.py:10: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(x, g(x), 'b-', lw=1, c='b')

# %%
# 기울기
# 도함수를 구해주는 것 - 2x가 되므로 1을 넣었을 때 2임
# 도함수는 어떤 함수의 미분값, 즉 기울기를 나타내는 함수

# scipy - 과학, 공학, 기술 분야에서 수치 계산을 위한 파이썬 패키지
# scipy.misc - 이미지 처리와 관련된 여러 유틸리티 함수를 제공하는 모듈 중 하나
# derivative - 수치 미분(numerical differentiation)을 계산하는 함수
    # f: 미분할 함수
    # x0: 미분을 계산할 위치
    # dx 미분의 미소 변화량, 기본값은 1e-6, 값이 작을수록 정확도가 높아짐

from scipy.misc import derivative

print(derivative(f,1,dx=1e-6))
print(derivative(f,2))    # dx=1e-6 기본값이라 생략한 것임
# Out:
# 2.000000000002
# 4.0

# %% [markdown]
# # 편미분
# - 독립 변수가 두 개 이상인 함수
# - 다변수 함수에서 한 변수를 제외한 나머지 변수들의 값을 고정하고, 해당 변수의 변화에 따른 함수값의 변화량을 나타내는 개념
# - 증가 함수 : 독립변수의 변화 방향과 종속변수의 변화 방향이 일치하는 함수
# - 감소 함수 : 어떤 사람의 몸무게는 그 사람의 운동량의 감소 함수다
# - 식사량을 줄이면 몸무게가 얼마나 주는지 알고 싶으면, 일단 운동량은 고정되어 있어야 한다
# - 그렇기에 상수취급을 하는 것이다.

# %%
# 파이썬에서 수학적인 식(expression), 방정식(equation), 함수(function) 등을 다룰 수 있도록 합니다.
# 이를 통해 파이썬 코드를 이용하여 수학적인 계산이 가능해지며, 많은 분야에서 활용됩니다.
# SymPy의 기능으로는, 미분과 적분, 방정식 풀이, 대수 연산, 행렬 연산, 그래프 그리기 등이 있으며,
# NumPy, SciPy 등과 함께 사용될 수 있습니다.

# Jupyter 노트북에서 수학식의 LaTex 표현을 위해 필요함

import sympy
sympy.init_printing(use_latex='mathjax')

x = sympy.symbols('x')
x
# Out:
# x

# %%
# 함수 f(x)를 x에 대해 미분한 결과를 반환하는 역할

sympy.diff(x**2, x)
# Out:
# 2⋅x

# %%
# 난감함 뭐를 미분해야 할지?

x, y = sympy.symbols('x y')
f = x ** 2 + 4 * x * y + 4 * y **2
f
# Out:
#  2              2
# x  + 4⋅x⋅y + 4⋅y

# %%
# diff() 함수로 미분, 변수, 상수를 구분하기 위하여 편미분인 것처럼 입력 변수 지정
# x에 대한 미분의 결과


sympy.diff(f, x)    # x를 기준으로 할 때
# Out:
# 2⋅x + 4⋅y

# %%
sympy.diff(f,y)
# Out:
# 4⋅x + 8⋅y

# %% [markdown]
# ## 적분
# - 적분은 미분과 반대되는 개념. 부정적분과 정적분이 있다.
#  - 부정적분은 정확하게 미분과 반대되는 개념. 즉 반 미분이다. 어떤 함수를 미분하여 나온 결과인 도함수라고 가정하고 이 도함수 f(x)에 대한 미분되기 전의 원래의 함수를 찾는 과정 또는 그 결과를 의미
#  - 정적분은 독립변수 x가 어떤 구간 [a,b] 사이일 때 그 구간에서 함수 f(x)의 값과 수평선(x축)이 이루는 면적을 구하는 행위 혹은 그 값을 의미
#
# 적분의 개념 : https://www.youtube.com/watch?v=kV2j3S5qBm4
#
# 미분과 적분의 관계 : https://www.youtube.com/watch?v=xAAAvj7bmKQ

# %%
def f(x) :
    return x**2 + 1
xx = np.linspace(-4.0, 4.0, 200)
yy = f(xx)

plt.figure(figsize=(6,6))
plt.xlim(-2,2)
plt.ylim(-1,4)
plt.plot(xx, yy)
plt.plot([-2,2],[0,0],c='k',lw=1)
plt.plot([0,0],[-1,4],c='k',lw=1)
plt.plot([0,0],[0,f(0)],c='b')
plt.plot([1,1],[0,f(1)],c='b')
plt.plot([1.5,1.5],[0,f(1.5)],c='b')
plt.plot([1,1.5],[f(1),f(1)],c='b')
plt.tick_params(labelbottom=False, labelleft=False, labelright=False, labeltop=False)
plt.tick_params(color='white')
plt.show()

# %%
x,y = sympy.symbols('x y')
f = 2 * x + y
f
# Out:
# 2*x + y

# %%
# 인테그랄

sympy.integrate(f,x)
# Out:
# x**2 + x*y

# %%
from matplotlib.patches import Polygon


def f(x):
    return x ** 3 - 3 * x ** 2 + x + 6


a, b = 0, 2
x = np.linspace(a - 0.5, b + 0.5, 50)
y = f(x)

ax = plt.subplot(111)
plt.title("정적분의 예")
plt.plot(x, y, 'r', linewidth=2)
plt.ylim(bottom=0)
ix = np.linspace(a, b)
iy = f(ix)
verts = [(a, 0)] + list(zip(ix, iy)) + [(b, 0)]
poly = Polygon(verts, facecolor='0.9', edgecolor='0.5')
ax.add_patch(poly)
plt.text(0.5 * (a + b), 0.2 * (f(a) + f(b)), r"$\int_a^b f(x)dx$",
         horizontalalignment='center', fontsize=20)
plt.figtext(0.9, 0.05, '$x$')
plt.figtext(0.1, 0.9, '$y$')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')
ax.set_xticks((a, b))
ax.set_xticklabels(('$a$', '$b$'))
ax.set_yticks([])
ax.set_xlim(-2, 4)
ax.set_ylim(0, 8)
plt.show()

# %%
# 위 그래프의 함수임

f = x**3 - 3*x**2 + x + 6
f
# Out:
# x**3 - 3*x**2 + x + 6

# %%
# 부정적분 - 함수 자체를 구하는 것

F = sympy.integrate(f)
F
# Out:
# x**4/4 - x**3 + x**2/2 + 6*x

# %%
# 정적분
# 심볼릭 적분 - 정확한 적분값

sympy.integrate(f,(x,0,2))
# Out:
# 10

# %%
# 수치적분 - 근사적인 적분값
import scipy as sp

def f(x):
    return x**3 - 3*x**2 + x +6

sp.integrate.quad(f,0,2)
# Out:
# (10.0, 1.1102230246251565e-13)

# %%
from scipy import integrate

def f(x):
    return x**3 - 3*x**2 + x +6

result, error = integrate.quad(f, 0, 1)
print(result)  # 출력: 1.0
# Out:
# 5.75
