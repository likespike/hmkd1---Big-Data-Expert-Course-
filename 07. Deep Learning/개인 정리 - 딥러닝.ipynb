# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # 딥러닝의 정의
# - 빡대가리도 가능한 머신러닝 기법;;
# - 머신러닝 - 컴퓨터야 이것좀 배워봐 + 사람의 가이드 일정부분 필요
# - 딥러닝 - 컴퓨터야 니가 다 알아서 해(가이드 불필요)
# - AlphaGo - 수백 만개의 트라이얼 앤 에러를 통해서 알아서 바둑 두는 법 알고리즘을 터득함
# - 바둑 몰라도, 유방암에 대해 잘 몰라도, 해당 AI만들 수 있음
#
# # 딥러닝 제품들
# - 구글 번역
# - TTS 엔진
# - 코드 짜는 AI (html, 파이썬 등)
# - Sketch2Code
# - Adobe에서 보정 들어간 사진 판독
#
# # 딥러닝이 잘하는 분야
# - 이미지 분류 - 자율 주행 등 (1초에 30번, 60번 사진을 찍음 -> 차, 사람 등 판단 -> 행동 결정)
# - 순서가 있는 데이터를 추론하거나 분석 sequence data (한글 sequence를 영어 sequence로 만들어 냄)

# %% [markdown]
# 가중치를 주어 선형 변환 -> 활성화 함수에 넣어줌(비선형 작업)
#
# 결국 다 연산임
