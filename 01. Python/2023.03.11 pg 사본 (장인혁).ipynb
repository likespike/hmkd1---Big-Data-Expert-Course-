# %%
### 이벤트에서 정수 101이상 입력시 '두 구 두 구 두 구 둥' 실행 안되게 수정
### price 1 2 3 변수 위치 이동
### 평점 코드 -> 좀 더 간결화

## 주문
import time
import datetime
import random

def checkorder() :
    
    print('\n=--------------영 수 증---------------=')
    
    if (menu_l['제육볶음'] > 0) :
        print('\n제육볶음 :  %d개' % menu_l['제육볶음'])
    
    if (menu_l['잔치국수'] > 0) :
        print('잔치국수 :  %d개' % menu_l['잔치국수'])
    
    if (menu_l['비빔밥'] > 0) :
        print('비빔밥 :    %d개' % menu_l['비빔밥'])
        
    if (menu_l['짜장면'] > 0) :
        print('\n짜장면 :    %d개' % menu_l['짜장면'])
    
    if (menu_l['짬뽕'] > 0) :
        print('짬뽕 :      %d개' % menu_l['짬뽕'])
    
    if (menu_l['탕수육'] > 0) :
        print('탕수육 :    %d개' % menu_l['탕수육'])
        
    if (menu_l['우동'] > 0) :
        print('\n우동 :      %d개' % menu_l['우동'])
        
    if (menu_l['돈까스'] > 0) :
        print('돈까스 :    %d개' % menu_l['돈까스'])
        
    if (menu_l['소바'] > 0) :
        print('소바 :      %d개' % menu_l['소바'])
    
    print('')

        
menu_l = {'제육볶음' : 0, '잔치국수' : 0, '비빔밥' : 0, '짜장면' : 0, '짬뽕' : 0, '탕수육' : 0, '우동' : 0, '돈까스' : 0, '소바' : 0}
order1 = order2 = order3 = order4 = order5 = order6 = order7 = order8 = order9 = 0
orderc1 = orderc2 = orderc3 = orderc4 = orderc5 = orderc6 = orderc7 = orderc8 = orderc9 = 0
discnt = 0

l = list(range(1,101))

now = datetime.datetime.now()
now_s = now.strftime('%Y-%m-%d %H:%M')
twenty = now + datetime.timedelta(minutes = 20)
tw = twenty.strftime('%Y-%m-%d %H:%M')

com = random.choice(l)

eff = ['    두 ', '구 ', '두 ', '구 ', '두 ', '구 ','두 ', '구 ', '둥! ']

# list2 = ['★','★', '★', '★', '★']
b_star = '★'
w_star = '☆'
list = ['매우 불만족', '불만족', '약간 불만족', '보통', '만족', '매우 만족']

while True :
    start = input('음식을 주문 하시겠습니까? (y / n) : ')
   

    if start == 'y' :
        
        while True :
            
            try :
                print("\n=-----------------선택-----------------=\n")
                sel_t = int(input('1번: 한식, 2번: 중식, 3번: 일식 중 하나를 골라주세요. : '))
       
            except :
                print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                continue
        
            else:
            
                if sel_t == 1 :
                    print('\n[한식을 선택하셨습니다.]\n')
                    print("=-----------------메뉴-----------------=")
                    print('1번: 제육볶음: 9000원 \n2번: 잔치국수: 8000원 \n3번: 비빔밥:  10000원')
                    print('========================================')

                    while True :
                    
                        try : 
                            sel_m = int(input('\n메뉴 번호를 선택해주세요. : '))
                            print('\n=--------------------------------------=')
                                
                        except :
                            print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                            continue
                            # 메뉴 입력
                       
                        else :

                            if sel_m == 1 :
                                print('\n[제육볶음을 선택하셨습니다.]\n')
                                
                                while True:
        
                                    try:
                                        order = int(input('몇 개를 주문하시겠습니까? : '))
                                        print()
        
                                    except :
                                        print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                        continue
        
                                    else:
                                        order1 += order
                                        menu_l['제육볶음'] += order
                                        break

                            elif sel_m == 2 :
                                print('\n[잔치국수를 선택하셨습니다.]\n')
        
                                while True:
        
                                    try:
                                        order = int(input('몇 개를 주문하시겠습니까? : '))
                                        print()
        
                                    except :
                                        print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                        continue
        
                                    else:
                                        order2 += order
                                        menu_l['잔치국수'] += order
                                        break

        
                            elif sel_m == 3 :
                                print('\n[비빔밥를 선택하셨습니다.]\n')

                                                
                                while True:
        
                                    try:
                                        order = int(input('몇 개를 주문하시겠습니까? : '))
                                        print()
        
                                    except :
                                        print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                        continue
        
                                    else:
                                        order3 += order
                                        menu_l['비빔밥'] += order
                                        break
                            
                            else :
                                print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                continue
                                # 음식 선택1
                        break
                           
                        
                elif sel_t == 2 :
                    print('\n[중식을 선택하셨습니다.]\n')
                    print("=-----------------메뉴-----------------=")
                    print('1번: 짜장면:   6000원 \n2번: 짬뽕:     6500원 \n3번: 탕수육:  14000원')
                    print('========================================')

                    while True :
                    
                        try : 
                            sel_m = int(input('\n메뉴 번호를 선택해주세요. : '))
                            print('\n=--------------------------------------=')
   
                        except :
                            print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                            continue
                            # 메뉴 입력
                        
                        else :
                            
                            if sel_m == 1 :
                                print('\n[짜장면을 선택하셨습니다.]\n')
        
                                while True:
        
                                    try:
                                        order = int(input('몇 개를 주문하시겠습니까? : '))
                                        print()
        
                                    except :
                                        print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                        continue
        
                                    else:
                                        order4 += order
                                        menu_l['짜장면'] += order
                                        break
                            
                            elif sel_m == 2 :
                                print('\n[짬뽕을 선택하셨습니다.]\n')
        
                                while True:
        
                                    try:
                                        order = int(input('몇 개를 주문하시겠습니까? : '))
                                        print()
        
                                    except :
                                        print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                        continue
        
                                    else:
                                        order5 += order
                                        menu_l['짬뽕'] += order
                                        break

        
                            elif sel_m == 3 :
                                print('\n[탕수육을 선택하셨습니다.]\n')
  
                                                
                                while True:
        
                                    try:
                                        order = int(input('몇 개를 주문하시겠습니까? : '))
                                        print()
        
                                    except :
                                        print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                        continue
        
                                    else:
                                        order6 += order
                                        menu_l['탕수육'] += order
                                        break
                
                            else :
                                print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                continue
                                # 음식 선택2
                            break
                         
                        
                elif sel_t == 3 :
                    print('\n[일식을 선택하셨습니다.]\n')
                    print("=-----------------메뉴-----------------=")
                    print('1번: 우동:       5000원 \n2번: 돈까스:     8500원 \n3번: 소바:       7000원')
                    print('========================================')

                    while True :
                    
                        try : 
                            sel_m = int(input('\n메뉴 번호를 선택해주세요. : '))
                            print('\n=--------------------------------------=')
   
                        except :
                            print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                            continue
                            # 메뉴 입력
                        
                        else :
                            
                            if sel_m == 1 :
                                print('\n[우동을 선택하셨습니다.]\n')
         
                                while True:
        
                                    try:
                                        order = int(input('몇 개를 주문하시겠습니까? : '))
                                        print()
        
                                    except :
                                        print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                        continue
        
                                    else:
                                        order7 += order
                                        menu_l['우동'] += order
                                        break

                            elif sel_m == 2 :
                                print('\n[돈까스를 선택하셨습니다.]\n')
        
                                while True:
        
                                    try:
                                        order = int(input('몇 개를 주문하시겠습니까? : '))
                                        print()
        
                                    except :
                                        print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                        continue
        
                                    else:
                                        order8 += order
                                        menu_l['돈까스'] += order
                                        break

        
                            elif sel_m == 3 :
                                print('\n[소바를 선택하셨습니다.]\n')

                                                
                                while True:
        
                                    try:
                                        order = int(input('몇 개를 주문하시겠습니까? : '))
                                        print()
        
                                    except :
                                        print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                        continue
        
                                    else:
                                        order9 += order
                                        menu_l['소바'] += order
                                        break
                
                            else :
                                print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                continue
                                # 음식 선택3  
                            
                            break                            
                
                else : 
                    print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                    continue                    
                
                checkorder()
                print('========================================\n')
            
            while True :
                keeporder = input('추가 주문을 하시겠습니까? (y / n) : ')
                print('')
        
                if keeporder == 'y' or keeporder == 'n' :
                    break
        
                else :
                    print('\n잘못 입력하셨습니다. y / n 중 하나를 다시 입력해주세요.\n')
            
            if keeporder == 'y' :
                continue
                # 주문 재 추가
             
            else :
                break
                
            break    
            # 요리 타입 선택
    
    elif start == 'n' :
        print('\n        [주문을 종료합니다.]')
        print('========================================\n')
        break
    
    else :
        print('\n잘못 입력하셨습니다. y / n 중 하나를 입력해 주세요.\n')
        continue
        #주문 시작
    
    
    while True :
        cancel = input('취소할 메뉴가 있으십니까? (y / n) : ')
        print('')
                        
        if cancel == 'y' :
            
            while True :                
                
                try :
                    print("=-----------------메뉴-----------------=")
                    print('\n[1번 : 제육볶음] [2번 : 잔치국수] [3번 : 비빔밥]\n\n[4번 : 짜장면]   [5번 : 짬뽕]     [6번 : 탕수육]\n\n[7번 : 우동]     [8번 : 돈까스]   [9번 : 소바]')
                    print("=--------------------------------------=\n")
                    cancel1 = int(input('취소할 음식의 번호를 입력해주세요 : '))
                    print('\n========================================\n')
                            
                except :
                    print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                    continue
                        
                else :
                            
                    if cancel1 == 1 :
                        print('\n[제육볶음을 선택하셨습니다.]\n')
                        print('[현재 주문하신 개수 %d개]' %(order1))        
                        
                        while True:
        
                            try:
                                order = int(input('\n몇 개를 취소하시겠습니까? : '))
                                print('\n========================================')
        
                            except :
                                print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                continue
        
                            else:
                                
                                if (order1 - order) >= 0 :
                            
                                    orderc1 += order
                                    menu_l['제육볶음'] -= orderc1
                                    break
                                
                                else :
                                    print('\n현재 주문하셨던 개수보다 많은 숫자입니다. 다시 입력해주세요.\n')
                                    continue
                                
                    elif cancel1 == 2 :
                        print('\n[잔치국수를 선택하셨습니다.]\n')
                        print('[현재 주문하신 개수 %d개]' %(order2))        
                        
                        while True:
        
                            try:
                                order = int(input('\n몇 개를 취소하시겠습니까? : '))
                                print('\n========================================')
        
                            except :
                                print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                continue
        
                            else:
                
                                if (order2 - order) >= 0 :
                            
                                    orderc2 += order
                                    menu_l['잔치국수'] -= orderc2
                                    break
                                
                                else :
                                    print('\n현재 주문하셨던 개수보다 많은 숫자입니다. 다시 입력해주세요.\n')
                                    continue

                    elif cancel1 == 3 :
                        print('\n[비빔밥을 선택하셨습니다.]\n')
                        print('[현재 주문하신 개수 %d개]' %(order3))        
                        
                        while True:
        
                            try:
                                order = int(input('\n몇 개를 취소하시겠습니까? : '))
                                print('\n========================================')
        
                            except :
                                print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                continue
        
                            else:
                                
                                if (order3 - order) >= 0 :
                            
                                    orderc3 += order
                                    menu_l['비빔밥'] -= orderc3
                                    break
                                
                                else :
                                    print('\n현재 주문하셨던 개수보다 많은 숫자입니다. 다시 입력해주세요.\n')
                                    continue
                                    
                    elif cancel1 == 4 :
                        print('\n[짜장면을 선택하셨습니다.]\n')
                        print('[현재 주문하신 개수 %d개]' %(order4))        
                        
                        while True:
        
                            try:
                                order = int(input('\n몇 개를 취소하시겠습니까? : '))
                                print('\n========================================')
        
                            except :
                                print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                continue
        
                            else:
                                
                                if (order4 - order) >= 0 :
                            
                                    orderc4 += order
                                    menu_l['짜장면'] -= orderc4
                                    break
                                
                                else :
                                    print('\n현재 주문하셨던 개수보다 많은 숫자입니다. 다시 입력해주세요.\n')
                                    continue
                            
                    elif cancel1 == 5 :
                        print('\n[짬뽕을 선택하셨습니다.]\n')
                        print('[현재 주문하신 개수 %d개]' %(order5))        
                        
                        while True:
        
                            try:
                                order = int(input('\n몇 개를 취소하시겠습니까? : '))
                                print('\n========================================')
        
                            except :
                                print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                continue
        
                            else:
                
                                if (order5 - order) >= 0 :
                            
                                    orderc5 += order
                                    menu_l['짬뽕'] -= orderc5
                                    break
                                
                                else :
                                    print('\n현재 주문하셨던 개수보다 많은 숫자입니다. 다시 입력해주세요\n')
                                    continue

                    elif cancel1 == 6 :
                        print('\n[탕수육을 선택하셨습니다.]\n')
                        print('[현재 주문하신 개수 %d개]' %(order6))        
                        
                        while True:
        
                            try:
                                order = int(input('\n몇 개를 취소하시겠습니까? : '))
                                print('\n========================================')
        
                            except :
                                print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                continue
        
                            else:
                                
                                if (order6 - order) >= 0 :
                            
                                    orderc6 += order
                                    menu_l['탕수육'] -= orderc6
                                    break
                                
                                else :
                                    print('\n현재 주문하셨던 개수보다 많은 숫자입니다. 다시 입력해주세요.\n')
                                    continue
                            
                    elif cancel1 == 7 :
                        print('\n[우동을 선택하셨습니다.]\n')
                        print('[현재 주문하신 개수 %d개]' %(order7))        
                        
                        while True:
        
                            try:
                                order = int(input('\n몇 개를 취소하시겠습니까? : '))
                                print('\n========================================')
        
                            except :
                                print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                continue
        
                            else :
                
                                if (order7 - order) >= 0 :
                            
                                    orderc7 += order
                                    menu_l['우동'] -= orderc7
                                    break
                                
                                else :
                                    print('\n현재 주문하셨던 개수보다 많은 숫자입니다. 다시 입력해주세요.\n')
                                    continue
                                    
                    elif cancel1 == 8 :
                        print('\n[돈까스를 선택하셨습니다.]\n')
                        print('[현재 주문하신 개수 %d개]' %(order8))        
                        
                        while True:
        
                            try:
                                order = int(input('\n몇 개를 취소하시겠습니까? : '))
                                print('\n========================================')
        
                            except :
                                print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                continue
        
                            else:
                
                                if (order8 - order) >= 0 :
                            
                                    orderc8 += order
                                    menu_l['돈까스'] -= 8
                                    break
                                
                                else :
                                    print('\n현재 주문하셨던 개수보다 많은 숫자입니다. 다시 입력해주세요.\n')
                                    continue
                            
                    elif cancel1 == 9 :
                        print('\n[소바를 선택하셨습니다.]\n')
                        print('[현재 주문하신 개수 %d개]' %(order9))        
                        
                        while True:
        
                            try:
                                order = int(input('\n몇 개를 취소하시겠습니까? : '))
                                print('\n========================================')
        
                            except :
                                print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                                continue
        
                            else:
                
                                if (order9 - order) >= 0 :
                            
                                    orderc9 += order
                                    menu_l['소바'] -= orderc9
                                    break
                                
                                else :
                                    print('\n현재 주문하셨던 개수보다 많은 숫자입니다. 다시 입력해주세요.\n')
                                    continue
                            
                    else :
                        print('\n잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
                        continue
                        
                break
    
        elif cancel == 'n' :
            break
             
        else :
            print('\n잘못 입력하셨습니다. y / n 중 하나를 다시 입력해주세요.\n')
            continue
        
        checkorder()
        print('========================================')
        #메뉴 취소
    
    if ((order1 - orderc1) == 0) & ((order2 - orderc2) == 0) & ((order3 - orderc3) == 0) & ((order4 - orderc4) == 0) & ((order5 - orderc5) == 0) & ((order6 - orderc6) == 0) & ((order7 - orderc7) == 0) & ((order8 - orderc8) == 0) & ((order9 - orderc9) == 0) :
        print('========================================')
        print('\n      [주문 내역이 없습니다.]')
        print('\n      [처음으로 되돌아갑니다.]')
        print('\n========================================')
        continue
        
    else :
            
        while True :
            take = input('포장 예약 하시겠습니까? (y / n) : ')
            print('')
        
            if take == 'y' or take == 'n' :
                break
                 
            else :
                print('\n잘못 입력하셨습니다. y / n 중 하나를 다시 입력해주세요.\n')
                continue
        
        if take == 'y' :
            print('========================================')
            print('\n포장 예약시 20분 후에 찾아오시면 됩니다.\n')
            print(f'현재 시간은 %s 입니다.\n' %(now_s))
            print(f'20분 후 시각은 %s 입니다.\n' %(tw))
            # 포장 예약 

            
        print('☆======================================☆')
        print('''\n깜짝 이벤트를 진행중입니다! 
1 부터 100 중 숫자를 하나 선택하셔서 
랜덤으로 지정되는 숫자를 맞추신 손님께는 
현재 주문한 음식값에서 5000원 할인해드립니다!\n\n''')
        print('☆======================================☆\n')
    
        while True :
        
            try : 
                player = int(input('1 부터 100사이의 숫자를 입력해 주세요. : '))
                print('')
    
            except :
                print('\n잘못 입력하셨습니다. 1 부터 100사이의 숫자를 입력해 주세요.\n')
                continue
    
            else :
            
#                 for i in eff :
#                     print(i, end='')
                    
#                     time.sleep(0.5)
                    
                if player == com :
                    for i in eff :
                        print(i, end ='')
                        
                        time.sleep(0.5)

                    print('\n\n   [★당첨번호는  %d번 입니다!★]\n' %(com))
                    print('\n★축하드립니다! 지금 주문하신 금액에서 5000원을 할인 받으실 수 있습니다!★\n')
                    
                    discnt += 5000
                    total = price1 + price2 + price3
                    
                    print('현재 주문하신 금액은 %d원 입니다.' %(total))
            
                elif player > 100 :
                    print('\n잘못 입력하셨습니다. 1 부터 100사이의 숫자를 입력해 주세요.\n')
                    continue
                
                else :
                    for i in eff :
                        print(i, end='')
                        
                        time.sleep(0.5)

                    print('\n\n   [★당첨번호는  %d번 입니다!★]\n' %(com))
                    print('\n아쉽게도 다음 기회를 노려보셔야겠네요.\n')
                    print('☆======================================☆')
    
            break
            # 이벤트
        

        checkorder()
        # 영수증

        price1 = (9000*(order1-orderc1))+(8000*(order2-orderc2))+(10000*(order3-orderc3))
        price2 = (6000*(order4-orderc4))+(6500*(order5-orderc5))+(14000*(order6-orderc6))
        price3 = (5000*(order7-orderc7))+(8500*(order8-orderc8))+(7000*(order9-orderc9))
        
        
        total_e = price1 + price2 + price3 - discnt

        print('\n총액 : %d원 입니다.' %(total_e))
        
        # 총액

    while True :
        
        try :
            print('\n=--------------만족도 조사--------------=')
            print('\n0개 = 매우 불만족 \n1개 = 불만족 \n2개 = 약간 불만족 \n3개 = 보통 \n4개 = 만족 \n5개 = 매우 만족')    
            print('\n=---------------------------------------=')        

            n = int(input('\n서비스가 마음에 드셨다면 만족하신 만큼 별의 개수로 평가해주세요. : '))
            print('')

        except :
            print('\n잘못 입력하셨습니다.1 에서 5 중 하나의 숫자를 입력해주세요.')
            continue

        else :
            
            
            for i in range(n):
                print(b_star, end=" ")
            for i in range(5-n):
                print(w_star, end=" ")
            print(f'\n\n[{list[i]}]')
            

            if n == 0 :

                for i in list2 :
                    list2.insert(0, '☆')
                    list2.pop()

                    print(list2[n], end = ' ')
                print('\n\n[매우 불만족]')
                break

            elif n == 1 :        

                for i in list2 :
                    list2.insert(0, '☆')
                    list2.pop()

                    print(list2[n], end = ' ')
                print('\n\n[불만족]')
                break

            elif n == 2 :        

                for i in list2 :
                    list2.insert(0, '☆')
                    list2.pop()


                    print(list2[n], end = ' ')
                print('\n\n[약간 불만족]')
                break

            elif n == 3 :        

                for i in list2 :
                    list2.insert(0, '☆')
                    list2.pop()

                    print(list2[n], end = ' ')
                print('\n\n[보통]')
                break

            elif n == 4 :        

                for i in list2 :
                    list2.insert(0, '☆')
                    list2.pop()

                    print(list2[n], end = ' ')
                print('\n\n[만족]')
                break

            elif n == 5 :        

                for i in list2 :
                    print(list2[0], end = ' ')
                print('\n\n[매우 만족]')
                break

            else :
                print('\n잘못 입력하셨습니다.1 에서 5 중 하나의 숫자를 입력해주세요.')
                continue

    print('\n\n저희 서비스를 이용해 주셔서 감사합니다.')
    print('\n=---------------------------------------=') 
    # 평가
    
    break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4144\596019500.py in <module>
#      47 discnt = 0
#      48
# ---> 49 l = list(range(1,101))
#      50
#      51 now = datetime.datetime.now()
#
# TypeError: 'list' object is not callable

# %%
### b_star = '★'
w_star = '☆'
list = ['매우 불만족', '불만족', '약간 불만족', '보통', '만족', '매우 만족']


n = int(input("별 몇 개? "))

for i in range(n):
    print(b_star, end=" ")
for i in range(5-n):
    print(w_star, end=" ")
print(f'\n\n[{list[i]}]')



# print(list2[n], end = ' ')
# print('\n\n[보통]')
# Out:
# 별 몇 개? 5
# ★ ★ ★ ★ ★
#
# [만족]

# %%
def menu_cnt():
    while True:
        
        try:
            order = int(input('몇 개를 주문하시겠습니까? : '))
            print()
        
        except :
            print('잘못 입력하셨습니다. 번호에 맞게 다시 입력해주세요.\n')
            continue
        
        else:
            order1 += order

# %%
list1 = ['☆', '☆', '☆', '☆', '☆']
print(list1)

list1.insert(0, '★')
list1.pop()
print(list1)

list1.insert(1, '★')
list1.pop()
print(list1)

list1.insert(2, '★')
list1.pop()
print(list1)

list1.insert(3, '★')
list1.pop()
print(list1)

list1.insert(4, '★')
list1.pop()
print(list1)

for i in list1 :
    print(i, end = ' ')
# Out:
# ['☆', '☆', '☆', '☆', '☆']
# ['★', '☆', '☆', '☆', '☆']
# ['★', '★', '☆', '☆', '☆']
# ['★', '★', '★', '☆', '☆']
# ['★', '★', '★', '★', '☆']
# ['★', '★', '★', '★', '★']
# ★ ★ ★ ★ ★

# %%
list2 = ['★','★', '★', '★', '★']

print('========================================')  
print('\n0개 = 매우 불만족 \n1개 = 불만족 \n2개 = 약간 불만족 \n3개 = 보통 \n4개 = 만족 \n5개 = 매우 만족')    
print('\n=---------------------------------------=')

try :
    n = int(input('\n서비스가 마음에 드셨다면 만족하신 만큼 별의 개수로 평가해주세요. : '))

except :
    print('\n잘못 입력하셨습니다.1 에서 5 중 하나의 숫자를 입력해주세요.')

else :
        
    if n == 0 :

        for i in list2 :
            list2.insert(0, '☆')
            list2.pop()

            print(list2[n], end = ' ')


    elif n == 1 :        

        for i in list2 :
            list2.insert(0, '☆')
            list2.pop()

            print(list2[n], end = ' ')

    elif n == 2 :        

        for i in list2 :
            list2.insert(0, '☆')
            list2.pop()

            print(list2[n], end = ' ')

    elif n == 3 :        

        for i in list2 :
            list2.insert(0, '☆')
            list2.pop()

            print(list2[n], end = ' ')

    elif n == 4 :        

        for i in list2 :
            list2.insert(0, '☆')
            list2.pop()

            print(list2[n], end = ' ')

    elif n == 5 :        

        for i in list2 :

            print(list2[0], end = ' ')
    else :
        print('\n잘못 입력하셨습니다.1 에서 5 중 하나의 숫자를 입력해주세요.')
# Out:
# ...
# 0개 = 매우 불만족
# 1개 = 불만족
# 2개 = 약간 불만족
# 3개 = 보통
# 4개 = 만족
# 5개 = 매우 만족
#
# =---------------------------------------=
#
# 서비스가 마음에 드셨다면 만족하신 만큼 별의 개수로 평가해주세요. : 0
# ☆ ☆ ☆ ☆ ☆

# %%
list1 = '★ ★ ★ ★ ★'

n = int(input(''))

if n == 0 :
    for i in range(6) :
        x = list1.replace('★', '☆', i)
        print(x[n], end = ' ')

elif n == 2 :
    for i in range(6) :
        x = list1.replace('★', '☆', i)
        print(x[n], end = ' ')
# Out:
# 1
