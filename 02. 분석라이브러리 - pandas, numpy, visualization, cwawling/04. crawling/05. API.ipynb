# %% [markdown]
# # API (Application Programming Interface)
#
# API란 웹 상에서 데이터를 주고받을 수 있도록 미리 정해진 규칙과 프로토콜을 제공하는 인터페이스입니다. 인공지능 개발자는 이러한 API를 통해 데이터를 쉽게 수집하고 활용할 수 있습니다.
#
# 날씨 정보, 지리 정보, 주가 정보, 소셜 미디어 데이터 등 다양한 데이터를 API를 통해 수집할 수 있습니다. 이렇게 수집한 데이터를 기반으로 인공지능 모델을 학습시키고 예측 모델을 구축할 수 있습니다.
#
# API를 사용하면 데이터를 실시간으로 수집하는 것도 가능합니다. 데이터 분석가나 인공지능 개발자는 API를 통해 빠르게 변화하는 데이터를 수집하고, 이를 바탕으로 인공지능 모델을 최신화하고 새로운 트렌드에 대응할 수 있습니다.
#
# 또한, 데이터를 가공하거나 필요한 부분만 추출할 수도 있습니다. 이를 통해 인공지능 개발자는 필요한 데이터만 추출하고 이를 활용하여 모델을 더욱 효과적으로 구성할 수 있습니다.
#
# 이러한 API를 활용한 데이터 수집은 파이썬에서도 쉽게 구현할 수 있습니다.
# requests 라이브러리를 이용하여 API를 호출하고, JSON 또는 XML과 같은 형식으로 데이터를 수집하고 가공할 수 있습니다.

# %% [markdown]
# ## Naver API
#
# https://developers.naver.com/main/
#
#
#
# 네이버 API는 네이버에서 제공하는 다양한 서비스들을 이용할 수 있도록 제공하는 API입니다. 네이버 블로그 검색, 지식인 검색, 뉴스 검색 등의 기능을 API를 통해 사용할 수 있습니다. 이를 이용하여 웹 애플리케이션, 모바일 애플리케이션 등 다양한 서비스를 개발할 수 있습니다.
#
# [사용방법]
#
# 1.	네이버 개발자 센터에서 애플리케이션을 등록하고 클라이언트 아이디와 클라이언트 시크릿을 발급
# 2.	애플리케이션에 사용할 네이버 오픈API를 사용 API에서 선택해 추가
# 3.	로그인 오픈 API 서비스 환경별 상세 정보는 로그인 오픈 API 서비스 환경에서 입력
#
# 네이버 오픈API는 인증 여부에 따라 로그인 방식 오픈 API와 비로그인 방식 오픈 API로 구분됩니다. 로그인 방식 오픈 API는 '네이버 로그인’의 인증을 받아 접근 토큰(access token)을 획득해야 사용할 수 있는 오픈 API입니다. API를 호출할 때 네이버 로그인 API를 통해 받은 접근 토큰의 값을 전송해야 합니다
#
#
# https://seo.tbwakorea.com/blog/naver-seo-api-searching-data/

# %% [markdown]
# ### 예시 1 - 네이버 블로그 겁색 API

# %%
# 네이버 검색 Open API 예제 - 블로그 검색
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# json 모듈 - JSON 데이터를 파싱하고 생성하는 데에 사용되는 다양한 함수와 메서드를 제공
# json.loads() - 파일 핸들러(file handle)를 사용하여 JSON 형식 파일 데이터를 파싱하여 파이썬 객체로 변환

import os
import sys
import urllib.request
import pandas as pd
import json
import re

# client_id와 client_secret 변수에는 네이버에서 제공하는 클라이언트 ID와 클라이언트 시크릿 값이 저장
client_id = 'VNx3Aev0BoTmQVfE8a94'
client_secret = 'eNDLCmXP2A'

# urllib.parse.quote() 함수를 사용하여 검색어에 대한 URL 인코딩을 수행
encText = urllib.parse.quote(input('검색 질의 : '))

# url 변수에는 검색어를 포함한 검색 API의 URL이 저장되어 있습니다. 이때 검색 결과 형식을 JSON or XML로 설정
url = 'https://openapi.naver.com/v1/search/blog?query=' + encText
# url = 'https://openapi.naver.com/v1/search/blog.xml?query=' + encText

# urllib.request.Request() 함수를 사용하여 API에 대한 요청(Request) 객체를 생성
request = urllib.request.Request(url)

# add_header() 함수를 사용하여 클라이언트 ID와 클라이언트 시크릿 값을 요청 헤더에 포함
request.add_header('X-Naver-Client-Id', client_id)
request.add_header('X-Naver-Client-Secret', client_secret)

# urllib.request.urlopen() 함수를 사용하여 요청 객체를 전송하고, API에서 반환한 응답(Response) 객체를 받아옴
response = urllib.request.urlopen(request)

# response.getcode() 함수를 사용하여 HTTP 응답 코드를 확인
rescode = response.getcode()

web_df = pd.DataFrame(columns=('title', 'link', 'description'))    # 밑에서 iloc쓰려면 index=range(10) 설정해야 함

if (rescode==200):
    response_body = response.read()    # urllib으로 가져오면 bytes 타입임
#     response_dict = json.loads(response_body.decode('utf-8'))    #str -> dic 타입으로 (디코딩은 필요 없는듯)
    response_dict = json.loads(response_body)
    
    items = response_dict['items']
    
    for item_index in range(0,len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        web_df.loc[item_index] = [title, link, description]    # 판다스에는 정수 인덱싱을 라벨로 변환해주는 내부적인 처리가 있음
        # web_df.iloc~ 를 사용하려면, DataFrame을 만들 때 미리 index 범위를 지정해 주어야 함
else:
    print('Error Code:' + rescode)

web_df
# Out:
# 검색 질의 : 인공지능
#                                             title  \
# 0                            인공지능 AI학원 자격증부터 실무까지
# 1                                   그림 인공지능 사용해보기
# 2             언론사, &apos;인공지능 R&amp;D&apos; 나설 때다
# 3           2023 월드IT쇼 SK텔레콤의 다양한 AI 인공지능 기술과 UAM
# 4       AI 인공지능 관련주 챗GPT 바드 - 춤을 추되 문 근처에서 춤을...
# 5              성동4차산업혁명체험센터 인공지능Ai 로봇코딩 드론 서울...
# 6     AI 그림 그리기, Bing Image Creator로 인공지능 이미지...
# 7    인공지능을 사랑하는 한 남자의 영화, &apos;그녀(her)&apos; 감상평
# 8  AI 인공지능 ETF SRVR, CLOU, IROB (ft. 챗gpt 관련주...
# 9                   후지의료기 인공 지능이 탑재된 JP-2000 안마의자
#
#                                                 link  \
# 0           https://blog.naver.com/kumh/223084650618
# 1  https://www.internetmap.kr/entry/Why-Generativ...
# 2      https://www.onlinejournalism.co.kr/1196231257
# 3       https://blog.naver.com/todshrck/223088135648
# 4        https://blog.naver.com/resumet/223016372983
# 5                           https://ndolson.com/5812
# 6       https://blog.naver.com/winsweet/223068891384
# 7        https://blog.naver.com/soh4472/223091394568
# 8     https://blog.naver.com/couplesoap/222999333420
# 9        https://blog.naver.com/wbstore/223079260672
#
#                                          description
# 0  미래에는 일자리도 더욱 늘어날 것이며 인공지능이 관여하는 분야는 점점 넓어질 것이기...
# 1  Stable Diffusion은 생성형 AI(인공지능), 그중에서도 단어를 입력하면...
# 2  고안되던 인공지능은 이제 전혀 다른 국면을 맞고 있다. 미국 NBC 방송의 유명 시...
# 3  인공지능 스피커로도 괜찮을 것 같네요. A.(에이닷)은 대화형 인공지능 서비스를 지...
# 4  개인적으로 인터넷이 불러온 3차 산업혁명 이후 4차의 주인공이 인공지능이 되지 않을...
# 5  성동4차산업혁명체험센터 인공지능Ai 로봇코딩 드론 서울 아이들 가볼만한 곳 강력 추...
# 6  Bing 이미지 생성기는 검색 사이트와 유사한 인터페이스로 누구나 쉽게 인공지능 이...
# 7  영화는 포스터에 등장하는 테오도르(호아킨 피닉스)를 중심으로 흘러가지만, 또 다른 ...
# 8  인공지능(AI)가 답변을 해주는 채팅 플랫폼이다. 지금까지 우리는 검색을 하면 키워...
# 9  #후지의료기 #인공지능안마의자 #안마의자 안녕하세요 웰빙스토어 막내입니다:) 비 소...

# %%
# Out:
# b'{\n\t"lastBuildDate":"Thu, 04 May 2023 21:49:16 +0900",\n\t"total":1667533,\n\t"start":1,\n\t"display":10,\n\t"items":[\n\t\t{\n\t\t\t"title":"<b>\xec\x9d\xb8\xea\xb3\xb5\xec\xa7\x80\xeb\x8a\xa5<\\/b> AI\xed\x95\x99\xec\x9b\x90 \xec\x9e\x90\xea\xb2\xa9\xec\xa6\x9d\xeb\xb6\x80\xed\x84\xb0 \xec\x8b\xa4\xeb\xac\xb4\xea\xb9\x8c\xec\xa7\x80",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/kumh\\/223084650618",\n\t\t\t"description":"\xeb\xaf\xb8\xeb\x9e\x98\xec\x97\x90\xeb\x8a\x94 \xec\x9d\xbc\xec\x9e\x90\xeb\xa6\xac\xeb\x8f\x84 \xeb\x8d\x94\xec\x9a\xb1 \xeb\x8a\x98\xec\x96\xb4\xeb\x82\xa0 \xea\xb2\x83\xec\x9d\xb4\xeb\xa9\xb0 <b>\xec\x9d\xb8\xea\xb3\xb5\xec\xa7\x80\xeb\x8a\xa5<\\/b>\xec\x9d\xb4 \xea\xb4\x80\xec\x97\xac\xed\x95\x98\xeb\x8a\x94 \xeb\xb6\x84\xec\x95\xbc\xeb\x8a\x94 \xec\xa0\x90\xec\xa0\x90 \xeb\x84\x93\xec\x96\xb4\xec\xa7\x88 \xea\xb2\x83\xec\x9d\xb4\xea\xb8\xb0\xec\x97\x90 \xec\x95\x88\xec\xa0\x95\xec\xa0\x81\xec\x9d\xb8... \xec\xbb\xa4\xeb\xa6\xac\xed\x81\x98\xeb\x9f\xbc\xec\x9d\x98 \xec\xb5\x9c\xec\xa2\x85 \xeb\xaa\xa9\xed\x91\x9c\xeb\x8a\x94 \xed\x8c\x8c\xec\x9d\xb4\xec\x8d\xac\xec\x9d\x84 \xed\x99\x9c\xec\x9a\xa9\xed\x95\xb4\xec\x84\x9c \xeb\x8d\xb0\xec\x9d\xb4\xed\x84\xb0\xeb\xa5\xbc \xeb\xb6\x84\xec\x84\x9d\xed\x95\x98\xea\xb3\xa0 <b>\xec\x9d\xb8\xea\xb3\xb5\xec\xa7\x80\xeb\x8a\xa5<\\/b> \xec\xa7\x80\xec\x8b\x9d\xec\x9d\x84 \xea\xb8\xb0\xeb\xb0\x98\xec\x9c\xbc\xeb\xa1\x9c \xed\x95\x98\xeb\x8a\x94... ",\n\t\t\t"bloggername":"\xea\xb9\x8c\xeb\xb9\x84\xea\xb9\x8c\xeb\xb9\x84\xec\x9d\x98 \xec\xa7\x80\xec\x8b\x9d\xec\xb0\xbd\xea\xb3\xa0",\n\t\t\t"bloggerlink":"blog.naver.com\\/kumh",\n\t\t\t"postdate":"20230425"\n\t\t},\n\t\t{\n\t\t\t"title":"\xea\xb7\xb8\xeb\xa6\xbc <b>\xec\x9d\xb8\xea\xb3\xb5\xec\xa7\x80\xeb\x8a\xa5<\\/b> \xec\x82\xac\xec\x9a\xa9\xed\x95\xb4\xeb\xb3\xb4\xea\xb8\xb0",\n\t\t\t"link":"https:\\/\\/www.internetmap.kr\\/entry\\/Why-Generative-AI?category=1083809",\n\t\t\t"description":"Stable Diffusion\xec\x9d\x80 \xec\x83\x9d\xec\x84\xb1\xed\x98\x95 AI(<b>\xec\x9d\xb8\xea\xb3\xb5\xec\xa7\x80\xeb\x8a\xa5<\\/b>), \xea\xb7\xb8\xec\xa4\x91\xec\x97\x90\xec\x84\x9c\xeb\x8f\x84 \xeb\x8b\xa8\xec\x96\xb4\xeb\xa5\xbc \xec\x9e\x85\xeb\xa0\xa5\xed\x95\x98\xeb\xa9\xb4 \xea\xb7\xb8\xeb\xa6\xbc\xec\x9d\x84 \xec\x83\x9d\xec\x84\xb1\xed\x95\xb4\xec\xa3\xbc\xeb\x8a\x94(text-to-image) \xec\x83\x9d\xec\x84\xb1\xed\x98\x95 AI\xeb\xa1\x9c\xec\x84\x9c, 2022\xeb\x85\x84 8\xec\x9b\x94\xec\x97\x90 \xec\x98\xa4\xed\x94\x88\xec\x86\x8c\xec\x8a\xa4\xeb\xa1\x9c \xea\xb3\xb5\xea\xb0\x9c\xeb\x90\x9c <b>\xec\x9d\xb8\xea\xb3\xb5\xec\xa7\x80\xeb\x8a\xa5<\\/b> \xeb\xaa\xa8\xeb\x8d\xb8\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4. \xeb\xa9\xb0\xec\xb9\xa0\xec\xa0\x84\xeb\xb6\x80\xed\x84\xb0 \xec\xa2\x8c\xec\xb6\xa9\xec\x9a\xb0\xeb\x8f\x8c\xed\x95\x98\xeb\xa9\xb0 \xeb\xa7\x8c\xec\xa7\x80\xea\xb3\xa0... ",\n\t\t\t"bloggername":"\xea\xb3\xb5\xea\xb0\x84\xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9d\xb8\xed\x84\xb0\xeb\x84\xb7\xec\xa7\x80\xeb\x8f\x84",\n\t\t\t"bloggerlink":"https:\\/\\/www.internetmap.kr\\/",\n\t\t\t"postdate":"20230326"\n\t\t},\n\t\t{\n\t\t\t"title":"\xec\x96\xb8\xeb\xa1\xa0\xec\x82\xac, &apos;<b>\xec\x9d\xb8\xea\xb3\xb5\xec\xa7\x80\xeb\x8a\xa5<\\/b> R&amp;D&apos; \xeb\x82\x98\xec\x84\xa4 \xeb\x95\x8c\xeb\x8b\xa4",\n\t\t\t"link":"https:\\/\\/www.onlinejournalism.co.kr\\/1196231257",\n\t\t\t"description":"\xea\xb3\xa0\xec\x95\x88\xeb\x90\x98\xeb\x8d\x98 <b>\xec\x9d\xb8\xea\xb3\xb5\xec\xa7\x80\xeb\x8a\xa5<\\/b>\xec\x9d\x80 \xec\x9d\xb4\xec\xa0\x9c \xec\xa0\x84\xed\x98\x80 \xeb\x8b\xa4\xeb\xa5\xb8 \xea\xb5\xad\xeb\xa9\xb4\xec\x9d\x84 \xeb\xa7\x9e\xea\xb3\xa0 \xec\x9e\x88\xeb\x8b\xa4. \xeb\xaf\xb8\xea\xb5\xad NBC \xeb\xb0\xa9\xec\x86\xa1\xec\x9d\x98 \xec\x9c\xa0\xeb\xaa\x85 \xec\x8b\x9c\xed\x8a\xb8\xec\xbd\xa4 &lt;\xec\x82\xac\xec\x9d\xb8\xed\x8e\xa0\xeb\x93\x9c... \xeb\x8c\x80\xed\x99\x94 \xed\x85\x8d\xec\x8a\xa4\xed\x8a\xb8\xeb\x8a\x94 GPT-3, \xec\x9d\x8c\xec\x84\xb1\xec\x9d\x80 \xec\x96\xb8\xec\x96\xb4, \xec\x8b\x9c\xea\xb0\x81 \xec\xa0\ ...

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = 'VNx3Aev0BoTmQVfE8a94'
client_secret = 'eNDLCmXP2A'

query = urllib.parse.quote(input('검색 질의: '))

display = 100
start = 1
end = 1000
sort = 'sim'    # 유사도?

news_df = pd.DataFrame(columns=('Title', 'Original Link', 'Link', 'Description', 'Publication Date'))

for start_index in range(start, end, display):
    
    url = 'https://openapi.naver.com/v1/search/news?query=' + query \
    + '&display=' + str(display) \
    + '&start=' + str(start_index) \
    + '&sort=' + sort
    
    request = urllib.request.Request(url)
    request.add_header('X-Naver-Client-Id', client_id)
    request.add_header('X-Naver-Client-Secret', client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if (rescode==200):
        response_body = response.read()    # urllib으로 가져오면 bytes 타입임
        response_dict = json.loads(response_body.decode('utf-8'))    #str -> dic 타입으로
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            original_link = items[item_index]['originallink']
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            pub_date = items[item_index]['pubDate']
            news_df.loc[item_index] = [title, original_link, link, description, pub_date]            
    else:
        print('Error Code:' + rescode)

news_df

#  'items': [{'title': '&apos;투자 온도계&apos; 더한 <b>인공지능</b> 자산관리',
#    'originallink': 'https://www.bloter.net/news/articleView.html?idxno=600662',
#    'link': 'https://n.news.naver.com/mnews/article/293/0000043417?sid=101',
#    'description': 'AI(<b>인공지능</b>) 자동투자 콴텍이 하나은행의 AI자산관리 플랫폼 &apos;아이웰스&apos;를 통해 &apos;금융시장 투자 온도계(SMART Index)&apos; 서비스를 제공한다. 14일 콴텍에 따르면 하나은행과 제휴해 선보이는 금융시장 투자 온도계는 그간... ',
#    'pubDate': 'Fri, 14 Apr 2023 18:06:00 +0900'},
# Out:
# 검색 질의: 인공지능
#                                               Title  \
# 0                  컴투버스, 셀바스AI와 메타버스내 인공지능 기술·사업 맞손
# 1                   &apos;투자 온도계&apos; 더한 인공지능 자산관리
# 2                 컴투버스, 셀바스AI와 메타버스 내 인공지능 기술·사업 협력
# 3                            인공지능 기술로 리튬이온배터리 수명 진단
# 4                          김외철 (사)한국인공지능협회 상근부회장 임명
# ..                                              ...
# 95               인간과 대화할 수 있게 된 인공지능, 다음 순서는 ‘자아’일까
# 96  아이메디신, 2023 월드IT쇼서 인공지능 기반 디지털 멘탈 헬스케어 플랫폼 소...
# 97              “인공지능 길들이기”…‘챗GPT’ 광주시민 무료 실습 교육 눈길
# 98                 건국대, 반도체·인공지능 등 2학기 17개 분야 교수 초빙
# 99         경기도, 인공지능(AI) 기술 활용한 게임 콘텐츠 제작 기업에 1억 지원
#
#                                         Original Link  \
# 0   http://www.newsdream.kr/news/articleView.html?...
# 1   https://www.bloter.net/news/articleView.html?i...
# 2             https://www.tokenpost.kr/article-129720
# 3        https://www.dongascience.com/news/view/59294
# 4   https://news.imaeil.com/page/view/202304191709...
# ..                                                ...
# 95  https://www.hani.co.kr/arti/science/science_ge...
# 96  https://kr.aving.net/news/articleView.html?idx...
# 97  http://www.kwangju.co.kr/article.php?aid=16819...
# 98    https://dhnews.co.kr/news/view/1065596975223198
# 99  http://www.econonews.co.kr/news/articleView.ht...
#
#                                                  Link  \
# 0   http://www.newsdream.kr/news/articleView.html?...
# 1   https://n.news.naver.com/mnews/article/293/000...
# 2             https://www.tokenpost.kr/article-129720
# 3   https://n.news.naver.com/mnews/article/584/000...
# 4   https://n.news.naver.com/mnews/article/088/000...
# ..                                                ...
# 95  https://n.news.naver.com/mnews/article/028/000...
# 96  https://kr.aving.net/news/articleView.html?idx...
# 97  http://www.kwangju.co.kr/article.php?aid=16819...
# 98    https://dhnews.co.kr/news/view/1065596975223198
# 99  http://www.econonews.co.kr/news/articleView.ht...
#
#                                           Description  \
# 0   컴투버스는 이번 협약을 바탕으로 셀바스AI와 함께 메타버스 인프라스트럭처로 설계되는...
# 1   AI(인공지능) 자동투자 콴텍이 하나은행의 AI자산관리 플랫폼 &apos;아이웰스&...
# 2   셀바스AI는 음성인식, 음성합성, 필기인식, 광학문자인식, 자연어 처리 등 최고 수...
# 3   인공지능(AI)을 구현하는 딥러닝 기술을 활용해 배터리의 수명과 관련한 일부 데이터...
# 4   김외철 전 경상북도 서울본부장이 지난 18일 (사)한국인공지능협회 상근부회장에 임명...
# ..                                                ...
# 95  하지만 이는 잠시 미뤄두고 이번 칼럼부터는 두뇌와 인공지능 관점을 다룰 것이다. 뜬...
# 96  아이메디신은 2012년 설립한 인공지능 기반 &apos;디지털 멘탈 헬스케어 플랫폼...
# 97  인공지능산업융합사업단이 광주시민을 대상으로 인공지능(AI) 기반 챗봇인 ‘챗 GPT...
# 98  21일 건국대에 따르면 초빙분야는 공과대학에서 ▲건설재료(사회환경공학부) ▲반도체 ...
# 99  경기도는 미래기술 분야(블록체인, 인공지능, 빅데이터, 클라우드, 메타버스, 가상·...
#
#                    Publication Date
# 0   Tue, 18 Apr 2023 10:54:00 +0900
# 1   Fri, 14 Apr 2023 18:06:00 +0900
# 2   Tue, 18 Apr 2023 09:30:00 +0900
# 3   Thu, 06 Apr 2023 13:53:00 +0900
# 4   Wed, 19 Apr 2023 17:14:00 +0900
# ..                              ...
# 95  Wed, 12 Apr 2023 10:03:00 +0900
# 96  Fri, 28 Apr 2023 14:04:00 +0900
# 97  Thu, 20 Apr 2023 17:38:00 +0900
# 98  Fri, 21 Apr 2023 16:34:00 +0900
# 99  Mon, 17 Apr 2023 15:52:00 +0900
#
# [100 rows x 5 columns]

# %% [markdown]
# 파이썬에서 클래스는 일종의 데이터 타입이며, 모든 변수나 객체는 어떤 클래스의 인스턴스(instance)입니다. 이때 클래스 이름은 해당 객체의 데이터 타입을 나타냅니다.
#
# 그래서 파이썬에서는 클래스 이름을 보기 쉽게 나타내기 위해 "<class '클래스 이름'>" 형태로 보여줍니다. 하지만 이는 사용자가 클래스 이름을 보기 편하게 하기 위한 것으로, 클래스 이름이 없는 데이터 타입(str, int 등)도 있습니다.
#
# 따라서 "<class 'str'>"처럼 클래스 이름이 나오는 것과 "str"처럼 클래스 이름이 생략되어 나오는 것이 모두 가능합니다.

# %%
# dict 객체임
print(type(response_dict))
response_dict
# Out:
# <class 'dict'>
# {'lastBuildDate': 'Thu, 04 May 2023 12:35:56 +0900',
#  'total': 1739155,
#  'start': 901,
#  'display': 100,
#  'items': [{'title': '컴투버스, 셀바스AI와 메타버스내 <b>인공지능</b> 기술·사업 맞손',
#    'originallink': 'http://www.newsdream.kr/news/articleView.html?idxno=41840',
#    'link': 'http://www.newsdream.kr/news/articleView.html?idxno=41840',
#    'description': '컴투버스는 이번 협약을 바탕으로 셀바스AI와 함께 메타버스 인프라스트럭처로 설계되는 컴투버스를 위해, <b>인공지능</b> 기술 및 서비스 개발에 대한 전략적 협력을 추진할 계획이다. 또한 셀바스AI와 2분기 첫 선을 보이는... ',
#    'pubDate': 'Tue, 18 Apr 2023 10:54:00 +0900'},
#   {'title': '&apos;투자 온도계&apos; 더한 <b>인공지능</b> 자산관리',
#    'originallink': 'https://www.bloter.net/news/articleView.html?idxno=600662',
#    'link': 'https://n.news.naver.com/mnews/article/293/0000043417?sid=101',
#    'description': 'AI(<b>인공지능</b>) 자동투자 콴텍이 하나은행의 AI자산관리 플랫폼 &apos;아이웰스&apos;를 통해 &apos;금융시장 투자 온도계(SMART Index)&apos; 서비스를 제공한다. 14일 콴텍에 따르면 하나은행과 제휴해 선보이는 금융시장 투자 온도계는 그간... ',
#    'pubDate': 'Fri, 14 Apr 2023 18:06:00 +0900'},
#   {'title': '컴투버스, 셀바스AI와 메타버스 내 <b>인공지능</b> 기술·사업 협력',
#    'originallink': 'https://www.tokenpost.kr/article-129720',
#    'link': 'https://www.tokenpost.kr/article-129720',
#    'description': '셀바스AI는 음성인식, 음성합성, 필기인식, 광학문자인식, 자연어 처리 등 최고 수준의 인간과 컴퓨터 간 상호작용(HCI, Human Computer Interaction) 기술을 기반으로 한 <b>인공지능</b> 전문 기업으로, 교육, 의료, 금융, 문화... ',
#    'pubDate': 'Tue, 18 Apr 2023 09:30:00 +0900'},
#   {'title': '<b>인공지능</b> 기술로 리튬이온배터리 수명 진단',
#    'originallink': 'https://www.dongascience.com/news/view/59294',
#    'link': 'https://n.news.naver.com/mnews/article/584/0000022587?sid=105',
#    'description': '<b>인공지능</b>(AI)을 구현하는 딥러닝 기술을 활용해 배터리의 수명과 관련한 일부 데이터만으로도 정확한 수명을 예측할 수 있다. 진단 시 필요한 시간과 비용을 절감해 폐배터리의 재활용 효율을 높일 것으로 기대된다.... ',
#    'pubDate': 'Thu, 06 Apr 2023 13:53:00 +0900'},
#   {'title': '김외철 (사)한국<b>인공지능</b>협회 상근부회장 임명',
#    'originallink': 'https://news.imaeil.com/page/view/2023041917093711685',
#    'link': 'https://n.news.naver.com/mnews/article/088/0000809783?sid=004',
#    'description': '김외철 전 경상북도 서울본부장이 지난 18일 (사)한국<b>인공지능</b>협회 상근부회장에 임명됐다. 옛 한나라당 당직자 출신인 그는 국회 정책연구위원, 제18대 대통령직인수위원회 전문위원, 국무총리실 정무비서관 등을... ',
#    'pubDate': 'Wed, 19 Apr 2023 17:14:00 +0900'},
#   {'title': '전남교육청, 대화형 <b>인공지능</b> 챗봇활용 안내서 배부',
#    'originallink': 'https://www.sportsseoul.com/news/read/1304252?ref=naver',
#    'link': 'https://n.news.naver.com/mnews/article/468/0000935715?sid=102',
#    'description': '챗봇활용 안내서= 전남교육청 제공 전라남도교육청이 대화형 <b>인공지능</b> 챗봇 활용 교육용 안내서를 제작해 최근 각급 학교에 배부했다. 대화형 <b>인공지능</b> 챗봇 중 하나인 ChatGPT는 OpenAI가 개발한 대화형 <b>인공지능</b>... ',
#    'pubDate': 'Wed, 12 Apr 2023 13:56:00 +0900'},
#   {'title': '수원시, <b>인공지능</b> 홍보 트럭 도시 누빈다',
#    'originallink': 'https://www.nspna.com/news/?mode=view&newsid=633549',
#    'link': 'https://www.nspna.com/news/?mode=view&newsid=633549',
#    'description': '경기 수원시(시장 이재준)의 주요 행사와 정책을 <b>인공지능</b> 디스플레이를 장착한 트럭이 도심 곳곳을 다니며 홍보한다. 시는 애드와 24일 수원시청에서 ‘디지털 모빌리티 영상홍보 협약’을 체결하고 애드가 운영하는... ',
#    'pubDate': 'Mon, 24 Apr 2023 17:18:00 +0900'},
#   {'title': '컴투버스-셀바스AI, 메타버스 <b>인공지능</b> 관련 기술 ‧ 사업 협력 협약',
#    'originallink': 'http://www.worktoday.co.kr/news/articleView.html?idxno=34723',
#    'link': 'http://www.worktoday.co.kr/news/articleView.html?idxno=34723',
#    'description': '셀바스AI는 음성인식, 음성합성, 필기인식, 광학문자인식, 자연어 처리 등 HCI(Human Computer Interaction) 기술을 기반으로 한 <b>인공지능</b> 전문 기업으로, 교육, 의료, 금융, 문화, 엔터테인먼트 등 다양한 분야와의 기술 협력을... ',
#    'pubDate': 'Tue, 18 Apr 2023 11:36:00 +0900'},
#   {'title': '구글 클라우드·경북도, <b>인공지능</b> 인재 양성 … 안동대에 AI진흥센터 설치',
#    'originallink': 'https://view.asiae.co.kr/article/2023041808225303454',
#    'link': 'https://n.news.naver.com/mnews/article/277/0005246839?sid=102',
#    'description': '경북도는 18일 Google cloud와 협약을 체결하고, 글로벌 <b>인공지능</b> 인재 양성에 나서기로 했다. 우선, 올 하반기부터 시범사업을 통해 안동대에 AI 진흥센터를 설치하고, 100여명의 인력을 양성한다는 계획이다. 과정은... ',
#    'pubDate': 'Tue, 18 Apr 2023 08:31:00 +0900'},
#   {'title': '경북도-구글 클라우드, 글로벌 <b>인공지능</b> 인재 양성 &apos;맞손&apos;',
#    'originallink': 'https://ilyo.co.kr/?ac=article_view&entry_id=450572',
#    'link': 'https://ilyo.co.kr/?ac=article_view&entry_id=450572',
#    'description': '글로벌 <b>인공지능</b> 인재 양성에 나서기로 했다. 도는 우선 올 하반기부터 시범사업으로 안동대에 AI 진흥센터를 설치하고, 100여 명의 인력을 양성한다는 계획이다. 과정은 비전공자 등도 수강이 가능한 AI, 클라우드... ',
#    'pubDate': 'Tue, 18 Apr 2023 10:06:00 +0900'},
#   {'title': '스노우플레이크, 한국타이어 통합 <b>인공지능</b> 데이터 분석 플랫폼 구축 지원',
#    'originallink': 'http://www.digitaltoday.co.kr/news/articleView.html?idxno=474861',
#    'link': 'http://www.digitaltoday.co.kr/news/articleView.html?idxno=474861',
#    'description': '스노우플레이크 로고. 글로벌 데이터 클라우드 기업 스노우플레이크는 한국앤컴퍼니그룹 사업형 지주회사 한국앤컴퍼니와 계열사 한국타이어앤테크놀로지(이하 한국타이어) 통합 데이터 분석 플랫폼 구축을 위해 자사... ',
#    'pubDate': 'Tue, 25 Apr 2023 14:12:00 +0900'},
#   {'title': '일산백병원, &apos;심정지 예측 <b>인공지능</b>(AI) 프로그램&apos; 도입',
#    'originallink': 'http://www.thefirstmedia.net/news/articleView.html?idxno=116121',
#    'link': 'http://www.thefirstmedia.net/news/articleView.html?idxno=116121',
#    'description': '▲일산백병원이 심정지 예측 <b>인공지능</b>(AI) 프로그램인 딥카스를 도입, 병동 간호사들이 딥카스 프로그램을 시연하고 있다.  인제대학교 일산백병원(원장 이성순)이 환자 안전을 위해 심정지 예측 <b>인공지능</b>(AI) 프로그램... ',
#    'pubDate': 'Tue, 18 Apr 2023 19:12:00 +0900'},
#   {'title': '중앙대 &apos;<b>인공지능</b>의 몸과 노동&apos; 학술대회 개최',
#    'originallink': 'http://www.newsis.com/view/?id=NISX20230405_0002254960&cID=10201&pID=10200',
#    'link': 'https://n.news.naver.com/mnews/article/003/0011785449?sid=102',
#    'description': '기사내용 요약 <b>인공지능</b> 기반 데이터 해석 이슈·활용방법 등 논의 허서우 인턴 기자 = 중앙대는 오는 28일 &apos;<b>인공지능</b>의 몸과 노동&apos;을 주제로 제27회 <b>인공지능</b>인문학 국내학술대회를 개최한다고 5일 밝혔다. &apos;<b>인공지능</b>의... ',
#    'pubDate': 'Wed, 05 Apr 2023 13:26:00 +0900'},
#   {'title': '메타, 메타버스 대신 <b>인공지능</b>에 집중',
#    'originallink': 'https://zdnet.co.kr/view/?no=20230406071810',
#    'link': 'https://n.news.naver.com/mnews/article/092/0002287887?sid=105',
#    'description': '페이스북, 인스타그램 운영사 메타가 미래 먹거리로 낙점한 메타버스 대신 <b>인공지능</b>(AI) 관련 사업에 집중하고 있다. 5일(현지시간) CNBC에 따르면 앤드류 보스워스 메타 최고기술책임자(CTO)는 닛케이아시아와... ',
#    'pubDate': 'Thu, 06 Apr 2023 08:33:00 +0900'},
#   {'title': '김동연 &quot;세계석학들과 &apos;<b>인공지능</b> 수도&apos; 만들겠다&quot;',
#    'originallink': 'http://www.inews24.com/view/1585082',
#    'link': 'https://n.news.naver.com/mnews/article/031/0000740656?sid=004',
#    'description': '김동연 경기도지사가 세계적인 석학들과 &apos;<b>인공지능</b> 수도&apos;를 만들겠다고 다짐했다. 김동연 지사는 13일 자신의 페이스북을 통해 &quot;뉴욕대 부설 &apos;THE GOVLAB&apos;에서 세계적인 석학들과 AI의 미래, 지방정부 차원의 운용 방안... ',
#    'pubDate': 'Thu, 13 Apr 2023 12:07:00 +0900'},
#   {'title': 'EsB투자그룹, AI <b>인공지능</b> 시스템 도입 검토',
#    'originallink': 'https://www.woodkorea.co.kr/news/articleView.html?idxno=73094',
#    'link': 'https://www.woodkorea.co.kr/news/articleView.html?idxno=73094',
#    'description': '챗GPT(ChatGPT) <b>인공지능</b>이 세계적으로 관심을 받고 있는 가운데 EsB투자그룹이 <b>인공지능</b> 데이터기반을 활용한 주식 관련 정보를 제공하는 시스템 개발 및 도입을 검토 중이라고 밝혔다. <b>인공지능</b>은 대량의 데이터를... ',
#    'pubDate': 'Tue, 25 Apr 2023 15:22:00 +0900'},
#   {'title': '인천시, <b>인공지능</b>·빅데이터 등 첨단기술 기반 교통상황실 구축',
#    'originallink': 'https://www.jeonmae.co.kr/news/articleView.html?idxno=954137',
#    'link': 'https://www.jeonmae.co.kr/news/articleView.html?idxno=954137',
#    'description': '최첨단 <b>인공지능</b>(AI)기술과 빅데이터 분석.활용해 교통 흐름을 관리하고, 교통사고에 대응하는 등 신속한 협업 체계를 구축하기로 뜻을 모았다. <b>지능</b>형 교통종합상황실은 <b>지능</b>형교통정보체계(ITS)에 기반했다. 시는 지난... ',
#    'pubDate': 'Wed, 26 Apr 2023 11:10:00 +0900'},
#   {'title': '경북교육청, <b>인공지능</b>(AI) 교육 선도학교 운영 내실화 도모',
#    'originallink': 'https://www.nspna.com/news/?mode=view&newsid=632674',
#    'link': 'https://www.nspna.com/news/?mode=view&newsid=632674',
#    'description': '2023년 <b>인공지능</b>(AI) 교육 선도학교 자체 사업 설명회 개최 경상북도교육청(교육감 임종식)은 지난 18일 경상북도교육청연수원에서 2023년 <b>인공지능</b>(AI) 교육 선도학교의 내실 있는 운영을 위한 자체 사업 설명회를... ',
#    'pubDate': 'Wed, 19 Apr 2023 16:48:00 +0900'},
#   {'title': '[도서관 마을포럼] &apos;<b>인공지능</b> 시대, 인간답게 산다는 건 무엇일까&apos;',
#    'originallink': 'http://www.naeil.com/news_view/?id_art=458234',
#    'link': 'http://www.naeil.com/news_view/?id_art=458234',
#    'description': '<b>인공지능</b> 시대의 삶과 일&apos;을 주제로 마을포럼이 열렸다. 사진 이의종 ◆&apos;<b>인공지능</b>은 왜 모른다고 못할까&apos; = 15일 느티나무도서관에서는 &apos;인간답게 산다는 건 뭘까? <b>인공지능</b> 시대의 삶과 일&apos;을 주제로 마을포럼이 열렸다.... ',
#    'pubDate': 'Thu, 20 Apr 2023 12:34:00 +0900'},
#   {'title': '부산빅데이터혁신센터, 디지털 전환 포럼 &apos;<b>인공지능</b>과 데이터의 미래&apos; 개최',
#    'originallink': 'http://www.bzeronews.com/news/articleView.html?idxno=604179',
#    'link': 'http://www.bzeronews.com/news/articleView.html?idxno=604179',
#    'description': '부산시(시장 박형준)는 오늘(27일) 오후 6시, 부산빅데이터혁신센터(해운대구 센텀동로 45, 7층)에서 &apos;ChatGPT 활용 사례로 보는 <b>인공지능</b>과 데이터의 미래&apos;를 주제로 「제7회 디지털 전환 포럼」(이하 DX포럼, 2022년 1~6회... ',
#    'pubDate': 'Thu, 27 Apr 2023 23:54:00 +0900'},
#   {'title': '[단독]외교부, 박진 장관 <b>인공지능</b>(AI) 아바타 제작…외교 무대서 활용',
#    'originallink': 'https://www.ichannela.com/news/main/news_detailPage.do?publishId=000000343342',
#    'link': 'https://n.news.naver.com/mnews/article/449/0000247710?sid=100',
#    'description': '외교부가 박진 장관의 <b>인공지능</b>(AI) 아바타를 제작한 것으로 확인 됐습니다. 외교부는 홍보 활동을 강화하기 위해 AI 박진 장관을 다양한 외교 무대에서 활용하겠다는 계획을 세웠습니다. AI 아바타는 해당 인물의... ',
#    'pubDate': 'Fri, 14 Apr 2023 17:05:00 +0900'},
#   {'title': '아마존도 생성 <b>인공지능</b> 출시?…“경쟁 뒤처져 있지 않다“',
#    'originallink': 'https://news.kbs.co.kr/news/view.do?ncd=7646834&ref=A',
#    'link': 'https://n.news.naver.com/mnews/article/056/0011462016?sid=104',
#    'description': '세계 최대 전자상거래 업체 아마존이 현재 글로벌 기업들이 뛰어들고 있는 <b>인공지능</b>(AI) 분야에서 자사도 뒤처져 있지 않다고 자신했습니다. 9일(현지시각) 워싱턴포스트(WP)에 따르면 스와미 시바수브라마니 AI 부사장은... ',
#    'pubDate': 'Mon, 10 Apr 2023 03:52:00 +0900'},
#   {'title': '“아리아 살려줘” 소중한 생명 구한 구미시 <b>인공지능</b> 스피커',
#    'originallink': 'https://www.donga.com/news/Society/article/all/20230410/118766210/2',
#    'link': 'https://n.news.naver.com/mnews/article/020/0003490496?sid=102',
#    'description': '경북 구미시 인동동에 홀로 거주하는 이 모 씨(78)는 최근 응급 상황에서 <b>인공지능</b>(AI) 스피커를 이용해 구조됐다. 10일 구미시에 따르면 이 씨는 지난 6일 아침 5시 18분경 자고 일어나니 갑자기 마비 증상이 왔다. 그는... ',
#    'pubDate': 'Mon, 10 Apr 2023 15:58:00 +0900'},
#   {'title': '인천시·인천경찰청,<b>인공지능</b> 기반 교통상황실 운영',
#    'originallink': 'https://news.kbs.co.kr/news/view.do?ncd=7642392&ref=A',
#    'link': 'https://n.news.naver.com/mnews/article/056/0011458484?sid=102',
#    'description': '인천시는 이달 안에 <b>인공지능</b> 기반 교통종합상황실을 준공해 인천경찰청과 합동으로 운영하겠다고 밝혔습니다. <b>인공지능</b> 교통종합상황실은 인천 시내 주요 도로 328㎞ 구간에서 실시간으로 교통정보를 수집해 교통상황... ',
#    'pubDate': 'Tue, 04 Apr 2023 09:24:00 +0900'},
#   {'title': '세종시교육청, <b>인공지능</b> 문답시대 &apos;챗GPT&apos; 개발·보급',
#    'originallink': 'https://cc.newdaily.co.kr/site/data/html/2023/04/11/2023041100150.html',
#    'link': 'https://cc.newdaily.co.kr/site/data/html/2023/04/11/2023041100150.html',
#    'description': '뉴데일리 이길표 기자 = 세종시교육청이 <b>인공지능</b> 도구 챗GPT 사용자 급증에 따라 학교 현장에서 사용할 수 있는 &apos;문답의 시대, 챗GPT&apos; 자료를 개발·보급한다고 11일 밝혔다. 자료는 챗GPT의 기본개념과 사용방법, 교수... ',
#    'pubDate': 'Tue, 11 Apr 2023 15:26:00 +0900'},
#   {'title': '[포토] 컴투버스, 셀바스AI와 메타버스 내 <b>인공지능</b> 관련 기술·사업 협력',
#    'originallink': 'http://www.asiaa.co.kr/news/articleView.html?idxno=122153',
#    'link': 'http://www.asiaa.co.kr/news/articleView.html?idxno=122153',
#    'description': '셀바스AI는 음성인식, 음성합성, 필기인식, 광학문자인식, 자연어 처리 등 최고 수준의 HCI(Human Computer Interaction) 기술을 기반으로 한 <b>인공지능</b> 전문 기업으로, 교육, 의료, 금융, 문화, 엔터테인먼트 등 다양한 분야와의... ',
#    'pubDate': 'Tue, 18 Apr 2023 10:16:00 +0900'},
#   {'title': '부산형 ‘<b>인공지능</b> 로봇’ 첫선…판교 주도 시장 추격 본격화',
#    'originallink': 'http://www.kookje.co.kr/news2011/asp/newsbody.asp?code=0200&key=20230414.22002004315',
#    'link': 'https://n.news.naver.com/mnews/article/658/0000038239?sid=101',
#    'description': '- 선박 화물 자동배치 기술 등 개발 - 19일 열릴 인재양성대전서 공개 ‘부산형 <b>인공지능</b>(AI) 로봇’이 전국 무대에 선보인다. 경기 판교와 수도권 대기업이 주도하는 AI 로봇 시장에서 부산의 추격이 시작될지... ',
#    'pubDate': 'Fri, 14 Apr 2023 03:02:00 +0900'},
#   {'title': '경북교육청, <b>인공지능</b>(AI) 교육 선도학교 운영 내실화 도모',
#    'originallink': 'https://www.dkilbo.com/news/articleView.html?idxno=398481',
#    'link': 'https://www.dkilbo.com/news/articleView.html?idxno=398481',
#    'description': '▲ 지난 18일 경북교육청연수원에서 2023년 <b>인공지능</b>(AI) 교육 선도학교의 내실 있는 운영을 위한 자체 사업 설명회를 개최하고 있다. 경북교육청 제공 경북교육청은 지난 18일 경북교육청연수원에서 2023년 <b>인공지능</b>(AI)... ',
#    'pubDate': 'Wed, 19 Apr 2023 21:46:00 +0900'},
#   {'title': '컴투버스, 셀바스AI와 <b>인공지능</b> 관련 기술·사업 협력 협약 체결',
#    'originallink': 'https://www.khgames.co.kr/news/articleView.html?idxno=212041',
#    'link': 'https://www.khgames.co.kr/news/articleView.html?idxno=212041',
#    'description': '셀바스AI는 음성인식, 음성합성, 필기인식, 광학문자인식, 자연어 처리 등 HCI(Human Computer Interaction) 기술을 기반으로 한 <b>인공지능</b> 전문 기업이다. 최근에는 25년간 축적한 <b>인공지능</b> 기술 및 노하우와 데이터를 기반으로... ',
#    'pubDate': 'Tue, 18 Apr 2023 09:54:00 +0900'},
#   {'title': '충북 제천세명대 제천시농촌협약센터, <b>인공지능</b> 시대 데이터 분석역량 강화 무...',
#    'originallink': 'https://www.ccdn.co.kr/news/articleView.html?idxno=911520',
#    'link': 'https://www.ccdn.co.kr/news/articleView.html?idxno=911520',
#    'description': '충북 제천 세명대학교(총장 권동현) 제천시농촌협약센터는 관내 농업 경쟁력 강화를 위해 &apos;<b>인공지능</b> 시대 데이터 분석역량 강화&apos; 교육을 실시했다고 24일 밝혔다. 교육은 김계수 세명대학교 경영학과 교수가 강사로 나서... ',
#    'pubDate': 'Mon, 24 Apr 2023 19:38:00 +0900'},
#   {'title': '[아침광장] <b>인공지능</b> 의사결정과 인간의 대체',
#    'originallink': 'http://www.kyongbuk.co.kr/news/articleView.html?idxno=2129613',
#    'link': 'http://www.kyongbuk.co.kr/news/articleView.html?idxno=2129613',
#    'description': '정채연 포스텍 인문사회학부 교수 오픈 AI 사가 개발한 <b>인공지능</b> 챗봇 서비스인 챗GPT가 새로운 시대적 화두가 되면서 이른바 세 번째 &apos;<b>인공지능</b>의 봄&apos;은 한동안 지속될 듯하다. 최근 챗GPT가 일으키는 열풍을 바라보면... ',
#    'pubDate': 'Wed, 19 Apr 2023 17:16:00 +0900'},
#   {'title': '컴투버스-셀바스AI, 메타버스 내 <b>인공지능</b>사업 맞손',
#    'originallink': 'http://www.biztribune.co.kr/news/articleView.html?idxno=279769',
#    'link': 'http://www.biztribune.co.kr/news/articleView.html?idxno=279769',
#    'description': '셀바스AI는 음성인식, 음성합성, 필기인식, 광학문자인식, 자연어 처리 등 최고 수준의 HCI(Human Computer Interaction) 기술을 기반으로 한 <b>인공지능</b> 전문 기업으로, 교육, 의료, 금융, 문화, 엔터테인먼트 등 다양한 분야와의... ',
#    'pubDate': 'Tue, 18 Apr 2023 13:42:00 +0900'},
#   {'title': '[호남대 AI 큐브] 이용이 SOS랩 총괄책임자, &quot;챗GPT 등 <b>인공지능</b> 도구 적극 활...',
#    'originallink': 'https://kr.aving.net/news/articleView.html?idxno=1778537',
#    'link': 'https://kr.aving.net/news/articleView.html?idxno=1778537',
#    'description': '이용이 총괄책임자는 &quot;챗GPT 등과 같은 <b>인공지능</b> 서비스를 사용하는 이들이 몇 초만에 처리하는 일들을, 미사용자들은 오랜 시간을 들여 해결한다&quot;라며 &quot;<b>인공지능</b> 기술을 이해하고 사용하는 것은 이제 필수&quot;라고... ',
#    'pubDate': 'Mon, 24 Apr 2023 16:34:00 +0900'},
#   {'title': '“노인 돌봄 <b>인공지능</b> 개발” SKT ESG 얼라이언스 소셜세이프티넷팀',
#    'originallink': 'https://bravo.etoday.co.kr/view/atc_view/14497',
#    'link': 'https://bravo.etoday.co.kr/view/atc_view/14497',
#    'description': '브라보마이라이프=이준호 기자 | “미래 요양 서비스를 위한 필수 기술 될 것” 최근 사회 곳곳에서 <b>인공지능</b> 열풍이 불며 이제 막 대중화되는 것처럼 느껴지지만, 사실 우리 주변에서 그 역할을 시작한 것은 꽤... ',
#    'pubDate': 'Wed, 19 Apr 2023 08:44:00 +0900'},
#   {'title': '[에너지 칼럼] 거대<b>인공지능</b>과 초소형 핵융합로·원자로',
#    'originallink': 'https://www.iusm.co.kr/news/articleView.html?idxno=1013545',
#    'link': 'https://www.iusm.co.kr/news/articleView.html?idxno=1013545',
#    'description': '거대 <b>인공지능</b> 챗GPT 시대가 열렸다. 생성형 <b>인공지능</b>이라고 불리는 이 <b>인공지능</b>은 다양한 자연어 처리 능력을 바탕으로 인간의 창작물인 그림, 텍스트, 비디오 등 다양한 분야에서 실로 막강한 능력을 보이면서 그저... ',
#    'pubDate': 'Thu, 20 Apr 2023 20:32:00 +0900'},
#   {'title': '논산시, <b>인공지능</b> 시대 선도할 미래인재 교육 신설',
#    'originallink': 'http://www.daejonilbo.com/news/articleView.html?idxno=2058653',
#    'link': 'https://n.news.naver.com/mnews/article/656/0000048117?sid=102',
#    'description': '논산시가 <b>인공지능</b>(AI) 시대를 선도해나갈 미래인재 교육망 확장에 고삐를 당기고 있다. 백성현 시장은 4월 간부회의에서 &quot;AI와 코딩, 메타버스 등 미래 산업 맞춤형 인재교육을 활성화해야 한다&quot;는 당부사항을 전한 바... ',
#    'pubDate': 'Sun, 16 Apr 2023 19:23:00 +0900'},
#   {'title': '<b>인공지능</b>융합사업단 김준하 단장, &quot;앞으로 전문가는 초거대 AI를 잘 활용하는...',
#    'originallink': 'https://www.aitimes.kr/news/articleView.html?idxno=27840',
#    'link': 'https://www.aitimes.kr/news/articleView.html?idxno=27840',
#    'description': '김준하 <b>인공지능</b>산업융합사업단장이 20일 사업단 대회의실에서 광주 시민을 대상으로 3시간 동안 챗 GPT를 활용한 실습 강의 모습(사진:사업단) <b>인공지능</b>산업융합사업단(단장 김준하)이 광주 시민들을 대상으로 전... ',
#    'pubDate': 'Thu, 20 Apr 2023 16:44:00 +0900'},
#   {'title': '코드비전, <b>인공지능</b> &apos;예지보전&apos; 진입장벽 혁신적으로 낮춘다!',
#    'originallink': 'https://www.aitimes.kr/news/articleView.html?idxno=27855',
#    'link': 'https://www.aitimes.kr/news/articleView.html?idxno=27855',
#    'description': '국제<b>인공지능</b>대전(AI EXPO KOREA 2023)&apos;에 참가해 혁신적인 <b>인공지능</b>(AI) 기반 예지보전 솔루션을 선보인다. 코드비전의 <b>인공지능</b> 예지보전 솔루션은 데이터 취득부터 AI 모델 구축, 플랫폼까지 제공하는 토탈 서비스로... ',
#    'pubDate': 'Sun, 23 Apr 2023 09:52:00 +0900'},
#   {'title': '국제<b>인공지능</b>&amp;윤리협회-크라우드웍스, AI 및 AI윤리 공동 사업 협력 MOU 체결',
#    'originallink': 'https://www.sedaily.com/NewsView/29OC73I74F',
#    'link': 'https://n.news.naver.com/mnews/article/011/0004179744?sid=101',
#    'description': 'IAAE 국제<b>인공지능</b>&amp;윤리협회(이사장 전창배)는 AI 학습용 데이터 라벨링 1위 기업인 크라우드웍스(대표 박민우)와 ‘AI 및 AI윤리에 관한 공동 사업 협약’을 체결했다고 17일 밝혔다. 이번 업무 협약을 통해 양 기관은... ',
#    'pubDate': 'Mon, 17 Apr 2023 09:53:00 +0900'},
#   {'title': '<b>인공지능</b> 기반 개인 맞춤형 뇌 신경조절치료 효과 입증',
#    'originallink': 'https://www.khan.co.kr/national/health-welfare/article/202304100939011',
#    'link': 'https://n.news.naver.com/mnews/article/032/0003216297?sid=102',
#    'description': '■성빈센트·부천성모·서울성모 공동 연구팀 뇌 손상 환자에게 뇌 영상 분석 기술을 활용한 <b>인공지능</b>(AI) 개인 맞춤형 뇌 신경조절치료를 적용하면 뇌로 전달되는 자극이 기존 대비 20% 상승해 치료 효과를 높아지는... ',
#    'pubDate': 'Mon, 10 Apr 2023 09:40:00 +0900'},
#   {'title': '<b>인공지능</b>도 행정문서 사용할 수 있게 된다',
#    'originallink': 'http://www.boannews.com/media/view.asp?idx=117339&kind=',
#    'link': 'http://www.boannews.com/media/view.asp?idx=117339&kind=',
#    'description': '행안부, ‘행정 효율과 협업 촉진에 관한 규정’ 개정안 5월 31일까지 입법예고[보안뉴스 ] <b>인공지능</b>·데이터 기반의 디지털플랫폼정부를 실현하기 위해 행정 업무 방식을 획기적으로 개선한다. 행정문서를 사람과... ',
#    'pubDate': 'Fri, 21 Apr 2023 14:42:00 +0900'},
#   {'title': 'BGF복지재단, 경기도교육청과 <b>인공지능</b>(AI) 로봇 교육 지원',
#    'originallink': 'http://www.handmk.com/news/articleView.html?idxno=15876',
#    'link': 'http://www.handmk.com/news/articleView.html?idxno=15876',
#    'description': 'BGF복지재단 AI 로봇 지원 / BGF복지재단 제공 BGF복지재단이 경기도교육청과 함께 장애 학생들의 학습 참여도와 학업 성취도를 높이기 위해 <b>인공지능</b>(AI) 로봇 교육을 지원한다고 24일 밝혔다. BGF복지재단은 디지털 시대에... ',
#    'pubDate': 'Mon, 24 Apr 2023 13:10:00 +0900'},
#   {'title': '경기도, <b>인공지능</b> 활용한 게임 콘텐츠 제작 기업 공모...선정 1개사, 개발 지...',
#    'originallink': 'https://www.aitimes.kr/news/articleView.html?idxno=27806',
#    'link': 'https://www.aitimes.kr/news/articleView.html?idxno=27806',
#    'description': '도는 미래기술 분야(블록체인, <b>인공지능</b>(AI), 빅데이터, 클라우드, 메타버스, 가상·증강현실) 전문가와 경기도 중소게임기업 대표로 구성된 자문회의를 거쳐 이번 사업의 공모 주제를 선정했다. 공모 주제는 &apos;<b>인공지능</b>... ',
#    'pubDate': 'Mon, 17 Apr 2023 19:12:00 +0900'},
#   {'title': '경기도, <b>인공지능</b>(AI) 로봇 ‘알파미니’ 어린이집에 &apos;대여&apos;',
#    'originallink': 'https://www.dnews.co.kr/uhtml/view.jsp?idxno=202304130839223880206',
#    'link': 'https://www.dnews.co.kr/uhtml/view.jsp?idxno=202304130839223880206',
#    'description': '240개 어린이집 대화형 로봇 도입..다양한 체험 기회 제공 경기도가 어린이집 240개소에 <b>인공지능</b>(AI) 로봇을 대여해 영유아들에게 첨단기술을 경험할 기회를 제공한다. <b>인공지능</b>(AI) 로봇 대여사업은어린이집에서... ',
#    'pubDate': 'Thu, 13 Apr 2023 08:52:00 +0900'},
#   {'title': '경기도, <b>인공지능</b>(AI) 기술 활용한 게임 콘텐츠 제작 기업에 1억원 지원',
#    'originallink': 'https://ilyo.co.kr/?ac=article_view&entry_id=450514',
#    'link': 'https://ilyo.co.kr/?ac=article_view&entry_id=450514',
#    'description': '도는 미래기술 분야(블록체인, <b>인공지능</b>, 빅데이터, 클라우드, 메타버스, 가상·증강현실) 전문가와 경기도 중소게임기업 대표로 구성된 자문회의를 거쳐 이번 사업의 공모주제를 선정했다. 공모주제는 ‘<b>인공지능</b>(AI)... ',
#    'pubDate': 'Mon, 17 Apr 2023 08:48:00 +0900'},
#   {'title': '김제시립도서관서 11일, <b>인공지능</b> 챗GPT 활용 특강',
#    'originallink': 'http://sjbnews.com/news/news.php?number=777012',
#    'link': 'http://sjbnews.com/news/news.php?number=777012',
#    'description': '배움 아카데미 조석중 대표가 나서 시 직장인을 대상으로 이뤄지는 이 강연은 ▲ 대화형 <b>인공지능</b> 시대에 필요한 윤리와 교훈, ▲ 챗GPT 활용한 업무 연계 방안과 시연 등으로 진행된다. 특히, 챗GPT는 오픈 AI에서 개발한... ',
#    'pubDate': 'Mon, 10 Apr 2023 19:30:00 +0900'},
#   {'title': '<b>인공지능</b>이 환자에게 적합한 약을 찾는 방법',
#    'originallink': 'https://www.bbc.com/korean/international-65295853?xtor=AL-73-%5Bpartner%5D-%5Bnaver%5D-%5Bheadline%5D-%5Bkorean%5D-%5Bbizdev%5D-%5Bisapi%5D',
#    'link': 'https://www.bbc.com/korean/international-65295853?xtor=AL-73-%5Bpartner%5D-%5Bnaver%5D-%5Bheadline%5D-%5Bkorean%5D-%5Bbizdev%5D-%5Bisapi%5D',
#    'description': '제네티카플러스는 이를 위해 특정 인간세포를 성장시키는 최신 줄기세포 기술과 <b>인공지능</b>(AI) 소프트웨어를 결합했다. 사내 전문가가 환자의 혈액 샘플에서 뇌세포를 생성하고 여러 항우울제에 노출시켜 &quot;생체표지자... ',
#    'pubDate': 'Mon, 17 Apr 2023 12:11:00 +0900'},
#   {'title': '[동정]김외철 전 국무총리실 비서관, 한국<b>인공지능</b>협회 상근부회장에',
#    'originallink': 'https://www.seoul.co.kr/news/newsView.php?id=20230420500216&wlog_tag3=naver',
#    'link': 'https://n.news.naver.com/mnews/article/081/0003355402?sid=100',
#    'description': '사단법인 한국<b>인공지능</b>협회 상근부회장에 김외철 전 국무총리실 비서관이 임명됐다. 20일 한국<b>인공지능</b>협회에 따르면 김현철 회장은 지난 18일 김 상근부회장에게 임명장을 수여했다. 2017년 설립된... ',
#    'pubDate': 'Thu, 20 Apr 2023 17:39:00 +0900'},
#   {'title': '<b>인공지능</b>으로 연금투자 진단부터 설계, 컨설팅, 사후관리까지...하나은행, &apos;퇴...',
#    'originallink': 'https://www.aitimes.kr/news/articleView.html?idxno=27912',
#    'link': 'https://www.aitimes.kr/news/articleView.html?idxno=27912',
#    'description': '사진:하나은행 하나은행(은행장 이승열)은 퇴직연금(DC, IRP) 가입 손님의 목표 연금자산 형성을 위해 진단·설계·컨설팅·사후관리 서비스를 지원하는 &apos;AI 연금투자 솔루션&apos; 서비스를 28일부터 시작했다. AI 연금투자... ',
#    'pubDate': 'Sat, 29 Apr 2023 17:08:00 +0900'},
#   {'title': '키움증권, 영웅전 <b>인공지능</b> 종목 정보 신설',
#    'originallink': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1652912',
#    'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1652912',
#    'description': '키움증권이 &apos;영웅문S#&apos;을 통해 공개한 &apos;키움영웅전&apos; 3월 정규전 최고 수익률이 국내 1억리그 415%, 1백리그 738% 등을 기록한 가운데 4월 정규전부터는 참가자 프로필 보유종목에 <b>인공지능</b>(AI) 종목 정보가 추가된다.... ',
#    'pubDate': 'Tue, 11 Apr 2023 11:47:00 +0900'},
#   {'title': '구글 클라우드, 경북도와 손잡고 <b>인공지능</b> 인재 길러낸다',
#    'originallink': 'http://www.boannews.com/media/view.asp?idx=117247&kind=',
#    'link': 'http://www.boannews.com/media/view.asp?idx=117247&kind=',
#    'description': '안동대에 <b>인공지능</b>(AI) 진흥센터 열고, 글로벌 <b>인공지능</b>(AI) 인재 양성 사업 추진[보안뉴스 ] 경북도는 지난 18일 구글 클라우드(Google cloud)와 협약을 체결하고, 글로벌 <b>인공지능</b> 인재 양성에 나서기로 했다.우선 올... ',
#    'pubDate': 'Wed, 19 Apr 2023 15:02:00 +0900'},
#   {'title': 'SKT, 미래 AI 인재와 <b>인공지능</b> 기술 개발 나선다',
#    'originallink': 'https://www.hellot.net/news/article.html?no=76987',
#    'link': 'https://www.hellot.net/news/article.html?no=76987',
#    'description': '현업 개발자와 실무 과제 함께 연구하는 현장형 AI 인재 육성 프로그램 지원자 모집 SK텔레콤은 기업 현장에서 실제 진행 중인 연구과제 수행을 통해 <b>인공지능</b> 분야의 미래 인재를 육성하는 &apos;SKT AI 펠로우십(SKT AI... ',
#    'pubDate': 'Tue, 11 Apr 2023 14:12:00 +0900'},
#   {'title': '“우리 교수님은 AI?” 인천대, <b>인공지능</b> 강의 나왔다',
#    'originallink': 'https://news.kmib.co.kr/article/view.asp?arcid=0018132843&code=61121411&cp=nv',
#    'link': 'https://n.news.naver.com/mnews/article/005/0001599258?sid=102',
#    'description': '<b>인공지능</b>(AI) 전문 기업 딥브레인AI가 인천대와 협업해 김평원 국어교육과 교수(인천대 교육혁신원장)를 <b>인공지능</b> 가상인간으로 구현했다고 6일 밝혔다. 딥브레인AI는 김 교수의 강의를 토대로 대본을 제작해 딥러닝... ',
#    'pubDate': 'Thu, 06 Apr 2023 11:27:00 +0900'},
#   {'title': '차이커뮤니케이션, <b>인공지능</b>(A.I) 퍼포먼스 플랫폼 ‘CHAI GPC’ 출시',
#    'originallink': 'https://view.asiae.co.kr/article/2023041409315795847',
#    'link': 'https://n.news.naver.com/mnews/article/277/0005246259?sid=101',
#    'description': '디지털광고회사 ‘차이커뮤니케이션’이 미래의 성장동력 산업으로 꼽힌 A.I사업에 집중해 광고회사 최초로 ‘퍼포먼스 광고 데이터’를 활용한 <b>인공지능</b>(AI) 퍼포먼스 플랫폼 ‘CHAI GPC(Generative Pre-trained Creator)... ',
#    'pubDate': 'Mon, 17 Apr 2023 09:01:00 +0900'},
#   {'title': '[칼럼]<b>인공지능</b>이 논리적인 문제를 잘 풀 수 있는가?',
#    'originallink': 'https://www.newsclaim.co.kr/news/articleView.html?idxno=3017509',
#    'link': 'https://www.newsclaim.co.kr/news/articleView.html?idxno=3017509',
#    'description': '픽사베이 &quot;<b>인공지능</b>이 논리적인 문제를 잘 풀 수 있는가?&quot; 이 질문은 질문 자체에 문제가 있다. 층위가 다른 두 가지를 비교하고 있기 때문이다. 논리의 기본은 삼단논법이다. &apos;A면 B이다&apos;가 참이고 &apos;B이면 C이다&apos;가 참일 때... ',
#    'pubDate': 'Sat, 22 Apr 2023 19:16:00 +0900'},
#   {'title': '과기정통부 &apos;소프트웨어·<b>인공지능</b>(AI) 보편 교육체계 구축&apos;',
#    'originallink': 'https://www.yna.co.kr/view/PYH20230420073500013?input=1196m',
#    'link': 'https://n.news.naver.com/mnews/article/001/0013894291?sid=105',
#    'description': '강도현 과학기술정보통신부 정보통신정책실장이 지난 20일 세종시 정부세종청사에서 소프트웨어 진흥 전략 주요 내용을 설명하고 있다. 2023.4.21',
#    'pubDate': 'Fri, 21 Apr 2023 08:00:00 +0900'},
#   {'title': '한국<b>인공지능</b>협회, 첫 상근부회장에 김외철 전 총리실 비서관',
#    'originallink': 'http://news.heraldcorp.com/view.php?ud=20230419000564',
#    'link': 'https://n.news.naver.com/mnews/article/016/0002132524?sid=101',
#    'description': '한국<b>인공지능</b>협회(회장 김현철)는 상근부회장에 김외철(55·사진) 전 국무총리실 비서관을 임명했다. 김 상근부회장은 지난 30여년 동안 정당을 포함한 국회, 국무총리실, 경북도 등 중앙정부와 지방자치단체에서 폭넓게... ',
#    'pubDate': 'Wed, 19 Apr 2023 14:50:00 +0900'},
#   {'title': '<b>인공지능</b> 로봇 ‘알파미니’ 도내 어린이집에 한 달간 대여',
#    'originallink': 'https://www.asiatoday.co.kr/view.php?key=20230413010007756',
#    'link': 'https://www.asiatoday.co.kr/view.php?key=20230413010007756',
#    'description': '경기도가 도내 어린이집 240개소에 <b>인공지능</b>(AI) 로봇을 대여해 영유아들에게 첨단기술을 경험할 기회를 제공한다. 13일 경기도에 따르면 AI 로봇 대여사업은 도내 어린이집에서 대화형 로봇 &apos;알파미니&apos;의 체험을... ',
#    'pubDate': 'Thu, 13 Apr 2023 16:28:00 +0900'},
#   {'title': '<b>인공 지능</b>의 마스터스 전망…1R 마쓰야마·스피스 등 선두 예상',
#    'originallink': 'https://www.yna.co.kr/view/AKR20230406011500007?input=1195m',
#    'link': 'https://sports.news.naver.com/news.nhn?oid=001&aid=0013862893',
#    'description': '6일 개막하는 &apos;명인 열전&apos; 제87회 마스터스 토너먼트의 특징 가운데 하나는 <b>인공 지능</b>(AI)이 마스터스 인터넷 홈페이지에서 대회 결과를 예상한다는 점이다. 마스터스 홈페이지에는 IBM이 <b>인공 지능</b>을 활용해 참가 선수... ',
#    'pubDate': 'Thu, 06 Apr 2023 06:43:00 +0900'},
#   {'title': '용인세브란스, <b>인공지능</b> 기반 흉부 방사선 영상 분석 효용성 입증',
#    'originallink': 'http://www.doctorstimes.com/news/articleView.html?idxno=222554',
#    'link': 'http://www.doctorstimes.com/news/articleView.html?idxno=222554',
#    'description': '국내 의료진이 <b>인공지능</b>(AI) 기반 흉부 방사선 영상 분석의 임상적 효용성을 입증했다. 용인세브란스병원 호흡기·알레르기내과 곽세현·이은혜 교수, 영상의학과 신현주 교수 연구팀이 연구를 진행, 결과를 발표했다.... ',
#    'pubDate': 'Tue, 18 Apr 2023 14:14:00 +0900'},
#   {'title': '김동연, 美서 세계적 석학들과 열띤 토론…&apos;<b>인공지능</b> 수도&apos; 포부 밝혀',
#    'originallink': 'http://moneys.mt.co.kr/news/mwView.php?no=2023041316480174477',
#    'link': 'https://n.news.naver.com/mnews/article/417/0000912702?sid=102',
#    'description': '김동연 경기도지사가 세계적인 석학들과 &apos;<b>인공지능</b> 수도&apos;를 만들겠다고 다짐했다. 김 지사는 &apos;청년기회&apos;와 해외투자 유치를 위해 미국을 순방중인 가운데 13일 자신의 SNS를 통해 &quot;AI 분야의 4대 천황이라고 불리는... ',
#    'pubDate': 'Thu, 13 Apr 2023 17:16:00 +0900'},
#   {'title': '<b>인공지능</b>(AI) 의료 솔루션 아르헨티나 인허가 획득',
#    'originallink': 'https://www.dailymedi.com/news/news_view.php?wr_id=896852',
#    'link': 'https://www.dailymedi.com/news/news_view.php?wr_id=896852',
#    'description': '\ufeff\ufeff의료 <b>인공지능</b>(AI) 솔루션 기업 제이엘케이(대표 김동민)는 아르헨티나 식품의약품의학기술청(ANMAT) 으로부터 제품 5개 솔루션에 대한 의료기기 인허가를 획득했다고 20일 밝혔다. 이번에 인허가 획득 제품은... ',
#    'pubDate': 'Fri, 21 Apr 2023 08:48:00 +0900'},
#   {'title': '알리바바 클라우드, 생성 <b>인공지능</b> 모델 &apos;통이치엔원 파트너십 프로그램&apos; 발표',
#    'originallink': 'https://www.aitimes.kr/news/articleView.html?idxno=27886',
#    'link': 'https://www.aitimes.kr/news/articleView.html?idxno=27886',
#    'description': '생성 <b>인공지능</b>(Generative AI) 모델 &apos;통이치엔원(通义千问, Tongyi Qianwen)&apos;을 각 산업 분야에 맞춘 대규모 언어 모델을 파트너들과 함께 공동 개발하는 &apos;통이치엔원 파트너십 프로그램&apos;을 25일, 발표했다. 이... ',
#    'pubDate': 'Wed, 26 Apr 2023 19:22:00 +0900'},
#   {'title': '일론 머스크, <b>인공지능</b> 회사 X.AI 차렸다...오픈AI와 경쟁?',
#    'originallink': 'http://www.digitaltoday.co.kr/news/articleView.html?idxno=474148',
#    'link': 'http://www.digitaltoday.co.kr/news/articleView.html?idxno=474148',
#    'description': '일론 머스크가 엑스닷에이아이(X.AI)를 설립했다 [사진: 셔터스톡] 일론 머스크 테슬라 및 트위터 CEO가 <b>인공지능</b>(AI) 회사 엑스닷에이아이(X.AI)를 미국 네바다 주에 설립했다고 파이낸셜타임스, 월스트리트저널(WSJ)... ',
#    'pubDate': 'Sat, 15 Apr 2023 07:54:00 +0900'},
#   {'title': 'KT그룹사, <b>인공지능</b> 등 기술 결집과 DX업무혁신 위한 &apos;2023 그룹DX원팀&apos;',
#    'originallink': 'https://www.aitimes.kr/news/articleView.html?idxno=27846',
#    'link': 'https://www.aitimes.kr/news/articleView.html?idxno=27846',
#    'description': '올해로 3년째를 맞는 &apos;그룹 DX 원팀&apos;은 KT그룹사들의 디지털전환(DX) 업무 혁신과 <b>인공지능</b>(AI)·로봇프로세스자동화(RPA) 역량 제고를 위해 그룹사 스스로 과제 발굴과 수행을 할 수 있도록 코칭과 실습 교육을... ',
#    'pubDate': 'Fri, 21 Apr 2023 09:50:00 +0900'},
#   {'title': '국방부, &quot;<b>인공지능</b> 강군육성의 핵심인 국방데이터 체계적 구축 필요&quot;',
#    'originallink': 'http://www.konas.net/article/article.asp?idx=60664',
#    'link': 'http://www.konas.net/article/article.asp?idx=60664',
#    'description': '국방부는 19일 신범철 국방부차관 주관으로 제2차 국방데이터관리위원회를 개최하고 <b>인공지능</b>(AI) 강군 육성의 핵심자산인 국방 데이터를 체계적으로 구축하고 활용하기 위한 정책 방향을 논의했다고 밝혔다.... ',
#    'pubDate': 'Wed, 19 Apr 2023 14:32:00 +0900'},
#   {'title': '논산시, <b>인공지능</b> 시대 선도할 미래인재 교육 신설',
#    'originallink': 'https://daily.hankooki.com/news/articleView.html?idxno=946198',
#    'link': 'https://daily.hankooki.com/news/articleView.html?idxno=946198',
#    'description': '사진=논산시 제공  논산시(시장 백성현)가 <b>인공지능</b>(AI) 시대를 선도해나갈 미래인재 교육망 확장에 고삐를 당기고 있다고 14일 밝혔다. 백성현 시장은 4월 간부회의에서 &quot;AI와 코딩, 메타버스 등 미래 산업 맞춤형... ',
#    'pubDate': 'Fri, 14 Apr 2023 16:28:00 +0900'},
#   {'title': '&apos;아리아 살려줘&apos;…<b>인공지능</b> 스피커가 생명 구했다',
#    'originallink': 'https://news.imaeil.com/page/view/2023041016312233476',
#    'link': 'https://n.news.naver.com/mnews/article/088/0000808146?sid=102',
#    'description': '10일 구미시에 따르면 지난 6일 구미 인동동에 홀로 거주하는 남성 A(78) 씨가 <b>인공지능</b>(AI) 스피커를 이용해 응급구조되는 일이 발생했다. A 씨는 오전 5시 18분쯤 자고 일어난 뒤 갑자기 마비 증상이 생겼고, 집안에 설치된... ',
#    'pubDate': 'Mon, 10 Apr 2023 16:42:00 +0900'},
#   {'title': '최첨단 <b>인공지능</b>기반 MRI 갖춘 계명대 대구동산병원',
#    'originallink': 'http://www.fnnews.com/news/202304120729078902',
#    'link': 'https://n.news.naver.com/mnews/article/014/0004995464?sid=102',
#    'description': '계명대 대구동산병원이 최첨단 <b>인공지능</b>기반 MRI를 도입, 본격 운영에 들어갔다. 12일 계명대 대구동산병원에 따르면 지난 7일 본관 1층 영상의학과에서최첨단 3.0T(지멘스 헬시니어스社 Magnetom Lumina) MRI 도입... ',
#    'pubDate': 'Wed, 12 Apr 2023 07:53:00 +0900'},
#   {'title': '김준하 <b>인공지능</b>산업융합사업단장, 광주시 공무원 대상 챗GPT 강연… &quot;AI 기술...',
#    'originallink': 'https://kr.aving.net/news/articleView.html?idxno=1778307',
#    'link': 'https://kr.aving.net/news/articleView.html?idxno=1778307',
#    'description': '광주광역시(시장 강기정)는 정보화 담당 공무원을 대상으로 생성형 <b>인공지능</b>(AI) &apos;챗GPT&apos;(ChatGPT)를 활용한 교육을 17일 실시했다. 이번 교육에는 김준하 <b>인공지능</b>산업융합사업단장이 연사로 나서 <b>인공지능</b> 챗봇인... ',
#    'pubDate': 'Mon, 17 Apr 2023 15:56:00 +0900'},
#   {'title': '배재대, 대전 초‧중‧고에 <b>인공지능</b>‧소프트웨어 전파',
#    'originallink': 'https://daily.hankooki.com/news/articleView.html?idxno=944429',
#    'link': 'https://daily.hankooki.com/news/articleView.html?idxno=944429',
#    'description': '사진=배재대 제공  배재대학교(총장 김욱) 학생‧교직원이 대전지역 초‧중‧고교에 <b>인공지능</b>‧소프트웨어 교육 도우미로 활약한다. 배재대 AI‧SW중심대학사업단(단장 정회경)은 10일 대학 스마트배재관에서 학생... ',
#    'pubDate': 'Tue, 11 Apr 2023 09:22:00 +0900'},
#   {'title': '서초구, 우범지대에 ‘<b>인공지능</b> CCTV’···“범죄행동 자동감지”[서울25]',
#    'originallink': 'https://www.khan.co.kr/local/Seoul/article/202304111408001',
#    'link': 'https://n.news.naver.com/mnews/article/032/0003216608?sid=102',
#    'description': '서울 서초구는 지역 범죄 위험 신호를 감지하고 사건·사고를 예방하기 위해 폐쇄회로(CC)TV 영상 분석에 <b>인공지능</b>(AI) 기술을 적용한 ‘<b>지능</b>형 선별관제시스템’을 운영한다고 11일 밝혔다. 장시간 배회와 폭행, 주택... ',
#    'pubDate': 'Tue, 11 Apr 2023 14:10:00 +0900'},
#   {'title': '<b>인공지능</b>協 상근부회장에 김외철',
#    'originallink': 'https://www.hankyung.com/society/article/2023041995031',
#    'link': 'https://n.news.naver.com/mnews/article/015/0004834858?sid=102',
#    'description': '한국<b>인공지능</b>협회는 19일 상근부회장에 김외철 전 국무총리실 비서관(사진)을 임명했다. 그는 정당, 국회, 국무총리실에 몸담았고 경상북도 개방형 1호 서울본부장 등을 지냈다.',
#    'pubDate': 'Wed, 19 Apr 2023 17:55:00 +0900'},
#   {'title': '경기도, <b>인공지능</b> 기술 활용 게임 콘텐츠 제작 기업에 1억원 지원',
#    'originallink': 'https://www.newscj.com/news/articleView.html?idxno=3018883',
#    'link': 'https://www.newscj.com/news/articleView.html?idxno=3018883',
#    'description': '도는 미래기술 분야(블록체인, <b>인공지능</b>, 빅데이터, 클라우드, 메타버스, 가상·증강현실) 전문가와 경기도 중소 게임기업 대표로 구성된 자문회의를 거쳐 이번 사업의 공모 주제를 선정했다. 공모 주제는 &apos;<b>인공지능</b>(AI)... ',
#    'pubDate': 'Mon, 17 Apr 2023 14:08:00 +0900'},
#   {'title': '구로구, 4차산업 분야 특강 &apos;AI <b>인공지능</b> 기술 이해&apos; 실시',
#    'originallink': 'http://www.gvalley.co.kr/news/articleView.html?idxno=609429',
#    'link': 'http://www.gvalley.co.kr/news/articleView.html?idxno=609429',
#    'description': '사진=4차산업분야 특강에서 인사말하는 문헌일구청장 G밸리뉴스 김가람 기자 =  구로구(구청장 문헌일)가 지난 21일 4차 산업혁명 시대에 필요한 역량을 강화하기 위해 &apos;그림으로 배우는 AI <b>인공지능</b> 기술 이해&apos; 특강을... ',
#    'pubDate': 'Tue, 25 Apr 2023 12:10:00 +0900'},
#   {'title': '<b>인공지능</b> 모빌리티 시대가 온다',
#    'originallink': 'http://sjbnews.com/news/news.php?number=777088',
#    'link': 'http://sjbnews.com/news/news.php?number=777088',
#    'description': '이 시기에 “모빌리티 기술혁명 미래보고서 2030”은 다보스포럼 회장인 클라우스 슈밥이 주장한 4차산업혁명의 핵심을 ‘<b>인공지능</b>AI, 로봇공학, 사물인터넷, 자율주행차, 3D프린팅, 나노기술’과 같이 6대 분야의... ',
#    'pubDate': 'Mon, 10 Apr 2023 19:30:00 +0900'},
#   {'title': '시야인사이트, 데이터와 <b>인공지능</b> 더한 국민안전플랫폼 &apos;세이브피플&apos; 선보인다',
#    'originallink': 'https://www.aitimes.kr/news/articleView.html?idxno=27899',
#    'link': 'https://www.aitimes.kr/news/articleView.html?idxno=27899',
#    'description': '플랫폼 및 로고 이미지 <b>지능</b>형 모니터링 전문기업 시야인사이트(대표 임형준)은 오는 5월 10일부터 12일까지 서울 삼성동 COEX에서 아시아 최대로 개최되는 &apos;제6회 국제<b>인공지능</b>대전(AI EXPO KOREA 2023)&apos;에 참가해 데이터와... ',
#    'pubDate': 'Fri, 28 Apr 2023 09:18:00 +0900'},
#   {'title': 'AI(<b>인공지능</b>) 일자리도 늘렸다...지난해 미국 AI관련 일자리 100% 폭증',
#    'originallink': 'http://www.fnnews.com/news/202304060706047412',
#    'link': 'https://n.news.naver.com/mnews/article/014/0004992645?sid=105',
#    'description': 'OpenAI의 AI챗봇 &apos;챗GPT&apos;로 인해 전 세계에서 AI(<b>인공지능</b>)에 대한 관심이 커지고 있는 가운데 AI가 일자리도 늘릴 수 있을 지 주목된다. 지난해 미국에서 AI 관련 일자리가 전년 대비 100%나 급증하면서다. 5일... ',
#    'pubDate': 'Thu, 06 Apr 2023 07:13:00 +0900'},
#   {'title': '<b>인공지능</b> 챗 GPT에 대한 창의성…미래 사회는 어떤 모습',
#    'originallink': 'https://www.sedaily.com/NewsView/29O9VQU7R8',
#    'link': 'https://n.news.naver.com/mnews/article/011/0004177963?sid=102',
#    'description': '국립광주과학관은 한국과총 광주전남지역연합회와 공동으로 오는 15일 국립광주과학관 상상홀에서 ‘<b>인공지능</b> 챗 GPT 시대, 진정한 창의성이란?’을 주제로 제2회 <b>인공지능</b>오딧세이 포럼을 개최한다고 12일 밝혔다.... ',
#    'pubDate': 'Wed, 12 Apr 2023 08:49:00 +0900'},
#   {'title': '광주시, <b>인공지능</b>·문화예술 양 날개로 도시 외교 확대',
#    'originallink': 'https://www.yna.co.kr/view/AKR20230410085000054?input=1195m',
#    'link': 'https://n.news.naver.com/mnews/article/001/0013870319?sid=102',
#    'description': '광주시가 <b>인공지능</b>(AI)과 문화예술을 매개로 도시 외교 보폭을 넓혀가고 있다. 10일 광주시에 따르면 지난해 7월 민선 8기 출범 이후 강기정 시장은 필립 골드버그 주한 미국 대사를 시작으로 독일, 일본, 중국, 영국... ',
#    'pubDate': 'Mon, 10 Apr 2023 14:06:00 +0900'},
#   {'title': '국립광주과학관, 제2회 <b>인공지능</b>오딧세이 포럼',
#    'originallink': 'https://view.asiae.co.kr/article/2023041209061957012',
#    'link': 'https://n.news.naver.com/mnews/article/277/0005244236?sid=102',
#    'description': '국립광주과학관과 한국과총 광주전남지역연합회가 오는 15일 과학관 상상홀에서 ‘<b>인공지능</b> 챗 GPT 시대, 진정한 창의성이란?’을 주제로 제2회 <b>인공지능</b> 오디세이 포럼을 개최한다. 해당 포럼은 최근 과학기술계 최대... ',
#    'pubDate': 'Wed, 12 Apr 2023 09:07:00 +0900'},
#   {'title': '충북대 산업<b>인공지능</b>연구센터, 인재양성대전 참여',
#    'originallink': 'http://www.jbnews.com/news/articleView.html?idxno=1391626',
#    'link': 'http://www.jbnews.com/news/articleView.html?idxno=1391626',
#    'description': '［중부매일 이지효 기자］ 충북대학교(총장 고창섭) 산업<b>인공지능</b>연구센터가 지난 19일부터 21일까지 서울 코엑스에서 진행된 &apos;ITRC 인재양성대전 2023&apos;에 참가해 산업<b>인공지능</b>연구센터의 연구활동을 선보였다.... ',
#    'pubDate': 'Sun, 23 Apr 2023 14:28:00 +0900'},
#   {'title': '[대덕특구 출범 50주년 과학의날 특집] 경계 확장하는 한의학… <b>인공지능</b>·IC...',
#    'originallink': 'https://www.cctoday.co.kr/news/articleView.html?idxno=2176643',
#    'link': 'https://www.cctoday.co.kr/news/articleView.html?idxno=2176643',
#    'description': '이제는 융합연구의 시대를 맞아, <b>인공지능</b>, ICT와의 융합을 통해 한의학의 원리와 효능을 과학적으로 규명하고, 그 경계를 계속해서 확장하며 새로운 미래융합의학을 만들어 가고 있다. 그동안 한의학연은 침 치료의 효과와... ',
#    'pubDate': 'Thu, 20 Apr 2023 15:36:00 +0900'},
#   {'title': '(금요아침)아니 땐 굴뚝에 연기를 그리는 <b>인공지능</b>',
#    'originallink': 'https://www.electimes.com/news/articleView.html?idxno=318646',
#    'link': 'https://www.electimes.com/news/articleView.html?idxno=318646',
#    'description': '&apos;스테이블 디퓨전(Stable Diffusion)&apos;이란 <b>인공지능</b>을 이용해서 실제 사진에 가까운 수준의 이미지를 필자가 직접 최초로 생성하는데 걸린 시간이다. 카카오톡을 통해서 해당 이미지를 지인들에게 말없이 공개했을 때 실제... ',
#    'pubDate': 'Thu, 20 Apr 2023 10:52:00 +0900'},
#   {'title': '경기도, ‘생성형 <b>인공지능</b>·공공데이터 활용 창업경진대회’ 참여작 모집',
#    'originallink': 'http://www.mediagunpo.co.kr/16078',
#    'link': 'http://www.mediagunpo.co.kr/16078',
#    'description': '이번 경진대회는 행정·안전·복지 등 다양한 공공데이터와 생성형 <b>인공지능</b>(Genrative AI) 기술을 결합한 창의적 아이디어 혹은 제품·서비스를 발굴하고, 더 나아가 <b>인공지능</b>과 공공데이터에 기반한 창업 문화를... ',
#    'pubDate': 'Wed, 26 Apr 2023 09:12:00 +0900'},
#   {'title': '&apos;어서와 한국은 처음이지&apos; 다음 나라는 스위스…정수센터 방문→<b>인공지능</b> 활용',
#    'originallink': 'http://www.topstarnews.net/news/articleView.html?idxno=15328131',
#    'link': 'http://www.topstarnews.net/news/articleView.html?idxno=15328131',
#    'description': '그레고는 <b>인공 지능</b>과 함께하는 여행을 선언했다. 하지만 식당을 물어보자 <b>인공 지능</b>이라 배가 고프지 않다고 답하는가 하면 온라인에서 찾아보라는 답변에 당황하기도 한다. &apos;어서와 한국은 처음이지&apos;는 한국에서 여러... ',
#    'pubDate': 'Wed, 26 Apr 2023 16:54:00 +0900'},
#   {'title': '세종시교육청, &apos;챗GPT&apos; 및 <b>인공지능</b> 교육자료 개발·보급',
#    'originallink': 'https://www.ccdailynews.com/news/articleView.html?idxno=2197690',
#    'link': 'https://www.ccdailynews.com/news/articleView.html?idxno=2197690',
#    'description': '▲ 초중고 <b>인공지능</b> 및 메타버스 교육자료./세종시교육청 제공 세종시교육청은 대화형 <b>인공지능</b> 도구 &apos;챗GPT&apos;의 성능 향상과 사용자 급증에 따라 학교 현장에서의 활용방안을 담은 도움 자료 &apos;문답의 시대, 챗GPT&apos;를 개발... ',
#    'pubDate': 'Tue, 11 Apr 2023 16:06:00 +0900'},
#   {'title': '&quot;<b>인공지능</b> 배워서 해외연수 가 볼래요?&quot;',
#    'originallink': 'http://www.mediajeju.com/news/articleView.html?idxno=344030',
#    'link': 'http://www.mediajeju.com/news/articleView.html?idxno=344030',
#    'description': '이번 프로그램은 △공통 기초 과정(파이썬 기초, <b>인공지능</b> 기초, 30시간) △역량강화 과정(컴퓨터 비전, 음성 및 자연어처리, 50시간) 등으로 이뤄졌다. 역량 과정 수료 후 40명을 선발하게 되며, 이들 학생은 20시간의... ',
#    'pubDate': 'Mon, 17 Apr 2023 14:16:00 +0900'},
#   {'title': '챗GPT 시대…가장 ‘완벽한 답’ 찾기 위한 혁신 필요 [<b>인공지능</b> 챗GPT 포럼]',
#    'originallink': 'https://www.kyeonggi.com/article/20230420580286',
#    'link': 'https://n.news.naver.com/mnews/article/666/0000009350?sid=103',
#    'description': '20일 오전 경기일보 대회의실에서 열린 <b>인공지능</b> 챗-GPT 포럼에서 참석자들이 토론을 벌이고 있다. 이번 포럼은 &apos;<b>인공지능</b> 챗-GPT 조력자인가? 파괴자인가?&apos;를 주제로 열렸다. 윤원규기자 챗 GPT로 촉발된 <b>인공지능</b>(AI) 시대를... ',
#    'pubDate': 'Thu, 20 Apr 2023 20:28:00 +0900'},
#   {'title': '광주 <b>인공지능</b> 사관학교 330명 모집에 778명 지원…2.4대 1',
#    'originallink': 'https://www.news1.kr/articles/5004668',
#    'link': 'https://n.news.naver.com/mnews/article/421/0006727274?sid=102',
#    'description': '광주 <b>인공지능</b> 사관학교 4기 교육생 모집에 서울과 부산, 제주 등 전국에서 지원자가 몰렸다. 4일 <b>인공지능</b>산업융합사업단에 따르면 AI 사관학교 4기 교육생 330명 모집에 779명이 지원해 2.4 대 1의 경쟁률을... ',
#    'pubDate': 'Tue, 04 Apr 2023 17:31:00 +0900'},
#   {'title': '[AI 프리즘] 생성형 AI가 연 새로운 시대 &apos;불안한 일자리&apos;... AI 전문가들이 ...',
#    'originallink': 'http://www.wikileaks-kr.org/news/articleView.html?idxno=137830',
#    'link': 'http://www.wikileaks-kr.org/news/articleView.html?idxno=137830',
#    'description': '이와 관련, &apos;더 컨버세이션(The conversation)&apos;은 AI 전문가들과 함께 <b>인공지능</b> 시대의 새로운 흐름과, 사라지는 일자리문제 대책 등 5가지 요소를 진단했다. ▷ 생성형 AI와 일자리 관계는 생성형 AI는 아티스트나 지식... ',
#    'pubDate': 'Fri, 28 Apr 2023 05:50:00 +0900'},
#   {'title': '중앙대, 오는 28일 &apos;<b>인공지능</b>의 몸과 노동&apos; 학술대회 개최',
#    'originallink': 'https://www.news1.kr/articles/5005606',
#    'link': 'https://n.news.naver.com/mnews/article/421/0006729032?sid=102',
#    'description': '중앙대학교는 오는 28일 오후 중앙대 서울캠퍼스 310관에서 제27회 <b>인공지능</b>인문학 국내학술대회를 연다고 5일 밝혔다. <b>인공지능</b>인문학 국내학술대회는 중앙대 인문콘텐츠연구소 HK+<b>인공지능</b>인문학사업단이 교육부와... ',
#    'pubDate': 'Wed, 05 Apr 2023 14:04:00 +0900'},
#   {'title': '<b>인공지능</b> 기반 CCTV 영상분석으로 교통 체증 해소, 도로안전 수준 높인다',
#    'originallink': 'http://www.boannews.com/media/view.asp?idx=117235&kind=',
#    'link': 'http://www.boannews.com/media/view.asp?idx=117235&kind=',
#    'description': '<b>인공지능</b> CCTV 이미지 분석해 차량 12종 구분해 차선별 통행량 파악...정확도 94% 수준[보안뉴스 ] 전국 도로에 설치된 CCTV 영상을 <b>인공지능</b>(AI)이 분석해 차종과 교통량을 자동으로 파악할 수 있는 데이터 분석모델이... ',
#    'pubDate': 'Wed, 19 Apr 2023 15:48:00 +0900'},
#   {'title': 'SKT, 차세대 <b>인공지능</b> 기술 개발 나선다',
#    'originallink': 'https://www.nbntv.kr/news/articleView.html?idxno=69722',
#    'link': 'https://www.nbntv.kr/news/articleView.html?idxno=69722',
#    'description': 'SKT가 미래 AI 인재들과 <b>인공지능</b> 기술로 세상을 바꾸기 위한 프로젝트에 나선다. [사진=SKT] SKT가 미래 AI 인재들과 <b>인공지능</b> 기술로 세상을 바꾸기 위한 프로젝트에 나선다. SK텔레콤은 기업 현장에서 실제 진행 중인... ',
#    'pubDate': 'Tue, 11 Apr 2023 13:18:00 +0900'},
#   {'title': '[중앙시평] <b>인공지능</b> 개발을 멈춰야 할까?',
#    'originallink': 'https://www.joongang.co.kr/article/25154048',
#    'link': 'https://n.news.naver.com/mnews/article/025/0003272193?sid=110',
#    'description': '<b>인공지능</b> 분야의 문외한 주제에 내놓아 본 의견이었는데, 최근 그 분야의 많은 전문가들이 이와 비슷한 입장을 발표했다. 전기차업체 테슬라와 우주탐사기업 스페이스엑스의 창업주 일론 머스크가 설립한 ‘삶의 미래... ',
#    'pubDate': 'Tue, 11 Apr 2023 01:00:00 +0900'},
#   {'title': '인간과 대화할 수 있게 된 <b>인공지능</b>, 다음 순서는 ‘자아’일까',
#    'originallink': 'https://www.hani.co.kr/arti/science/science_general/1087533.html',
#    'link': 'https://n.news.naver.com/mnews/article/028/0002635420?sid=105',
#    'description': '하지만 이는 잠시 미뤄두고 이번 칼럼부터는 두뇌와 <b>인공지능</b> 관점을 다룰 것이다. 뜬금없는 도약으로 느껴지겠지만, 원래 커넥션 시리즈의 후반에서 두뇌를 모방한 <b>인공 지능</b>과 그 한계를 다룰 예정이었다. 우리 두뇌는... ',
#    'pubDate': 'Wed, 12 Apr 2023 10:03:00 +0900'},
#   {'title': '아이메디신, 2023 월드IT쇼서 <b>인공지능</b> 기반 디지털 멘탈 헬스케어 플랫폼 소...',
#    'originallink': 'https://kr.aving.net/news/articleView.html?idxno=1778725',
#    'link': 'https://kr.aving.net/news/articleView.html?idxno=1778725',
#    'description': '아이메디신은 2012년 설립한 <b>인공지능</b> 기반 &apos;디지털 멘탈 헬스케어 플랫폼&apos; 전문기업이다. 아이메디신이 제공하는 멘탈 헬스케어 방식은 헬멧 형태의 디바이스(iSyncWave)를 착용해 뇌파를 스캔하고 이를 바탕으로... ',
#    'pubDate': 'Fri, 28 Apr 2023 14:04:00 +0900'},
#   {'title': '“<b>인공지능</b> 길들이기”…‘챗GPT’ 광주시민 무료 실습 교육 눈길',
#    'originallink': 'http://www.kwangju.co.kr/article.php?aid=1681979740751400004',
#    'link': 'http://www.kwangju.co.kr/article.php?aid=1681979740751400004',
#    'description': '<b>인공지능</b>산업융합사업단이 광주시민을 대상으로 <b>인공지능</b>(AI) 기반 챗봇인 ‘챗 GPT’에 대한 무료 실습 기회를 제공해 큰 호응을 얻고 있다. 김준하 <b>인공지능</b>산업융합사업단장은 20일 광주 북구... ',
#    'pubDate': 'Thu, 20 Apr 2023 17:38:00 +0900'},
#   {'title': '건국대, 반도체·<b>인공지능</b> 등 2학기 17개 분야 교수 초빙',
#    'originallink': 'https://dhnews.co.kr/news/view/1065596975223198',
#    'link': 'https://dhnews.co.kr/news/view/1065596975223198',
#    'description': '21일 건국대에 따르면 초빙분야는 공과대학에서 ▲건설재료(사회환경공학부) ▲반도체 및 에너지 소재(화학공학부) ▲<b>인공지능</b>/정보보호(암호학 제외)/컴파일러/프로그래밍언어론(컴퓨터공학부) ▲실감미디어/가상... ',
#    'pubDate': 'Fri, 21 Apr 2023 16:34:00 +0900'},
#   {'title': '경기도, <b>인공지능</b>(AI) 기술 활용한 게임 콘텐츠 제작 기업에 1억 지원',
#    'originallink': 'http://www.econonews.co.kr/news/articleView.html?idxno=283736',
#    'link': 'http://www.econonews.co.kr/news/articleView.html?idxno=283736',
#    'description': '경기도는 미래기술 분야(블록체인, <b>인공지능</b>, 빅데이터, 클라우드, 메타버스, 가상·증강현실) 전문가와 경기도 중소게임기업 대표로 구성된 자문회의를 거쳐 이번 사업의 공모 주제를 선정했다고 설명했다. 공모... ',
#    'pubDate': 'Mon, 17 Apr 2023 15:52:00 +0900'}]}

# %%
# str임
print(type(response_body.decode('utf-8')))
print(response_body.decode('utf-8'))
# Out:
# <class 'str'>
# {
# 	"lastBuildDate":"Thu, 04 May 2023 12:35:56 +0900",
# 	"total":1739155,
# 	"start":901,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"컴투버스, 셀바스AI와 메타버스내 <b>인공지능<\/b> 기술·사업 맞손",
# 			"originallink":"http:\/\/www.newsdream.kr\/news\/articleView.html?idxno=41840",
# 			"link":"http:\/\/www.newsdream.kr\/news\/articleView.html?idxno=41840",
# 			"description":"컴투버스는 이번 협약을 바탕으로 셀바스AI와 함께 메타버스 인프라스트럭처로 설계되는 컴투버스를 위해, <b>인공지능<\/b> 기술 및 서비스 개발에 대한 전략적 협력을 추진할 계획이다. 또한 셀바스AI와 2분기 첫 선을 보이는... ",
# 			"pubDate":"Tue, 18 Apr 2023 10:54:00 +0900"
# 		},
# 		{
# 			"title":"&apos;투자 온도계&apos; 더한 <b>인공지능<\/b> 자산관리",
# 			"originallink":"https:\/\/www.bloter.net\/news\/articleView.html?idxno=600662",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/293\/0000043417?sid=101",
# 			"description":"AI(<b>인공지능<\/b>) 자동투자 콴텍이 하나은행의 AI자산관리 플랫폼 &apos;아이웰스&apos;를 통해 &apos;금융시장 투자 온도계(SMART Index)&apos; 서비스를 제공한다. 14일 콴텍에 따르면 하나은행과 제휴해 선보이는 금융시장 투자 온도계는 그간... ",
# 			"pubDate":"Fri, 14 Apr 2023 18:06:00 +0900"
# 		},
# 		{
# 			"title":"컴투버스, 셀바스AI와 메타버스 내 <b>인공지능<\/b> 기술·사업 협력",
# 			"originallink":"https:\/\/www.tokenpost.kr\/article-129720",
# 			"link":"https:\/\/www.tokenpost.kr\/article-129720",
# 			"description":"셀바스AI는 음성인식, 음성합성, 필기인식, 광학문자인식, 자연어 처리 등 최고 수준의 인간과 컴퓨터 간 상호작용(HCI, Human Computer Interaction) 기술을 기반으로 한 <b>인공지능<\/b> 전문 기업으로, 교육, 의료, 금융, 문화... ",
# 			"pubDate":"Tue, 18 Apr 2023 09:30:00 +0900"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 기술로 리튬이온배터리 수명 진단",
# 			"originallink":"https:\/\/www.dongascience.com\/news\/view\/59294",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/584\/0000022587?sid=105",
# 			"description":"<b>인공지능<\/b>(AI)을 구현하는 딥러닝 기술을 활용해 배터리의 수명과 관련한 일부 데이터만으로도 정확한 수명을 예측할 수 있다. 진단 시 필요한 시간과 비용을 절감해 폐배터리의 재활용 효율을 높일 것으로 기대된다.... ",
# 			"pubDate":"Thu, 06 Apr 2023 13:53:00 +0900"
# 		},
# 		{
# 			"title":"김외철 (사)한국<b>인공지능<\/b>협회 상근부회장 임명",
# 			"originallink":"https:\/\/news.imaeil.com\/page\/view\/2023041917093711685",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/088\/0000809783?sid=004",
# 			"description":"김외철 전 경상북도 서울본부장이 지난 18일 (사)한국<b>인공지능<\/b>협회 상근부회장에 임명됐다. 옛 한나라당 당직자 출신인 그는 국회 정책연구위원, 제18대 대통령직인수위원회 전문위원, 국무총리실 정무비서관 등을... ",
# 			"pubDate":"Wed, 19 Apr 2023 17:14:00 +0900"
# 		},
# 		{
# 			"title":"전남교육청, 대화형 <b>인공지능<\/b> 챗봇활용 안내서 배부",
# 			"originallink":"https:\/\/www.sportsseoul.com\/news\/read\/1304252?ref=naver",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/468\/0000935715?sid=102",
# 			"description":"챗봇활용 안내서= 전남교육청 제공 전라남도교육청이 대화형 <b>인공지능<\/b> 챗봇 활용 교육용 안내서를 제작해 최근 각급 학교에 배부했다. 대화형 <b>인공지능<\/b> 챗봇 중 하나인 ChatGPT는 OpenAI가 개발한 대화형 <b>인공지능<\/b>... ",
# 			"pubDate":"Wed, 12 Apr 2023 13:56:00 +0900"
# 		},
# 		{
# 			"title":"수원시, <b>인공지능<\/b> 홍보 트럭 도시 누빈다",
# 			"originallink":"https:\/\/www.nspna.com\/news\/?mode=view&newsid=633549",
# 			"link":"https:\/\/www.nspna.com\/news\/?mode=view&newsid=633549",
# 			"description":"경기 수원시(시장 이재준)의 주요 행사와 정책을 <b>인공지능<\/b> 디스플레이를 장착한 트럭이 도심 곳곳을 다니며 홍보한다. 시는 애드와 24일 수원시청에서 ‘디지털 모빌리티 영상홍보 협약’을 체결하고 애드가 운영하는... ",
# 			"pubDate":"Mon, 24 Apr 2023 17:18:00 +0900"
# 		},
# 		{
# 			"title":"컴투버스-셀바스AI, 메타버스 <b>인공지능<\/b> 관련 기술 ‧ 사업 협력 협약",
# 			"originallink":"http:\/\/www.worktoday.co.kr\/news\/articleView.html?idxno=34723",
# 			"link":"http:\/\/www.worktoday.co.kr\/news\/articleView.html?idxno=34723",
# 			"description":"셀바스AI는 음성인식, 음성합성, 필기인식, 광학문자인식, 자연어 처리 등 HCI(Human Computer Interaction) 기술을 기반으로 한 <b>인공지능<\/b> 전문 기업으로, 교육, 의료, 금융, 문화, 엔터테인먼트 등 다양한 분야와의 기술 협력을... ",
# 			"pubDate":"Tue, 18 Apr 2023 11:36:00 +0900"
# 		},
# 		{
# 			"title":"구글 클라우드·경북도, <b>인공지능<\/b> 인재 양성 … 안동대에 AI진흥센터 설치",
# 			"originallink":"https:\/\/view.asiae.co.kr\/article\/2023041808225303454",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/277\/0005246839?sid=102",
# 			"description":"경북도는 18일 Google cloud와 협약을 체결하고, 글로벌 <b>인공지능<\/b> 인재 양성에 나서기로 했다. 우선, 올 하반기부터 시범사업을 통해 안동대에 AI 진흥센터를 설치하고, 100여명의 인력을 양성한다는 계획이다. 과정은... ",
# 			"pubDate":"Tue, 18 Apr 2023 08:31:00 +0900"
# 		},
# 		{
# 			"title":"경북도-구글 클라우드, 글로벌 <b>인공지능<\/b> 인재 양성 &apos;맞손&apos;",
# 			"originallink":"https:\/\/ilyo.co.kr\/?ac=article_view&entry_id=450572",
# 			"link":"https:\/\/ilyo.co.kr\/?ac=article_view&entry_id=450572",
# 			"description":"글로벌 <b>인공지능<\/b> 인재 양성에 나서기로 했다. 도는 우선 올 하반기부터 시범사업으로 안동대에 AI 진흥센터를 설치하고, 100여 명의 인력을 양성한다는 계획이다. 과정은 비전공자 등도 수강이 가능한 AI, 클라우드... ",
# 			"pubDate":"Tue, 18 Apr 2023 10:06:00 +0900"
# 		},
# 		{
# 			"title":"스노우플레이크, 한국타이어 통합 <b>인공지능<\/b> 데이터 분석 플랫폼 구축 지원",
# 			"originallink":"http:\/\/www.digitaltoday.co.kr\/news\/articleView.html?idxno=474861",
# 			"link":"http:\/\/www.digitaltoday.co.kr\/news\/articleView.html?idxno=474861",
# 			"description":"스노우플레이크 로고. 글로벌 데이터 클라우드 기업 스노우플레이크는 한국앤컴퍼니그룹 사업형 지주회사 한국앤컴퍼니와 계열사 한국타이어앤테크놀로지(이하 한국타이어) 통합 데이터 분석 플랫폼 구축을 위해 자사... ",
# 			"pubDate":"Tue, 25 Apr 2023 14:12:00 +0900"
# 		},
# 		{
# 			"title":"일산백병원, &apos;심정지 예측 <b>인공지능<\/b>(AI) 프로그램&apos; 도입",
# 			"originallink":"http:\/\/www.thefirstmedia.net\/news\/articleView.html?idxno=116121",
# 			"link":"http:\/\/www.thefirstmedia.net\/news\/articleView.html?idxno=116121",
# 			"description":"▲일산백병원이 심정지 예측 <b>인공지능<\/b>(AI) 프로그램인 딥카스를 도입, 병동 간호사들이 딥카스 프로그램을 시연하고 있다.  인제대학교 일산백병원(원장 이성순)이 환자 안전을 위해 심정지 예측 <b>인공지능<\/b>(AI) 프로그램... ",
# 			"pubDate":"Tue, 18 Apr 2023 19:12:00 +0900"
# 		},
# 		{
# 			"title":"중앙대 &apos;<b>인공지능<\/b>의 몸과 노동&apos; 학술대회 개최",
# 			"originallink":"http:\/\/www.newsis.com\/view\/?id=NISX20230405_0002254960&cID=10201&pID=10200",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/003\/0011785449?sid=102",
# 			"description":"기사내용 요약 <b>인공지능<\/b> 기반 데이터 해석 이슈·활용방법 등 논의 허서우 인턴 기자 = 중앙대는 오는 28일 &apos;<b>인공지능<\/b>의 몸과 노동&apos;을 주제로 제27회 <b>인공지능<\/b>인문학 국내학술대회를 개최한다고 5일 밝혔다. &apos;<b>인공지능<\/b>의... ",
# 			"pubDate":"Wed, 05 Apr 2023 13:26:00 +0900"
# 		},
# 		{
# 			"title":"메타, 메타버스 대신 <b>인공지능<\/b>에 집중",
# 			"originallink":"https:\/\/zdnet.co.kr\/view\/?no=20230406071810",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/092\/0002287887?sid=105",
# 			"description":"페이스북, 인스타그램 운영사 메타가 미래 먹거리로 낙점한 메타버스 대신 <b>인공지능<\/b>(AI) 관련 사업에 집중하고 있다. 5일(현지시간) CNBC에 따르면 앤드류 보스워스 메타 최고기술책임자(CTO)는 닛케이아시아와... ",
# 			"pubDate":"Thu, 06 Apr 2023 08:33:00 +0900"
# 		},
# 		{
# 			"title":"김동연 &quot;세계석학들과 &apos;<b>인공지능<\/b> 수도&apos; 만들겠다&quot;",
# 			"originallink":"http:\/\/www.inews24.com\/view\/1585082",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/031\/0000740656?sid=004",
# 			"description":"김동연 경기도지사가 세계적인 석학들과 &apos;<b>인공지능<\/b> 수도&apos;를 만들겠다고 다짐했다. 김동연 지사는 13일 자신의 페이스북을 통해 &quot;뉴욕대 부설 &apos;THE GOVLAB&apos;에서 세계적인 석학들과 AI의 미래, 지방정부 차원의 운용 방안... ",
# 			"pubDate":"Thu, 13 Apr 2023 12:07:00 +0900"
# 		},
# 		{
# 			"title":"EsB투자그룹, AI <b>인공지능<\/b> 시스템 도입 검토",
# 			"originallink":"https:\/\/www.woodkorea.co.kr\/news\/articleView.html?idxno=73094",
# 			"link":"https:\/\/www.woodkorea.co.kr\/news\/articleView.html?idxno=73094",
# 			"description":"챗GPT(ChatGPT) <b>인공지능<\/b>이 세계적으로 관심을 받고 있는 가운데 EsB투자그룹이 <b>인공지능<\/b> 데이터기반을 활용한 주식 관련 정보를 제공하는 시스템 개발 및 도입을 검토 중이라고 밝혔다. <b>인공지능<\/b>은 대량의 데이터를... ",
# 			"pubDate":"Tue, 25 Apr 2023 15:22:00 +0900"
# 		},
# 		{
# 			"title":"인천시, <b>인공지능<\/b>·빅데이터 등 첨단기술 기반 교통상황실 구축",
# 			"originallink":"https:\/\/www.jeonmae.co.kr\/news\/articleView.html?idxno=954137",
# 			"link":"https:\/\/www.jeonmae.co.kr\/news\/articleView.html?idxno=954137",
# 			"description":"최첨단 <b>인공지능<\/b>(AI)기술과 빅데이터 분석.활용해 교통 흐름을 관리하고, 교통사고에 대응하는 등 신속한 협업 체계를 구축하기로 뜻을 모았다. <b>지능<\/b>형 교통종합상황실은 <b>지능<\/b>형교통정보체계(ITS)에 기반했다. 시는 지난... ",
# 			"pubDate":"Wed, 26 Apr 2023 11:10:00 +0900"
# 		},
# 		{
# 			"title":"경북교육청, <b>인공지능<\/b>(AI) 교육 선도학교 운영 내실화 도모",
# 			"originallink":"https:\/\/www.nspna.com\/news\/?mode=view&newsid=632674",
# 			"link":"https:\/\/www.nspna.com\/news\/?mode=view&newsid=632674",
# 			"description":"2023년 <b>인공지능<\/b>(AI) 교육 선도학교 자체 사업 설명회 개최 경상북도교육청(교육감 임종식)은 지난 18일 경상북도교육청연수원에서 2023년 <b>인공지능<\/b>(AI) 교육 선도학교의 내실 있는 운영을 위한 자체 사업 설명회를... ",
# 			"pubDate":"Wed, 19 Apr 2023 16:48:00 +0900"
# 		},
# 		{
# 			"title":"[도서관 마을포럼] &apos;<b>인공지능<\/b> 시대, 인간답게 산다는 건 무엇일까&apos;",
# 			"originallink":"http:\/\/www.naeil.com\/news_view\/?id_art=458234",
# 			"link":"http:\/\/www.naeil.com\/news_view\/?id_art=458234",
# 			"description":"<b>인공지능<\/b> 시대의 삶과 일&apos;을 주제로 마을포럼이 열렸다. 사진 이의종 ◆&apos;<b>인공지능<\/b>은 왜 모른다고 못할까&apos; = 15일 느티나무도서관에서는 &apos;인간답게 산다는 건 뭘까? <b>인공지능<\/b> 시대의 삶과 일&apos;을 주제로 마을포럼이 열렸다.... ",
# 			"pubDate":"Thu, 20 Apr 2023 12:34:00 +0900"
# 		},
# 		{
# 			"title":"부산빅데이터혁신센터, 디지털 전환 포럼 &apos;<b>인공지능<\/b>과 데이터의 미래&apos; 개최",
# 			"originallink":"http:\/\/www.bzeronews.com\/news\/articleView.html?idxno=604179",
# 			"link":"http:\/\/www.bzeronews.com\/news\/articleView.html?idxno=604179",
# 			"description":"부산시(시장 박형준)는 오늘(27일) 오후 6시, 부산빅데이터혁신센터(해운대구 센텀동로 45, 7층)에서 &apos;ChatGPT 활용 사례로 보는 <b>인공지능<\/b>과 데이터의 미래&apos;를 주제로 「제7회 디지털 전환 포럼」(이하 DX포럼, 2022년 1~6회... ",
# 			"pubDate":"Thu, 27 Apr 2023 23:54:00 +0900"
# 		},
# 		{
# 			"title":"[단독]외교부, 박진 장관 <b>인공지능<\/b>(AI) 아바타 제작…외교 무대서 활용",
# 			"originallink":"https:\/\/www.ichannela.com\/news\/main\/news_detailPage.do?publishId=000000343342",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/449\/0000247710?sid=100",
# 			"description":"외교부가 박진 장관의 <b>인공지능<\/b>(AI) 아바타를 제작한 것으로 확인 됐습니다. 외교부는 홍보 활동을 강화하기 위해 AI 박진 장관을 다양한 외교 무대에서 활용하겠다는 계획을 세웠습니다. AI 아바타는 해당 인물의... ",
# 			"pubDate":"Fri, 14 Apr 2023 17:05:00 +0900"
# 		},
# 		{
# 			"title":"아마존도 생성 <b>인공지능<\/b> 출시?…“경쟁 뒤처져 있지 않다“",
# 			"originallink":"https:\/\/news.kbs.co.kr\/news\/view.do?ncd=7646834&ref=A",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/056\/0011462016?sid=104",
# 			"description":"세계 최대 전자상거래 업체 아마존이 현재 글로벌 기업들이 뛰어들고 있는 <b>인공지능<\/b>(AI) 분야에서 자사도 뒤처져 있지 않다고 자신했습니다. 9일(현지시각) 워싱턴포스트(WP)에 따르면 스와미 시바수브라마니 AI 부사장은... ",
# 			"pubDate":"Mon, 10 Apr 2023 03:52:00 +0900"
# 		},
# 		{
# 			"title":"“아리아 살려줘” 소중한 생명 구한 구미시 <b>인공지능<\/b> 스피커",
# 			"originallink":"https:\/\/www.donga.com\/news\/Society\/article\/all\/20230410\/118766210\/2",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/020\/0003490496?sid=102",
# 			"description":"경북 구미시 인동동에 홀로 거주하는 이 모 씨(78)는 최근 응급 상황에서 <b>인공지능<\/b>(AI) 스피커를 이용해 구조됐다. 10일 구미시에 따르면 이 씨는 지난 6일 아침 5시 18분경 자고 일어나니 갑자기 마비 증상이 왔다. 그는... ",
# 			"pubDate":"Mon, 10 Apr 2023 15:58:00 +0900"
# 		},
# 		{
# 			"title":"인천시·인천경찰청,<b>인공지능<\/b> 기반 교통상황실 운영",
# 			"originallink":"https:\/\/news.kbs.co.kr\/news\/view.do?ncd=7642392&ref=A",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/056\/0011458484?sid=102",
# 			"description":"인천시는 이달 안에 <b>인공지능<\/b> 기반 교통종합상황실을 준공해 인천경찰청과 합동으로 운영하겠다고 밝혔습니다. <b>인공지능<\/b> 교통종합상황실은 인천 시내 주요 도로 328㎞ 구간에서 실시간으로 교통정보를 수집해 교통상황... ",
# 			"pubDate":"Tue, 04 Apr 2023 09:24:00 +0900"
# 		},
# 		{
# 			"title":"세종시교육청, <b>인공지능<\/b> 문답시대 &apos;챗GPT&apos; 개발·보급",
# 			"originallink":"https:\/\/cc.newdaily.co.kr\/site\/data\/html\/2023\/04\/11\/2023041100150.html",
# 			"link":"https:\/\/cc.newdaily.co.kr\/site\/data\/html\/2023\/04\/11\/2023041100150.html",
# 			"description":"뉴데일리 이길표 기자 = 세종시교육청이 <b>인공지능<\/b> 도구 챗GPT 사용자 급증에 따라 학교 현장에서 사용할 수 있는 &apos;문답의 시대, 챗GPT&apos; 자료를 개발·보급한다고 11일 밝혔다. 자료는 챗GPT의 기본개념과 사용방법, 교수... ",
# 			"pubDate":"Tue, 11 Apr 2023 15:26:00 +0900"
# 		},
# 		{
# 			"title":"[포토] 컴투버스, 셀바스AI와 메타버스 내 <b>인공지능<\/b> 관련 기술·사업 협력",
# 			"originallink":"http:\/\/www.asiaa.co.kr\/news\/articleView.html?idxno=122153",
# 			"link":"http:\/\/www.asiaa.co.kr\/news\/articleView.html?idxno=122153",
# 			"description":"셀바스AI는 음성인식, 음성합성, 필기인식, 광학문자인식, 자연어 처리 등 최고 수준의 HCI(Human Computer Interaction) 기술을 기반으로 한 <b>인공지능<\/b> 전문 기업으로, 교육, 의료, 금융, 문화, 엔터테인먼트 등 다양한 분야와의... ",
# 			"pubDate":"Tue, 18 Apr 2023 10:16:00 +0900"
# 		},
# 		{
# 			"title":"부산형 ‘<b>인공지능<\/b> 로봇’ 첫선…판교 주도 시장 추격 본격화",
# 			"originallink":"http:\/\/www.kookje.co.kr\/news2011\/asp\/newsbody.asp?code=0200&key=20230414.22002004315",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/658\/0000038239?sid=101",
# 			"description":"- 선박 화물 자동배치 기술 등 개발 - 19일 열릴 인재양성대전서 공개 ‘부산형 <b>인공지능<\/b>(AI) 로봇’이 전국 무대에 선보인다. 경기 판교와 수도권 대기업이 주도하는 AI 로봇 시장에서 부산의 추격이 시작될지... ",
# 			"pubDate":"Fri, 14 Apr 2023 03:02:00 +0900"
# 		},
# 		{
# 			"title":"경북교육청, <b>인공지능<\/b>(AI) 교육 선도학교 운영 내실화 도모",
# 			"originallink":"https:\/\/www.dkilbo.com\/news\/articleView.html?idxno=398481",
# 			"link":"https:\/\/www.dkilbo.com\/news\/articleView.html?idxno=398481",
# 			"description":"▲ 지난 18일 경북교육청연수원에서 2023년 <b>인공지능<\/b>(AI) 교육 선도학교의 내실 있는 운영을 위한 자체 사업 설명회를 개최하고 있다. 경북교육청 제공 경북교육청은 지난 18일 경북교육청연수원에서 2023년 <b>인공지능<\/b>(AI)... ",
# 			"pubDate":"Wed, 19 Apr 2023 21:46:00 +0900"
# 		},
# 		{
# 			"title":"컴투버스, 셀바스AI와 <b>인공지능<\/b> 관련 기술·사업 협력 협약 체결",
# 			"originallink":"https:\/\/www.khgames.co.kr\/news\/articleView.html?idxno=212041",
# 			"link":"https:\/\/www.khgames.co.kr\/news\/articleView.html?idxno=212041",
# 			"description":"셀바스AI는 음성인식, 음성합성, 필기인식, 광학문자인식, 자연어 처리 등 HCI(Human Computer Interaction) 기술을 기반으로 한 <b>인공지능<\/b> 전문 기업이다. 최근에는 25년간 축적한 <b>인공지능<\/b> 기술 및 노하우와 데이터를 기반으로... ",
# 			"pubDate":"Tue, 18 Apr 2023 09:54:00 +0900"
# 		},
# 		{
# 			"title":"충북 제천세명대 제천시농촌협약센터, <b>인공지능<\/b> 시대 데이터 분석역량 강화 무...",
# 			"originallink":"https:\/\/www.ccdn.co.kr\/news\/articleView.html?idxno=911520",
# 			"link":"https:\/\/www.ccdn.co.kr\/news\/articleView.html?idxno=911520",
# 			"description":"충북 제천 세명대학교(총장 권동현) 제천시농촌협약센터는 관내 농업 경쟁력 강화를 위해 &apos;<b>인공지능<\/b> 시대 데이터 분석역량 강화&apos; 교육을 실시했다고 24일 밝혔다. 교육은 김계수 세명대학교 경영학과 교수가 강사로 나서... ",
# 			"pubDate":"Mon, 24 Apr 2023 19:38:00 +0900"
# 		},
# 		{
# 			"title":"[아침광장] <b>인공지능<\/b> 의사결정과 인간의 대체",
# 			"originallink":"http:\/\/www.kyongbuk.co.kr\/news\/articleView.html?idxno=2129613",
# 			"link":"http:\/\/www.kyongbuk.co.kr\/news\/articleView.html?idxno=2129613",
# 			"description":"정채연 포스텍 인문사회학부 교수 오픈 AI 사가 개발한 <b>인공지능<\/b> 챗봇 서비스인 챗GPT가 새로운 시대적 화두가 되면서 이른바 세 번째 &apos;<b>인공지능<\/b>의 봄&apos;은 한동안 지속될 듯하다. 최근 챗GPT가 일으키는 열풍을 바라보면... ",
# 			"pubDate":"Wed, 19 Apr 2023 17:16:00 +0900"
# 		},
# 		{
# 			"title":"컴투버스-셀바스AI, 메타버스 내 <b>인공지능<\/b>사업 맞손",
# 			"originallink":"http:\/\/www.biztribune.co.kr\/news\/articleView.html?idxno=279769",
# 			"link":"http:\/\/www.biztribune.co.kr\/news\/articleView.html?idxno=279769",
# 			"description":"셀바스AI는 음성인식, 음성합성, 필기인식, 광학문자인식, 자연어 처리 등 최고 수준의 HCI(Human Computer Interaction) 기술을 기반으로 한 <b>인공지능<\/b> 전문 기업으로, 교육, 의료, 금융, 문화, 엔터테인먼트 등 다양한 분야와의... ",
# 			"pubDate":"Tue, 18 Apr 2023 13:42:00 +0900"
# 		},
# 		{
# 			"title":"[호남대 AI 큐브] 이용이 SOS랩 총괄책임자, &quot;챗GPT 등 <b>인공지능<\/b> 도구 적극 활...",
# 			"originallink":"https:\/\/kr.aving.net\/news\/articleView.html?idxno=1778537",
# 			"link":"https:\/\/kr.aving.net\/news\/articleView.html?idxno=1778537",
# 			"description":"이용이 총괄책임자는 &quot;챗GPT 등과 같은 <b>인공지능<\/b> 서비스를 사용하는 이들이 몇 초만에 처리하는 일들을, 미사용자들은 오랜 시간을 들여 해결한다&quot;라며 &quot;<b>인공지능<\/b> 기술을 이해하고 사용하는 것은 이제 필수&quot;라고... ",
# 			"pubDate":"Mon, 24 Apr 2023 16:34:00 +0900"
# 		},
# 		{
# 			"title":"“노인 돌봄 <b>인공지능<\/b> 개발” SKT ESG 얼라이언스 소셜세이프티넷팀",
# 			"originallink":"https:\/\/bravo.etoday.co.kr\/view\/atc_view\/14497",
# 			"link":"https:\/\/bravo.etoday.co.kr\/view\/atc_view\/14497",
# 			"description":"브라보마이라이프=이준호 기자 | “미래 요양 서비스를 위한 필수 기술 될 것” 최근 사회 곳곳에서 <b>인공지능<\/b> 열풍이 불며 이제 막 대중화되는 것처럼 느껴지지만, 사실 우리 주변에서 그 역할을 시작한 것은 꽤... ",
# 			"pubDate":"Wed, 19 Apr 2023 08:44:00 +0900"
# 		},
# 		{
# 			"title":"[에너지 칼럼] 거대<b>인공지능<\/b>과 초소형 핵융합로·원자로",
# 			"originallink":"https:\/\/www.iusm.co.kr\/news\/articleView.html?idxno=1013545",
# 			"link":"https:\/\/www.iusm.co.kr\/news\/articleView.html?idxno=1013545",
# 			"description":"거대 <b>인공지능<\/b> 챗GPT 시대가 열렸다. 생성형 <b>인공지능<\/b>이라고 불리는 이 <b>인공지능<\/b>은 다양한 자연어 처리 능력을 바탕으로 인간의 창작물인 그림, 텍스트, 비디오 등 다양한 분야에서 실로 막강한 능력을 보이면서 그저... ",
# 			"pubDate":"Thu, 20 Apr 2023 20:32:00 +0900"
# 		},
# 		{
# 			"title":"논산시, <b>인공지능<\/b> 시대 선도할 미래인재 교육 신설",
# 			"originallink":"http:\/\/www.daejonilbo.com\/news\/articleView.html?idxno=2058653",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/656\/0000048117?sid=102",
# 			"description":"논산시가 <b>인공지능<\/b>(AI) 시대를 선도해나갈 미래인재 교육망 확장에 고삐를 당기고 있다. 백성현 시장은 4월 간부회의에서 &quot;AI와 코딩, 메타버스 등 미래 산업 맞춤형 인재교육을 활성화해야 한다&quot;는 당부사항을 전한 바... ",
# 			"pubDate":"Sun, 16 Apr 2023 19:23:00 +0900"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>융합사업단 김준하 단장, &quot;앞으로 전문가는 초거대 AI를 잘 활용하는...",
# 			"originallink":"https:\/\/www.aitimes.kr\/news\/articleView.html?idxno=27840",
# 			"link":"https:\/\/www.aitimes.kr\/news\/articleView.html?idxno=27840",
# 			"description":"김준하 <b>인공지능<\/b>산업융합사업단장이 20일 사업단 대회의실에서 광주 시민을 대상으로 3시간 동안 챗 GPT를 활용한 실습 강의 모습(사진:사업단) <b>인공지능<\/b>산업융합사업단(단장 김준하)이 광주 시민들을 대상으로 전... ",
# 			"pubDate":"Thu, 20 Apr 2023 16:44:00 +0900"
# 		},
# 		{
# 			"title":"코드비전, <b>인공지능<\/b> &apos;예지보전&apos; 진입장벽 혁신적으로 낮춘다!",
# 			"originallink":"https:\/\/www.aitimes.kr\/news\/articleView.html?idxno=27855",
# 			"link":"https:\/\/www.aitimes.kr\/news\/articleView.html?idxno=27855",
# 			"description":"국제<b>인공지능<\/b>대전(AI EXPO KOREA 2023)&apos;에 참가해 혁신적인 <b>인공지능<\/b>(AI) 기반 예지보전 솔루션을 선보인다. 코드비전의 <b>인공지능<\/b> 예지보전 솔루션은 데이터 취득부터 AI 모델 구축, 플랫폼까지 제공하는 토탈 서비스로... ",
# 			"pubDate":"Sun, 23 Apr 2023 09:52:00 +0900"
# 		},
# 		{
# 			"title":"국제<b>인공지능<\/b>&amp;윤리협회-크라우드웍스, AI 및 AI윤리 공동 사업 협력 MOU 체결",
# 			"originallink":"https:\/\/www.sedaily.com\/NewsView\/29OC73I74F",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/011\/0004179744?sid=101",
# 			"description":"IAAE 국제<b>인공지능<\/b>&amp;윤리협회(이사장 전창배)는 AI 학습용 데이터 라벨링 1위 기업인 크라우드웍스(대표 박민우)와 ‘AI 및 AI윤리에 관한 공동 사업 협약’을 체결했다고 17일 밝혔다. 이번 업무 협약을 통해 양 기관은... ",
# 			"pubDate":"Mon, 17 Apr 2023 09:53:00 +0900"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 기반 개인 맞춤형 뇌 신경조절치료 효과 입증",
# 			"originallink":"https:\/\/www.khan.co.kr\/national\/health-welfare\/article\/202304100939011",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/032\/0003216297?sid=102",
# 			"description":"■성빈센트·부천성모·서울성모 공동 연구팀 뇌 손상 환자에게 뇌 영상 분석 기술을 활용한 <b>인공지능<\/b>(AI) 개인 맞춤형 뇌 신경조절치료를 적용하면 뇌로 전달되는 자극이 기존 대비 20% 상승해 치료 효과를 높아지는... ",
# 			"pubDate":"Mon, 10 Apr 2023 09:40:00 +0900"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>도 행정문서 사용할 수 있게 된다",
# 			"originallink":"http:\/\/www.boannews.com\/media\/view.asp?idx=117339&kind=",
# 			"link":"http:\/\/www.boannews.com\/media\/view.asp?idx=117339&kind=",
# 			"description":"행안부, ‘행정 효율과 협업 촉진에 관한 규정’ 개정안 5월 31일까지 입법예고[보안뉴스 ] <b>인공지능<\/b>·데이터 기반의 디지털플랫폼정부를 실현하기 위해 행정 업무 방식을 획기적으로 개선한다. 행정문서를 사람과... ",
# 			"pubDate":"Fri, 21 Apr 2023 14:42:00 +0900"
# 		},
# 		{
# 			"title":"BGF복지재단, 경기도교육청과 <b>인공지능<\/b>(AI) 로봇 교육 지원",
# 			"originallink":"http:\/\/www.handmk.com\/news\/articleView.html?idxno=15876",
# 			"link":"http:\/\/www.handmk.com\/news\/articleView.html?idxno=15876",
# 			"description":"BGF복지재단 AI 로봇 지원 \/ BGF복지재단 제공 BGF복지재단이 경기도교육청과 함께 장애 학생들의 학습 참여도와 학업 성취도를 높이기 위해 <b>인공지능<\/b>(AI) 로봇 교육을 지원한다고 24일 밝혔다. BGF복지재단은 디지털 시대에... ",
# 			"pubDate":"Mon, 24 Apr 2023 13:10:00 +0900"
# 		},
# 		{
# 			"title":"경기도, <b>인공지능<\/b> 활용한 게임 콘텐츠 제작 기업 공모...선정 1개사, 개발 지...",
# 			"originallink":"https:\/\/www.aitimes.kr\/news\/articleView.html?idxno=27806",
# 			"link":"https:\/\/www.aitimes.kr\/news\/articleView.html?idxno=27806",
# 			"description":"도는 미래기술 분야(블록체인, <b>인공지능<\/b>(AI), 빅데이터, 클라우드, 메타버스, 가상·증강현실) 전문가와 경기도 중소게임기업 대표로 구성된 자문회의를 거쳐 이번 사업의 공모 주제를 선정했다. 공모 주제는 &apos;<b>인공지능<\/b>... ",
# 			"pubDate":"Mon, 17 Apr 2023 19:12:00 +0900"
# 		},
# 		{
# 			"title":"경기도, <b>인공지능<\/b>(AI) 로봇 ‘알파미니’ 어린이집에 &apos;대여&apos;",
# 			"originallink":"https:\/\/www.dnews.co.kr\/uhtml\/view.jsp?idxno=202304130839223880206",
# 			"link":"https:\/\/www.dnews.co.kr\/uhtml\/view.jsp?idxno=202304130839223880206",
# 			"description":"240개 어린이집 대화형 로봇 도입..다양한 체험 기회 제공 경기도가 어린이집 240개소에 <b>인공지능<\/b>(AI) 로봇을 대여해 영유아들에게 첨단기술을 경험할 기회를 제공한다. <b>인공지능<\/b>(AI) 로봇 대여사업은어린이집에서... ",
# 			"pubDate":"Thu, 13 Apr 2023 08:52:00 +0900"
# 		},
# 		{
# 			"title":"경기도, <b>인공지능<\/b>(AI) 기술 활용한 게임 콘텐츠 제작 기업에 1억원 지원",
# 			"originallink":"https:\/\/ilyo.co.kr\/?ac=article_view&entry_id=450514",
# 			"link":"https:\/\/ilyo.co.kr\/?ac=article_view&entry_id=450514",
# 			"description":"도는 미래기술 분야(블록체인, <b>인공지능<\/b>, 빅데이터, 클라우드, 메타버스, 가상·증강현실) 전문가와 경기도 중소게임기업 대표로 구성된 자문회의를 거쳐 이번 사업의 공모주제를 선정했다. 공모주제는 ‘<b>인공지능<\/b>(AI)... ",
# 			"pubDate":"Mon, 17 Apr 2023 08:48:00 +0900"
# 		},
# 		{
# 			"title":"김제시립도서관서 11일, <b>인공지능<\/b> 챗GPT 활용 특강",
# 			"originallink":"http:\/\/sjbnews.com\/news\/news.php?number=777012",
# 			"link":"http:\/\/sjbnews.com\/news\/news.php?number=777012",
# 			"description":"배움 아카데미 조석중 대표가 나서 시 직장인을 대상으로 이뤄지는 이 강연은 ▲ 대화형 <b>인공지능<\/b> 시대에 필요한 윤리와 교훈, ▲ 챗GPT 활용한 업무 연계 방안과 시연 등으로 진행된다. 특히, 챗GPT는 오픈 AI에서 개발한... ",
# 			"pubDate":"Mon, 10 Apr 2023 19:30:00 +0900"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>이 환자에게 적합한 약을 찾는 방법",
# 			"originallink":"https:\/\/www.bbc.com\/korean\/international-65295853?xtor=AL-73-%5Bpartner%5D-%5Bnaver%5D-%5Bheadline%5D-%5Bkorean%5D-%5Bbizdev%5D-%5Bisapi%5D",
# 			"link":"https:\/\/www.bbc.com\/korean\/international-65295853?xtor=AL-73-%5Bpartner%5D-%5Bnaver%5D-%5Bheadline%5D-%5Bkorean%5D-%5Bbizdev%5D-%5Bisapi%5D",
# 			"description":"제네티카플러스는 이를 위해 특정 인간세포를 성장시키는 최신 줄기세포 기술과 <b>인공지능<\/b>(AI) 소프트웨어를 결합했다. 사내 전문가가 환자의 혈액 샘플에서 뇌세포를 생성하고 여러 항우울제에 노출시켜 &quot;생체표지자... ",
# 			"pubDate":"Mon, 17 Apr 2023 12:11:00 +0900"
# 		},
# 		{
# 			"title":"[동정]김외철 전 국무총리실 비서관, 한국<b>인공지능<\/b>협회 상근부회장에",
# 			"originallink":"https:\/\/www.seoul.co.kr\/news\/newsView.php?id=20230420500216&wlog_tag3=naver",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/081\/0003355402?sid=100",
# 			"description":"사단법인 한국<b>인공지능<\/b>협회 상근부회장에 김외철 전 국무총리실 비서관이 임명됐다. 20일 한국<b>인공지능<\/b>협회에 따르면 김현철 회장은 지난 18일 김 상근부회장에게 임명장을 수여했다. 2017년 설립된... ",
# 			"pubDate":"Thu, 20 Apr 2023 17:39:00 +0900"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>으로 연금투자 진단부터 설계, 컨설팅, 사후관리까지...하나은행, &apos;퇴...",
# 			"originallink":"https:\/\/www.aitimes.kr\/news\/articleView.html?idxno=27912",
# 			"link":"https:\/\/www.aitimes.kr\/news\/articleView.html?idxno=27912",
# 			"description":"사진:하나은행 하나은행(은행장 이승열)은 퇴직연금(DC, IRP) 가입 손님의 목표 연금자산 형성을 위해 진단·설계·컨설팅·사후관리 서비스를 지원하는 &apos;AI 연금투자 솔루션&apos; 서비스를 28일부터 시작했다. AI 연금투자... ",
# 			"pubDate":"Sat, 29 Apr 2023 17:08:00 +0900"
# 		},
# 		{
# 			"title":"키움증권, 영웅전 <b>인공지능<\/b> 종목 정보 신설",
# 			"originallink":"http:\/\/www.enewstoday.co.kr\/news\/articleView.html?idxno=1652912",
# 			"link":"http:\/\/www.enewstoday.co.kr\/news\/articleView.html?idxno=1652912",
# 			"description":"키움증권이 &apos;영웅문S#&apos;을 통해 공개한 &apos;키움영웅전&apos; 3월 정규전 최고 수익률이 국내 1억리그 415%, 1백리그 738% 등을 기록한 가운데 4월 정규전부터는 참가자 프로필 보유종목에 <b>인공지능<\/b>(AI) 종목 정보가 추가된다.... ",
# 			"pubDate":"Tue, 11 Apr 2023 11:47:00 +0900"
# 		},
# 		{
# 			"title":"구글 클라우드, 경북도와 손잡고 <b>인공지능<\/b> 인재 길러낸다",
# 			"originallink":"http:\/\/www.boannews.com\/media\/view.asp?idx=117247&kind=",
# 			"link":"http:\/\/www.boannews.com\/media\/view.asp?idx=117247&kind=",
# 			"description":"안동대에 <b>인공지능<\/b>(AI) 진흥센터 열고, 글로벌 <b>인공지능<\/b>(AI) 인재 양성 사업 추진[보안뉴스 ] 경북도는 지난 18일 구글 클라우드(Google cloud)와 협약을 체결하고, 글로벌 <b>인공지능<\/b> 인재 양성에 나서기로 했다.우선 올... ",
# 			"pubDate":"Wed, 19 Apr 2023 15:02:00 +0900"
# 		},
# 		{
# 			"title":"SKT, 미래 AI 인재와 <b>인공지능<\/b> 기술 개발 나선다",
# 			"originallink":"https:\/\/www.hellot.net\/news\/article.html?no=76987",
# 			"link":"https:\/\/www.hellot.net\/news\/article.html?no=76987",
# 			"description":"현업 개발자와 실무 과제 함께 연구하는 현장형 AI 인재 육성 프로그램 지원자 모집 SK텔레콤은 기업 현장에서 실제 진행 중인 연구과제 수행을 통해 <b>인공지능<\/b> 분야의 미래 인재를 육성하는 &apos;SKT AI 펠로우십(SKT AI... ",
# 			"pubDate":"Tue, 11 Apr 2023 14:12:00 +0900"
# 		},
# 		{
# 			"title":"“우리 교수님은 AI?” 인천대, <b>인공지능<\/b> 강의 나왔다",
# 			"originallink":"https:\/\/news.kmib.co.kr\/article\/view.asp?arcid=0018132843&code=61121411&cp=nv",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/005\/0001599258?sid=102",
# 			"description":"<b>인공지능<\/b>(AI) 전문 기업 딥브레인AI가 인천대와 협업해 김평원 국어교육과 교수(인천대 교육혁신원장)를 <b>인공지능<\/b> 가상인간으로 구현했다고 6일 밝혔다. 딥브레인AI는 김 교수의 강의를 토대로 대본을 제작해 딥러닝... ",
# 			"pubDate":"Thu, 06 Apr 2023 11:27:00 +0900"
# 		},
# 		{
# 			"title":"차이커뮤니케이션, <b>인공지능<\/b>(A.I) 퍼포먼스 플랫폼 ‘CHAI GPC’ 출시",
# 			"originallink":"https:\/\/view.asiae.co.kr\/article\/2023041409315795847",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/277\/0005246259?sid=101",
# 			"description":"디지털광고회사 ‘차이커뮤니케이션’이 미래의 성장동력 산업으로 꼽힌 A.I사업에 집중해 광고회사 최초로 ‘퍼포먼스 광고 데이터’를 활용한 <b>인공지능<\/b>(AI) 퍼포먼스 플랫폼 ‘CHAI GPC(Generative Pre-trained Creator)... ",
# 			"pubDate":"Mon, 17 Apr 2023 09:01:00 +0900"
# 		},
# 		{
# 			"title":"[칼럼]<b>인공지능<\/b>이 논리적인 문제를 잘 풀 수 있는가?",
# 			"originallink":"https:\/\/www.newsclaim.co.kr\/news\/articleView.html?idxno=3017509",
# 			"link":"https:\/\/www.newsclaim.co.kr\/news\/articleView.html?idxno=3017509",
# 			"description":"픽사베이 &quot;<b>인공지능<\/b>이 논리적인 문제를 잘 풀 수 있는가?&quot; 이 질문은 질문 자체에 문제가 있다. 층위가 다른 두 가지를 비교하고 있기 때문이다. 논리의 기본은 삼단논법이다. &apos;A면 B이다&apos;가 참이고 &apos;B이면 C이다&apos;가 참일 때... ",
# 			"pubDate":"Sat, 22 Apr 2023 19:16:00 +0900"
# 		},
# 		{
# 			"title":"과기정통부 &apos;소프트웨어·<b>인공지능<\/b>(AI) 보편 교육체계 구축&apos;",
# 			"originallink":"https:\/\/www.yna.co.kr\/view\/PYH20230420073500013?input=1196m",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/001\/0013894291?sid=105",
# 			"description":"강도현 과학기술정보통신부 정보통신정책실장이 지난 20일 세종시 정부세종청사에서 소프트웨어 진흥 전략 주요 내용을 설명하고 있다. 2023.4.21",
# 			"pubDate":"Fri, 21 Apr 2023 08:00:00 +0900"
# 		},
# 		{
# 			"title":"한국<b>인공지능<\/b>협회, 첫 상근부회장에 김외철 전 총리실 비서관",
# 			"originallink":"http:\/\/news.heraldcorp.com\/view.php?ud=20230419000564",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/016\/0002132524?sid=101",
# 			"description":"한국<b>인공지능<\/b>협회(회장 김현철)는 상근부회장에 김외철(55·사진) 전 국무총리실 비서관을 임명했다. 김 상근부회장은 지난 30여년 동안 정당을 포함한 국회, 국무총리실, 경북도 등 중앙정부와 지방자치단체에서 폭넓게... ",
# 			"pubDate":"Wed, 19 Apr 2023 14:50:00 +0900"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 로봇 ‘알파미니’ 도내 어린이집에 한 달간 대여",
# 			"originallink":"https:\/\/www.asiatoday.co.kr\/view.php?key=20230413010007756",
# 			"link":"https:\/\/www.asiatoday.co.kr\/view.php?key=20230413010007756",
# 			"description":"경기도가 도내 어린이집 240개소에 <b>인공지능<\/b>(AI) 로봇을 대여해 영유아들에게 첨단기술을 경험할 기회를 제공한다. 13일 경기도에 따르면 AI 로봇 대여사업은 도내 어린이집에서 대화형 로봇 &apos;알파미니&apos;의 체험을... ",
# 			"pubDate":"Thu, 13 Apr 2023 16:28:00 +0900"
# 		},
# 		{
# 			"title":"<b>인공 지능<\/b>의 마스터스 전망…1R 마쓰야마·스피스 등 선두 예상",
# 			"originallink":"https:\/\/www.yna.co.kr\/view\/AKR20230406011500007?input=1195m",
# 			"link":"https:\/\/sports.news.naver.com\/news.nhn?oid=001&aid=0013862893",
# 			"description":"6일 개막하는 &apos;명인 열전&apos; 제87회 마스터스 토너먼트의 특징 가운데 하나는 <b>인공 지능<\/b>(AI)이 마스터스 인터넷 홈페이지에서 대회 결과를 예상한다는 점이다. 마스터스 홈페이지에는 IBM이 <b>인공 지능<\/b>을 활용해 참가 선수... ",
# 			"pubDate":"Thu, 06 Apr 2023 06:43:00 +0900"
# 		},
# 		{
# 			"title":"용인세브란스, <b>인공지능<\/b> 기반 흉부 방사선 영상 분석 효용성 입증",
# 			"originallink":"http:\/\/www.doctorstimes.com\/news\/articleView.html?idxno=222554",
# 			"link":"http:\/\/www.doctorstimes.com\/news\/articleView.html?idxno=222554",
# 			"description":"국내 의료진이 <b>인공지능<\/b>(AI) 기반 흉부 방사선 영상 분석의 임상적 효용성을 입증했다. 용인세브란스병원 호흡기·알레르기내과 곽세현·이은혜 교수, 영상의학과 신현주 교수 연구팀이 연구를 진행, 결과를 발표했다.... ",
# 			"pubDate":"Tue, 18 Apr 2023 14:14:00 +0900"
# 		},
# 		{
# 			"title":"김동연, 美서 세계적 석학들과 열띤 토론…&apos;<b>인공지능<\/b> 수도&apos; 포부 밝혀",
# 			"originallink":"http:\/\/moneys.mt.co.kr\/news\/mwView.php?no=2023041316480174477",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/417\/0000912702?sid=102",
# 			"description":"김동연 경기도지사가 세계적인 석학들과 &apos;<b>인공지능<\/b> 수도&apos;를 만들겠다고 다짐했다. 김 지사는 &apos;청년기회&apos;와 해외투자 유치를 위해 미국을 순방중인 가운데 13일 자신의 SNS를 통해 &quot;AI 분야의 4대 천황이라고 불리는... ",
# 			"pubDate":"Thu, 13 Apr 2023 17:16:00 +0900"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>(AI) 의료 솔루션 아르헨티나 인허가 획득",
# 			"originallink":"https:\/\/www.dailymedi.com\/news\/news_view.php?wr_id=896852",
# 			"link":"https:\/\/www.dailymedi.com\/news\/news_view.php?wr_id=896852",
# 			"description":"﻿﻿의료 <b>인공지능<\/b>(AI) 솔루션 기업 제이엘케이(대표 김동민)는 아르헨티나 식품의약품의학기술청(ANMAT) 으로부터 제품 5개 솔루션에 대한 의료기기 인허가를 획득했다고 20일 밝혔다. 이번에 인허가 획득 제품은... ",
# 			"pubDate":"Fri, 21 Apr 2023 08:48:00 +0900"
# 		},
# 		{
# 			"title":"알리바바 클라우드, 생성 <b>인공지능<\/b> 모델 &apos;통이치엔원 파트너십 프로그램&apos; 발표",
# 			"originallink":"https:\/\/www.aitimes.kr\/news\/articleView.html?idxno=27886",
# 			"link":"https:\/\/www.aitimes.kr\/news\/articleView.html?idxno=27886",
# 			"description":"생성 <b>인공지능<\/b>(Generative AI) 모델 &apos;통이치엔원(通义千问, Tongyi Qianwen)&apos;을 각 산업 분야에 맞춘 대규모 언어 모델을 파트너들과 함께 공동 개발하는 &apos;통이치엔원 파트너십 프로그램&apos;을 25일, 발표했다. 이... ",
# 			"pubDate":"Wed, 26 Apr 2023 19:22:00 +0900"
# 		},
# 		{
# 			"title":"일론 머스크, <b>인공지능<\/b> 회사 X.AI 차렸다...오픈AI와 경쟁?",
# 			"originallink":"http:\/\/www.digitaltoday.co.kr\/news\/articleView.html?idxno=474148",
# 			"link":"http:\/\/www.digitaltoday.co.kr\/news\/articleView.html?idxno=474148",
# 			"description":"일론 머스크가 엑스닷에이아이(X.AI)를 설립했다 [사진: 셔터스톡] 일론 머스크 테슬라 및 트위터 CEO가 <b>인공지능<\/b>(AI) 회사 엑스닷에이아이(X.AI)를 미국 네바다 주에 설립했다고 파이낸셜타임스, 월스트리트저널(WSJ)... ",
# 			"pubDate":"Sat, 15 Apr 2023 07:54:00 +0900"
# 		},
# 		{
# 			"title":"KT그룹사, <b>인공지능<\/b> 등 기술 결집과 DX업무혁신 위한 &apos;2023 그룹DX원팀&apos;",
# 			"originallink":"https:\/\/www.aitimes.kr\/news\/articleView.html?idxno=27846",
# 			"link":"https:\/\/www.aitimes.kr\/news\/articleView.html?idxno=27846",
# 			"description":"올해로 3년째를 맞는 &apos;그룹 DX 원팀&apos;은 KT그룹사들의 디지털전환(DX) 업무 혁신과 <b>인공지능<\/b>(AI)·로봇프로세스자동화(RPA) 역량 제고를 위해 그룹사 스스로 과제 발굴과 수행을 할 수 있도록 코칭과 실습 교육을... ",
# 			"pubDate":"Fri, 21 Apr 2023 09:50:00 +0900"
# 		},
# 		{
# 			"title":"국방부, &quot;<b>인공지능<\/b> 강군육성의 핵심인 국방데이터 체계적 구축 필요&quot;",
# 			"originallink":"http:\/\/www.konas.net\/article\/article.asp?idx=60664",
# 			"link":"http:\/\/www.konas.net\/article\/article.asp?idx=60664",
# 			"description":"국방부는 19일 신범철 국방부차관 주관으로 제2차 국방데이터관리위원회를 개최하고 <b>인공지능<\/b>(AI) 강군 육성의 핵심자산인 국방 데이터를 체계적으로 구축하고 활용하기 위한 정책 방향을 논의했다고 밝혔다.... ",
# 			"pubDate":"Wed, 19 Apr 2023 14:32:00 +0900"
# 		},
# 		{
# 			"title":"논산시, <b>인공지능<\/b> 시대 선도할 미래인재 교육 신설",
# 			"originallink":"https:\/\/daily.hankooki.com\/news\/articleView.html?idxno=946198",
# 			"link":"https:\/\/daily.hankooki.com\/news\/articleView.html?idxno=946198",
# 			"description":"사진=논산시 제공  논산시(시장 백성현)가 <b>인공지능<\/b>(AI) 시대를 선도해나갈 미래인재 교육망 확장에 고삐를 당기고 있다고 14일 밝혔다. 백성현 시장은 4월 간부회의에서 &quot;AI와 코딩, 메타버스 등 미래 산업 맞춤형... ",
# 			"pubDate":"Fri, 14 Apr 2023 16:28:00 +0900"
# 		},
# 		{
# 			"title":"&apos;아리아 살려줘&apos;…<b>인공지능<\/b> 스피커가 생명 구했다",
# 			"originallink":"https:\/\/news.imaeil.com\/page\/view\/2023041016312233476",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/088\/0000808146?sid=102",
# 			"description":"10일 구미시에 따르면 지난 6일 구미 인동동에 홀로 거주하는 남성 A(78) 씨가 <b>인공지능<\/b>(AI) 스피커를 이용해 응급구조되는 일이 발생했다. A 씨는 오전 5시 18분쯤 자고 일어난 뒤 갑자기 마비 증상이 생겼고, 집안에 설치된... ",
# 			"pubDate":"Mon, 10 Apr 2023 16:42:00 +0900"
# 		},
# 		{
# 			"title":"최첨단 <b>인공지능<\/b>기반 MRI 갖춘 계명대 대구동산병원",
# 			"originallink":"http:\/\/www.fnnews.com\/news\/202304120729078902",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/014\/0004995464?sid=102",
# 			"description":"계명대 대구동산병원이 최첨단 <b>인공지능<\/b>기반 MRI를 도입, 본격 운영에 들어갔다. 12일 계명대 대구동산병원에 따르면 지난 7일 본관 1층 영상의학과에서최첨단 3.0T(지멘스 헬시니어스社 Magnetom Lumina) MRI 도입... ",
# 			"pubDate":"Wed, 12 Apr 2023 07:53:00 +0900"
# 		},
# 		{
# 			"title":"김준하 <b>인공지능<\/b>산업융합사업단장, 광주시 공무원 대상 챗GPT 강연… &quot;AI 기술...",
# 			"originallink":"https:\/\/kr.aving.net\/news\/articleView.html?idxno=1778307",
# 			"link":"https:\/\/kr.aving.net\/news\/articleView.html?idxno=1778307",
# 			"description":"광주광역시(시장 강기정)는 정보화 담당 공무원을 대상으로 생성형 <b>인공지능<\/b>(AI) &apos;챗GPT&apos;(ChatGPT)를 활용한 교육을 17일 실시했다. 이번 교육에는 김준하 <b>인공지능<\/b>산업융합사업단장이 연사로 나서 <b>인공지능<\/b> 챗봇인... ",
# 			"pubDate":"Mon, 17 Apr 2023 15:56:00 +0900"
# 		},
# 		{
# 			"title":"배재대, 대전 초‧중‧고에 <b>인공지능<\/b>‧소프트웨어 전파",
# 			"originallink":"https:\/\/daily.hankooki.com\/news\/articleView.html?idxno=944429",
# 			"link":"https:\/\/daily.hankooki.com\/news\/articleView.html?idxno=944429",
# 			"description":"사진=배재대 제공  배재대학교(총장 김욱) 학생‧교직원이 대전지역 초‧중‧고교에 <b>인공지능<\/b>‧소프트웨어 교육 도우미로 활약한다. 배재대 AI‧SW중심대학사업단(단장 정회경)은 10일 대학 스마트배재관에서 학생... ",
# 			"pubDate":"Tue, 11 Apr 2023 09:22:00 +0900"
# 		},
# 		{
# 			"title":"서초구, 우범지대에 ‘<b>인공지능<\/b> CCTV’···“범죄행동 자동감지”[서울25]",
# 			"originallink":"https:\/\/www.khan.co.kr\/local\/Seoul\/article\/202304111408001",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/032\/0003216608?sid=102",
# 			"description":"서울 서초구는 지역 범죄 위험 신호를 감지하고 사건·사고를 예방하기 위해 폐쇄회로(CC)TV 영상 분석에 <b>인공지능<\/b>(AI) 기술을 적용한 ‘<b>지능<\/b>형 선별관제시스템’을 운영한다고 11일 밝혔다. 장시간 배회와 폭행, 주택... ",
# 			"pubDate":"Tue, 11 Apr 2023 14:10:00 +0900"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>協 상근부회장에 김외철",
# 			"originallink":"https:\/\/www.hankyung.com\/society\/article\/2023041995031",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/015\/0004834858?sid=102",
# 			"description":"한국<b>인공지능<\/b>협회는 19일 상근부회장에 김외철 전 국무총리실 비서관(사진)을 임명했다. 그는 정당, 국회, 국무총리실에 몸담았고 경상북도 개방형 1호 서울본부장 등을 지냈다.",
# 			"pubDate":"Wed, 19 Apr 2023 17:55:00 +0900"
# 		},
# 		{
# 			"title":"경기도, <b>인공지능<\/b> 기술 활용 게임 콘텐츠 제작 기업에 1억원 지원",
# 			"originallink":"https:\/\/www.newscj.com\/news\/articleView.html?idxno=3018883",
# 			"link":"https:\/\/www.newscj.com\/news\/articleView.html?idxno=3018883",
# 			"description":"도는 미래기술 분야(블록체인, <b>인공지능<\/b>, 빅데이터, 클라우드, 메타버스, 가상·증강현실) 전문가와 경기도 중소 게임기업 대표로 구성된 자문회의를 거쳐 이번 사업의 공모 주제를 선정했다. 공모 주제는 &apos;<b>인공지능<\/b>(AI)... ",
# 			"pubDate":"Mon, 17 Apr 2023 14:08:00 +0900"
# 		},
# 		{
# 			"title":"구로구, 4차산업 분야 특강 &apos;AI <b>인공지능<\/b> 기술 이해&apos; 실시",
# 			"originallink":"http:\/\/www.gvalley.co.kr\/news\/articleView.html?idxno=609429",
# 			"link":"http:\/\/www.gvalley.co.kr\/news\/articleView.html?idxno=609429",
# 			"description":"사진=4차산업분야 특강에서 인사말하는 문헌일구청장 G밸리뉴스 김가람 기자 =  구로구(구청장 문헌일)가 지난 21일 4차 산업혁명 시대에 필요한 역량을 강화하기 위해 &apos;그림으로 배우는 AI <b>인공지능<\/b> 기술 이해&apos; 특강을... ",
# 			"pubDate":"Tue, 25 Apr 2023 12:10:00 +0900"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 모빌리티 시대가 온다",
# 			"originallink":"http:\/\/sjbnews.com\/news\/news.php?number=777088",
# 			"link":"http:\/\/sjbnews.com\/news\/news.php?number=777088",
# 			"description":"이 시기에 “모빌리티 기술혁명 미래보고서 2030”은 다보스포럼 회장인 클라우스 슈밥이 주장한 4차산업혁명의 핵심을 ‘<b>인공지능<\/b>AI, 로봇공학, 사물인터넷, 자율주행차, 3D프린팅, 나노기술’과 같이 6대 분야의... ",
# 			"pubDate":"Mon, 10 Apr 2023 19:30:00 +0900"
# 		},
# 		{
# 			"title":"시야인사이트, 데이터와 <b>인공지능<\/b> 더한 국민안전플랫폼 &apos;세이브피플&apos; 선보인다",
# 			"originallink":"https:\/\/www.aitimes.kr\/news\/articleView.html?idxno=27899",
# 			"link":"https:\/\/www.aitimes.kr\/news\/articleView.html?idxno=27899",
# 			"description":"플랫폼 및 로고 이미지 <b>지능<\/b>형 모니터링 전문기업 시야인사이트(대표 임형준)은 오는 5월 10일부터 12일까지 서울 삼성동 COEX에서 아시아 최대로 개최되는 &apos;제6회 국제<b>인공지능<\/b>대전(AI EXPO KOREA 2023)&apos;에 참가해 데이터와... ",
# 			"pubDate":"Fri, 28 Apr 2023 09:18:00 +0900"
# 		},
# 		{
# 			"title":"AI(<b>인공지능<\/b>) 일자리도 늘렸다...지난해 미국 AI관련 일자리 100% 폭증",
# 			"originallink":"http:\/\/www.fnnews.com\/news\/202304060706047412",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/014\/0004992645?sid=105",
# 			"description":"OpenAI의 AI챗봇 &apos;챗GPT&apos;로 인해 전 세계에서 AI(<b>인공지능<\/b>)에 대한 관심이 커지고 있는 가운데 AI가 일자리도 늘릴 수 있을 지 주목된다. 지난해 미국에서 AI 관련 일자리가 전년 대비 100%나 급증하면서다. 5일... ",
# 			"pubDate":"Thu, 06 Apr 2023 07:13:00 +0900"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 챗 GPT에 대한 창의성…미래 사회는 어떤 모습",
# 			"originallink":"https:\/\/www.sedaily.com\/NewsView\/29O9VQU7R8",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/011\/0004177963?sid=102",
# 			"description":"국립광주과학관은 한국과총 광주전남지역연합회와 공동으로 오는 15일 국립광주과학관 상상홀에서 ‘<b>인공지능<\/b> 챗 GPT 시대, 진정한 창의성이란?’을 주제로 제2회 <b>인공지능<\/b>오딧세이 포럼을 개최한다고 12일 밝혔다.... ",
# 			"pubDate":"Wed, 12 Apr 2023 08:49:00 +0900"
# 		},
# 		{
# 			"title":"광주시, <b>인공지능<\/b>·문화예술 양 날개로 도시 외교 확대",
# 			"originallink":"https:\/\/www.yna.co.kr\/view\/AKR20230410085000054?input=1195m",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/001\/0013870319?sid=102",
# 			"description":"광주시가 <b>인공지능<\/b>(AI)과 문화예술을 매개로 도시 외교 보폭을 넓혀가고 있다. 10일 광주시에 따르면 지난해 7월 민선 8기 출범 이후 강기정 시장은 필립 골드버그 주한 미국 대사를 시작으로 독일, 일본, 중국, 영국... ",
# 			"pubDate":"Mon, 10 Apr 2023 14:06:00 +0900"
# 		},
# 		{
# 			"title":"국립광주과학관, 제2회 <b>인공지능<\/b>오딧세이 포럼",
# 			"originallink":"https:\/\/view.asiae.co.kr\/article\/2023041209061957012",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/277\/0005244236?sid=102",
# 			"description":"국립광주과학관과 한국과총 광주전남지역연합회가 오는 15일 과학관 상상홀에서 ‘<b>인공지능<\/b> 챗 GPT 시대, 진정한 창의성이란?’을 주제로 제2회 <b>인공지능<\/b> 오디세이 포럼을 개최한다. 해당 포럼은 최근 과학기술계 최대... ",
# 			"pubDate":"Wed, 12 Apr 2023 09:07:00 +0900"
# 		},
# 		{
# 			"title":"충북대 산업<b>인공지능<\/b>연구센터, 인재양성대전 참여",
# 			"originallink":"http:\/\/www.jbnews.com\/news\/articleView.html?idxno=1391626",
# 			"link":"http:\/\/www.jbnews.com\/news\/articleView.html?idxno=1391626",
# 			"description":"［중부매일 이지효 기자］ 충북대학교(총장 고창섭) 산업<b>인공지능<\/b>연구센터가 지난 19일부터 21일까지 서울 코엑스에서 진행된 &apos;ITRC 인재양성대전 2023&apos;에 참가해 산업<b>인공지능<\/b>연구센터의 연구활동을 선보였다.... ",
# 			"pubDate":"Sun, 23 Apr 2023 14:28:00 +0900"
# 		},
# 		{
# 			"title":"[대덕특구 출범 50주년 과학의날 특집] 경계 확장하는 한의학… <b>인공지능<\/b>·IC...",
# 			"originallink":"https:\/\/www.cctoday.co.kr\/news\/articleView.html?idxno=2176643",
# 			"link":"https:\/\/www.cctoday.co.kr\/news\/articleView.html?idxno=2176643",
# 			"description":"이제는 융합연구의 시대를 맞아, <b>인공지능<\/b>, ICT와의 융합을 통해 한의학의 원리와 효능을 과학적으로 규명하고, 그 경계를 계속해서 확장하며 새로운 미래융합의학을 만들어 가고 있다. 그동안 한의학연은 침 치료의 효과와... ",
# 			"pubDate":"Thu, 20 Apr 2023 15:36:00 +0900"
# 		},
# 		{
# 			"title":"(금요아침)아니 땐 굴뚝에 연기를 그리는 <b>인공지능<\/b>",
# 			"originallink":"https:\/\/www.electimes.com\/news\/articleView.html?idxno=318646",
# 			"link":"https:\/\/www.electimes.com\/news\/articleView.html?idxno=318646",
# 			"description":"&apos;스테이블 디퓨전(Stable Diffusion)&apos;이란 <b>인공지능<\/b>을 이용해서 실제 사진에 가까운 수준의 이미지를 필자가 직접 최초로 생성하는데 걸린 시간이다. 카카오톡을 통해서 해당 이미지를 지인들에게 말없이 공개했을 때 실제... ",
# 			"pubDate":"Thu, 20 Apr 2023 10:52:00 +0900"
# 		},
# 		{
# 			"title":"경기도, ‘생성형 <b>인공지능<\/b>·공공데이터 활용 창업경진대회’ 참여작 모집",
# 			"originallink":"http:\/\/www.mediagunpo.co.kr\/16078",
# 			"link":"http:\/\/www.mediagunpo.co.kr\/16078",
# 			"description":"이번 경진대회는 행정·안전·복지 등 다양한 공공데이터와 생성형 <b>인공지능<\/b>(Genrative AI) 기술을 결합한 창의적 아이디어 혹은 제품·서비스를 발굴하고, 더 나아가 <b>인공지능<\/b>과 공공데이터에 기반한 창업 문화를... ",
# 			"pubDate":"Wed, 26 Apr 2023 09:12:00 +0900"
# 		},
# 		{
# 			"title":"&apos;어서와 한국은 처음이지&apos; 다음 나라는 스위스…정수센터 방문→<b>인공지능<\/b> 활용",
# 			"originallink":"http:\/\/www.topstarnews.net\/news\/articleView.html?idxno=15328131",
# 			"link":"http:\/\/www.topstarnews.net\/news\/articleView.html?idxno=15328131",
# 			"description":"그레고는 <b>인공 지능<\/b>과 함께하는 여행을 선언했다. 하지만 식당을 물어보자 <b>인공 지능<\/b>이라 배가 고프지 않다고 답하는가 하면 온라인에서 찾아보라는 답변에 당황하기도 한다. &apos;어서와 한국은 처음이지&apos;는 한국에서 여러... ",
# 			"pubDate":"Wed, 26 Apr 2023 16:54:00 +0900"
# 		},
# 		{
# 			"title":"세종시교육청, &apos;챗GPT&apos; 및 <b>인공지능<\/b> 교육자료 개발·보급",
# 			"originallink":"https:\/\/www.ccdailynews.com\/news\/articleView.html?idxno=2197690",
# 			"link":"https:\/\/www.ccdailynews.com\/news\/articleView.html?idxno=2197690",
# 			"description":"▲ 초중고 <b>인공지능<\/b> 및 메타버스 교육자료.\/세종시교육청 제공 세종시교육청은 대화형 <b>인공지능<\/b> 도구 &apos;챗GPT&apos;의 성능 향상과 사용자 급증에 따라 학교 현장에서의 활용방안을 담은 도움 자료 &apos;문답의 시대, 챗GPT&apos;를 개발... ",
# 			"pubDate":"Tue, 11 Apr 2023 16:06:00 +0900"
# 		},
# 		{
# 			"title":"&quot;<b>인공지능<\/b> 배워서 해외연수 가 볼래요?&quot;",
# 			"originallink":"http:\/\/www.mediajeju.com\/news\/articleView.html?idxno=344030",
# 			"link":"http:\/\/www.mediajeju.com\/news\/articleView.html?idxno=344030",
# 			"description":"이번 프로그램은 △공통 기초 과정(파이썬 기초, <b>인공지능<\/b> 기초, 30시간) △역량강화 과정(컴퓨터 비전, 음성 및 자연어처리, 50시간) 등으로 이뤄졌다. 역량 과정 수료 후 40명을 선발하게 되며, 이들 학생은 20시간의... ",
# 			"pubDate":"Mon, 17 Apr 2023 14:16:00 +0900"
# 		},
# 		{
# 			"title":"챗GPT 시대…가장 ‘완벽한 답’ 찾기 위한 혁신 필요 [<b>인공지능<\/b> 챗GPT 포럼]",
# 			"originallink":"https:\/\/www.kyeonggi.com\/article\/20230420580286",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/666\/0000009350?sid=103",
# 			"description":"20일 오전 경기일보 대회의실에서 열린 <b>인공지능<\/b> 챗-GPT 포럼에서 참석자들이 토론을 벌이고 있다. 이번 포럼은 &apos;<b>인공지능<\/b> 챗-GPT 조력자인가? 파괴자인가?&apos;를 주제로 열렸다. 윤원규기자 챗 GPT로 촉발된 <b>인공지능<\/b>(AI) 시대를... ",
# 			"pubDate":"Thu, 20 Apr 2023 20:28:00 +0900"
# 		},
# 		{
# 			"title":"광주 <b>인공지능<\/b> 사관학교 330명 모집에 778명 지원…2.4대 1",
# 			"originallink":"https:\/\/www.news1.kr\/articles\/5004668",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/421\/0006727274?sid=102",
# 			"description":"광주 <b>인공지능<\/b> 사관학교 4기 교육생 모집에 서울과 부산, 제주 등 전국에서 지원자가 몰렸다. 4일 <b>인공지능<\/b>산업융합사업단에 따르면 AI 사관학교 4기 교육생 330명 모집에 779명이 지원해 2.4 대 1의 경쟁률을... ",
# 			"pubDate":"Tue, 04 Apr 2023 17:31:00 +0900"
# 		},
# 		{
# 			"title":"[AI 프리즘] 생성형 AI가 연 새로운 시대 &apos;불안한 일자리&apos;... AI 전문가들이 ...",
# 			"originallink":"http:\/\/www.wikileaks-kr.org\/news\/articleView.html?idxno=137830",
# 			"link":"http:\/\/www.wikileaks-kr.org\/news\/articleView.html?idxno=137830",
# 			"description":"이와 관련, &apos;더 컨버세이션(The conversation)&apos;은 AI 전문가들과 함께 <b>인공지능<\/b> 시대의 새로운 흐름과, 사라지는 일자리문제 대책 등 5가지 요소를 진단했다. ▷ 생성형 AI와 일자리 관계는 생성형 AI는 아티스트나 지식... ",
# 			"pubDate":"Fri, 28 Apr 2023 05:50:00 +0900"
# 		},
# 		{
# 			"title":"중앙대, 오는 28일 &apos;<b>인공지능<\/b>의 몸과 노동&apos; 학술대회 개최",
# 			"originallink":"https:\/\/www.news1.kr\/articles\/5005606",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/421\/0006729032?sid=102",
# 			"description":"중앙대학교는 오는 28일 오후 중앙대 서울캠퍼스 310관에서 제27회 <b>인공지능<\/b>인문학 국내학술대회를 연다고 5일 밝혔다. <b>인공지능<\/b>인문학 국내학술대회는 중앙대 인문콘텐츠연구소 HK+<b>인공지능<\/b>인문학사업단이 교육부와... ",
# 			"pubDate":"Wed, 05 Apr 2023 14:04:00 +0900"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 기반 CCTV 영상분석으로 교통 체증 해소, 도로안전 수준 높인다",
# 			"originallink":"http:\/\/www.boannews.com\/media\/view.asp?idx=117235&kind=",
# 			"link":"http:\/\/www.boannews.com\/media\/view.asp?idx=117235&kind=",
# 			"description":"<b>인공지능<\/b> CCTV 이미지 분석해 차량 12종 구분해 차선별 통행량 파악...정확도 94% 수준[보안뉴스 ] 전국 도로에 설치된 CCTV 영상을 <b>인공지능<\/b>(AI)이 분석해 차종과 교통량을 자동으로 파악할 수 있는 데이터 분석모델이... ",
# 			"pubDate":"Wed, 19 Apr 2023 15:48:00 +0900"
# 		},
# 		{
# 			"title":"SKT, 차세대 <b>인공지능<\/b> 기술 개발 나선다",
# 			"originallink":"https:\/\/www.nbntv.kr\/news\/articleView.html?idxno=69722",
# 			"link":"https:\/\/www.nbntv.kr\/news\/articleView.html?idxno=69722",
# 			"description":"SKT가 미래 AI 인재들과 <b>인공지능<\/b> 기술로 세상을 바꾸기 위한 프로젝트에 나선다. [사진=SKT] SKT가 미래 AI 인재들과 <b>인공지능<\/b> 기술로 세상을 바꾸기 위한 프로젝트에 나선다. SK텔레콤은 기업 현장에서 실제 진행 중인... ",
# 			"pubDate":"Tue, 11 Apr 2023 13:18:00 +0900"
# 		},
# 		{
# 			"title":"[중앙시평] <b>인공지능<\/b> 개발을 멈춰야 할까?",
# 			"originallink":"https:\/\/www.joongang.co.kr\/article\/25154048",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/025\/0003272193?sid=110",
# 			"description":"<b>인공지능<\/b> 분야의 문외한 주제에 내놓아 본 의견이었는데, 최근 그 분야의 많은 전문가들이 이와 비슷한 입장을 발표했다. 전기차업체 테슬라와 우주탐사기업 스페이스엑스의 창업주 일론 머스크가 설립한 ‘삶의 미래... ",
# 			"pubDate":"Tue, 11 Apr 2023 01:00:00 +0900"
# 		},
# 		{
# 			"title":"인간과 대화할 수 있게 된 <b>인공지능<\/b>, 다음 순서는 ‘자아’일까",
# 			"originallink":"https:\/\/www.hani.co.kr\/arti\/science\/science_general\/1087533.html",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/028\/0002635420?sid=105",
# 			"description":"하지만 이는 잠시 미뤄두고 이번 칼럼부터는 두뇌와 <b>인공지능<\/b> 관점을 다룰 것이다. 뜬금없는 도약으로 느껴지겠지만, 원래 커넥션 시리즈의 후반에서 두뇌를 모방한 <b>인공 지능<\/b>과 그 한계를 다룰 예정이었다. 우리 두뇌는... ",
# 			"pubDate":"Wed, 12 Apr 2023 10:03:00 +0900"
# 		},
# 		{
# 			"title":"아이메디신, 2023 월드IT쇼서 <b>인공지능<\/b> 기반 디지털 멘탈 헬스케어 플랫폼 소...",
# 			"originallink":"https:\/\/kr.aving.net\/news\/articleView.html?idxno=1778725",
# 			"link":"https:\/\/kr.aving.net\/news\/articleView.html?idxno=1778725",
# 			"description":"아이메디신은 2012년 설립한 <b>인공지능<\/b> 기반 &apos;디지털 멘탈 헬스케어 플랫폼&apos; 전문기업이다. 아이메디신이 제공하는 멘탈 헬스케어 방식은 헬멧 형태의 디바이스(iSyncWave)를 착용해 뇌파를 스캔하고 이를 바탕으로... ",
# 			"pubDate":"Fri, 28 Apr 2023 14:04:00 +0900"
# 		},
# 		{
# 			"title":"“<b>인공지능<\/b> 길들이기”…‘챗GPT’ 광주시민 무료 실습 교육 눈길",
# 			"originallink":"http:\/\/www.kwangju.co.kr\/article.php?aid=1681979740751400004",
# 			"link":"http:\/\/www.kwangju.co.kr\/article.php?aid=1681979740751400004",
# 			"description":"<b>인공지능<\/b>산업융합사업단이 광주시민을 대상으로 <b>인공지능<\/b>(AI) 기반 챗봇인 ‘챗 GPT’에 대한 무료 실습 기회를 제공해 큰 호응을 얻고 있다. 김준하 <b>인공지능<\/b>산업융합사업단장은 20일 광주 북구... ",
# 			"pubDate":"Thu, 20 Apr 2023 17:38:00 +0900"
# 		},
# 		{
# 			"title":"건국대, 반도체·<b>인공지능<\/b> 등 2학기 17개 분야 교수 초빙",
# 			"originallink":"https:\/\/dhnews.co.kr\/news\/view\/1065596975223198",
# 			"link":"https:\/\/dhnews.co.kr\/news\/view\/1065596975223198",
# 			"description":"21일 건국대에 따르면 초빙분야는 공과대학에서 ▲건설재료(사회환경공학부) ▲반도체 및 에너지 소재(화학공학부) ▲<b>인공지능<\/b>\/정보보호(암호학 제외)\/컴파일러\/프로그래밍언어론(컴퓨터공학부) ▲실감미디어\/가상... ",
# 			"pubDate":"Fri, 21 Apr 2023 16:34:00 +0900"
# 		},
# 		{
# 			"title":"경기도, <b>인공지능<\/b>(AI) 기술 활용한 게임 콘텐츠 제작 기업에 1억 지원",
# 			"originallink":"http:\/\/www.econonews.co.kr\/news\/articleView.html?idxno=283736",
# 			"link":"http:\/\/www.econonews.co.kr\/news\/articleView.html?idxno=283736",
# 			"description":"경기도는 미래기술 분야(블록체인, <b>인공지능<\/b>, 빅데이터, 클라우드, 메타버스, 가상·증강현실) 전문가와 경기도 중소게임기업 대표로 구성된 자문회의를 거쳐 이번 사업의 공모 주제를 선정했다고 설명했다. 공모... ",
# 			"pubDate":"Mon, 17 Apr 2023 15:52:00 +0900"
# 		}
# 	]
# }

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "xUCzXK76sez26412vcLf"
client_secret = "oCZNcdIe3A"

query = urllib.parse.quote(input("검색 질의: "))

idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

news_df = pd.DataFrame(columns=('Title','Original Link','Link','Description','Publication Date'))

for start_index in range(start, end, display):

    url = "https://openapi.naver.com/v1/search/news?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index) \
    + "&sort=" + sort
    
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, "", items[item_index]['title'])
            original_link = items[item_index]['originallink']
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            pub_date = items[item_index]['pubDate']
            news_df.loc[idx] = [title, original_link, link, description, pub_date]
            idx += 1        
    else:
        print("Error Code:" + rescode)
news_df
# Out:
# 검색 질의: 인공 지능
#                                                  Title  \
# 0            美 FTC 칸 위원장 &quot;인공지능 남용 예의주시하고 있다&quot;
# 1                          경기도 인공지능(AI) 산학연관 협의체 6월 출범
# 2                    인공지능의 대부가 챗GPT 위협을 인류에 경고하다 [핫이슈]
# 3                              경기도 인공지능 산학연관 협의체 6월 출범
# 4                          엠로, 자체 개발한 인공지능 기술 일본서 특허등록
# ..                                                 ...
# 995                      광주시, 인공지능·문화예술 양 날개로 도시 외교 확대
# 996                    인공지능 챗 GPT에 대한 창의성…미래 사회는 어떤 모습
# 997               경기도, 인공지능 기술 활용 게임 콘텐츠 제작 기업에 1억원 지원
# 998  KT그룹사, 인공지능 등 기술 결집과 DX업무혁신 위한 &apos;2023 그룹DX...
# 999                                   인공지능協 상근부회장에 김외철
#
#                                          Original Link  \
# 0    https://www.yna.co.kr/view/AKR2023050400250009...
# 1    http://www.newsis.com/view/?id=NISX20230504_00...
# 2                https://www.mk.co.kr/article/10728202
# 3    https://daily.hankooki.com/news/articleView.ht...
# 4    https://www.hankyung.com/economy/article/20230...
# ..                                                 ...
# 995  https://www.yna.co.kr/view/AKR2023041008500005...
# 996        https://www.sedaily.com/NewsView/29O9VQU7R8
# 997  https://www.newscj.com/news/articleView.html?i...
# 998  https://www.aitimes.kr/news/articleView.html?i...
# 999  https://www.hankyung.com/society/article/20230...
#
#                                                   Link  \
# 0    https://n.news.naver.com/mnews/article/001/001...
# 1    https://n.news.naver.com/mnews/article/003/001...
# 2    https://n.news.naver.com/mnews/article/009/000...
# 3    https://daily.hankooki.com/news/articleView.ht...
# 4    https://n.news.naver.com/mnews/article/015/000...
# ..                                                 ...
# 995  https://n.news.naver.com/mnews/article/001/001...
# 996  https://n.news.naver.com/mnews/article/011/000...
# 997  https://www.newscj.com/news/articleView.html?i...
# 998  https://www.aitimes.kr/news/articleView.html?i...
# 999  https://n.news.naver.com/mnews/article/015/000...
#
#                                            Description  \
# 0    뉴욕타임스 기고…&quot;새로운 시장에서도 강력하게 법 집행&quot; 김태종 특...
# 1    기사내용 요약 정책 제안, 의견 수렴 창구 역할 경기도 인공지능(AI) 산업 발전을...
# 2    인간보다 똑똑한 측면 보여 코드를 짜고 스스로 실행하는 지능 갖춘 자율적 존재 우려...
# 3    사진=경기도 제공 경기도와 도내 기업, 대학, 연구소가 함께 경기도 인공지능(AI)...
# 4    공급망관리 소프트웨어 기업 엠로가 일본에서 인공지능 기술 관련 특허를 등록했다고 3...
# ..                                                 ...
# 995  광주시가 인공지능(AI)과 문화예술을 매개로 도시 외교 보폭을 넓혀가고 있다. 10...
# 996  국립광주과학관은 한국과총 광주전남지역연합회와 공동으로 오는 15일 국립광주과학관 상...
# 997  도는 미래기술 분야(블록체인, 인공지능, 빅데이터, 클라우드, 메타버스, 가상·증강...
# 998  올해로 3년째를 맞는 &apos;그룹 DX 원팀&apos;은 KT그룹사들의 디지털전...
# 999  한국인공지능협회는 19일 상근부회장에 김외철 전 국무총리실 비서관(사진)을 임명했다...
#
#                     Publication Date
# 0    Thu, 04 May 2023 02:09:00 +0900
# 1    Thu, 04 May 2023 09:11:00 +0900
# 2    Thu, 04 May 2023 09:31:00 +0900
# 3    Thu, 04 May 2023 10:18:00 +0900
# 4    Wed, 03 May 2023 17:27:00 +0900
# ..                               ...
# 995  Mon, 10 Apr 2023 14:06:00 +0900
# 996  Wed, 12 Apr 2023 08:49:00 +0900
# 997  Mon, 17 Apr 2023 14:08:00 +0900
# 998  Fri, 21 Apr 2023 09:50:00 +0900
# 999  Wed, 19 Apr 2023 17:55:00 +0900
#
# [1000 rows x 5 columns]

# %%
news_df['Original Link']
# Out:
# 0      https://www.yna.co.kr/view/AKR2023050400250009...
# 1      http://www.newsis.com/view/?id=NISX20230504_00...
# 2                  https://www.mk.co.kr/article/10728202
# 3      https://daily.hankooki.com/news/articleView.ht...
# 4      https://www.hankyung.com/economy/article/20230...
#                              ...
# 995    https://www.yna.co.kr/view/AKR2023041008500005...
# 996          https://www.sedaily.com/NewsView/29O9VQU7R8
# 997    https://www.newscj.com/news/articleView.html?i...
# 998    https://www.aitimes.kr/news/articleView.html?i...
# 999    https://www.hankyung.com/society/article/20230...
# Name: Original Link, Length: 1000, dtype: object

# %% [markdown]
# #### 과제1_0504.
# 네이버 지식인에서 1000개의 데이터를 가져와서 'Title', 'Link', 'Description'을 컬럼으로 하는 데이터프레임을 작성해서 출력하세요.
# - news
# - blog
# - webkr : 웹문서
# - kin : 지식인

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = 'VNx3Aev0BoTmQVfE8a94'
client_secret = 'eNDLCmXP2A'

query = urllib.parse.quote(input('검색 질의: '))

display = 100
start = 1
end = 1000
sort = 'point'    # 평점순으로 내림차순 정렬

news_df = pd.DataFrame(columns=('Title', 'Link', 'Description'))

for start_index in range(start, end, display):
    
    url = 'https://openapi.naver.com/v1/search/kin?query=' + query \
    + '&display=' + str(display) \
    + '&start=' + str(start_index) \
    + '&sort=' + sort
    
    request = urllib.request.Request(url)
    request.add_header('X-Naver-Client-Id', client_id)
    request.add_header('X-Naver-Client-Secret', client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if (rescode==200):
        response_body = response.read()    # urllib으로 가져오면 bytes 타입임
        response_dict = json.loads(response_body.decode('utf-8'))    #str -> dic 타입으로
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            news_df.loc[item_index] = [title, link, description]            
    else:
        print('Error Code:' + rescode)

news_df
# Out:
# 검색 질의: 영등포 맛집
#                               Title  \
# 0              영등포구주변에데이트장소좀추천해주세요!
# 1                     크리스마스에 갈 곳 추천
# 2                       수도권 혼자 구경할곳
# 3   서울대 주변에 놀거리 추천해주세요 수학여행 하루치...
# 4                         서울 가볼곳 추천
# ..                              ...
# 95                    서울 데이트 영화관 코스
# 96    서울에서 펜팔친구랑 만나기로했는데요 조언좀해주세요^^
# 97        블로그체험단 모집을 오픈과 동시에 하려는데요.
# 98               영등포역 부근에 맛집좀 알려주세요
# 99                   영등포역 근처 맛집..!!
#
#                                                  Link  \
# 0   https://kin.naver.com/qna/detail.naver?d1id=12...
# 1   https://kin.naver.com/qna/detail.naver?d1id=12...
# 2   https://kin.naver.com/qna/detail.naver?d1id=9&...
# 3   https://kin.naver.com/qna/detail.naver?d1id=9&...
# 4   https://kin.naver.com/qna/detail.naver?d1id=12...
# ..                                                ...
# 95  https://kin.naver.com/qna/detail.naver?d1id=3&...
# 96  https://kin.naver.com/qna/detail.naver?d1id=20...
# 97  https://kin.naver.com/qna/detail.naver?d1id=4&...
# 98  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 99  https://kin.naver.com/qna/detail.naver?d1id=8&...
#
#                                           Description
# 0   ... 수있구요 영등포역쪽엔 롯데백화점도 있답니다! 그리고 먹자골목에 술집이며 맛집...
# 1   ... 01) 영등포 타임스퀘어 - 트리장식 더현대서울 - 트리장식 시청광장 - 트...
# 2   ... 1호선 영등포역 타임스퀘어 영등포 지하상가와 연결되어 있음 노량진 역 컵밥 ...
# 3   ... 고척돔 영등포역 6번출구 타임스퀘어 영등포 지하상가 노량진 역 2번출구 컵밥...
# 4   ... 가기 쉽게 지하철로 정리해 봄 (최대한 합리적이면서 저렴하게 광고질 없이 서...
# ..                                                ...
# 95  ... 그리고 심심하시면 타임스퀘어나 신세계백화점, 롯데백화점, 지하상가 가셔서 아...
# 96  ... ㅎㅎ 서로 추억도 만들고 관심있으면계속만날수도있고 겸사겸사해서 좋은감정 만드...
# 97  이번에 영등포에서 50평 규모의 이자카야를 오픈합니다. 신규오픈이라 손님이 빌까봐 ...
# 98  ... 여친이 맵고 짜고 자극적인 음식을 못먹구요 병원 조제약을 복용중이라 되도록이...
# 99  제가 영등포에 가는데요. 영등포역에 내려서 모좀 먹을라고 하는데요...... 이번에...
#
# [100 rows x 3 columns]

# %% [markdown]
# ## OpenWeatherMap 날씨정보
#
#
# https://home.openweathermap.org/users/sign_up
#
# [사용방법]
#
# 1. https://openweathermap.org/api 사이트에서 Current Weather data에 대한 API doc 내용을 파악
# 2.	OpenWeatherMap 홈페이지에서 회원가입
# 3.	회원가입 후 API Key를 발급. New Account 등록 후 API Keys라는 탭에서 API Key 확인 가능
# 4.	발급받은 API Key를 사용하여 API를 호출
#
#
# * 기본적으로 유료 사이트이지만 현재 날씨, 5일까지의 날씨는 무료로 사용할 수 있음(단 1분에 60번만 호출 가능)

# %% [markdown]
# #### 과제2_0504.
# 서울, 도쿄, 뉴욕의 날씨 조회를 아래와 같은 형식으로 출력하세요.
#
# * text로 가져와서 json으로 변환하여 일차 출력
#   - cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
#   - 가져올 정보 : 도시별 날씨(description), 최저 기온(temp_min), 최고 기온(temp_max), 습도(humidity), 기압(pressure), 풍속(speed)
#   - 기온 데이터는 켈빈 온도로 되어 있으며 섭씨 온도로 변환해서 출력
# * json 포멧으로 출력 데이터를 아래와 같이 가독력 있게 출력(소수점 2번째에서 반올림 처리)
#
#
# [출력형식]
#
#     도시 = Seoul
#     | 날씨 = broken clouds
#     | 최저 기온 = -1.0 2
#     | 최고 기온 = 2.0 2
#     | 습도 = 74
#     | 기압 = 1023
#     | 풍속 = 0.5

# %%
import os
import sys
import pandas as pd
import re
import urllib
import json

# API call
city_list = ['Seoul,KR', 'Tokyo,JP', 'New.York,US']
city_lat = []
city_lon = []

for city in city_list:
    url = f'http://api.openweathermap.org/geo/1.0/direct?q={city}&appid=556a2e345d0fdd0fa90db44a994b009d'
    city_coordinates = json.loads(urllib.request.urlopen(url).read())
    city_lat.append(city_coordinates[0]['lat'])
    city_lon.append(city_coordinates[0]['lon'])

df = pd.DataFrame({'city': city_list, 'latitude': city_lat, 'longitude': city_lon})
df.iloc[2,0] = 'New York'
print(df,'\n')
# print('위도 = ', city_lat)
# print('경도 = ', city_lon,'\n')

# API call
for lat, lon in zip(city_lat, city_lon):
    url = f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=556a2e345d0fdd0fa90db44a994b009d'
    response_dict = json.loads(urllib.request.urlopen(url).read())
    print(f"도시 = {response_dict['name']}")
    print(f"| 날씨 = {response_dict['weather'][0]['description']}")
    print(f"| 최저 기온 = {round(response_dict['main']['temp_min']-273.15, 2)}℃")
    print(f"| 최고 기온 = {round(response_dict['main']['temp_max']-273.15, 2)}℃")
    print(f"| 습도 = {response_dict['main']['humidity']}%")
    print(f"| 기압 = {response_dict['main']['pressure']}hPa")
    print(f"| 풍속 = {response_dict['wind']['speed']}m/s", '\n')
# Out:
#        city   latitude   longitude
# 0  Seoul,KR  37.566679  126.978291
# 1  Tokyo,JP  35.682839  139.759455
# 2  New York  40.712728  -74.006015
#
# 도시 = Seoul
# | 날씨 = light rain
# | 최저 기온 = 12.72℃
# | 최고 기온 = 12.75℃
# | 습도 = 84%
# | 기압 = 1009hPa
# | 풍속 = 4.31m/s
#
# 도시 = Japan
# | 날씨 = broken clouds
# | 최저 기온 = 23.22℃
# | 최고 기온 = 30.7℃
# | 습도 = 46%
# | 기압 = 1004hPa
# | 풍속 = 15.43m/s
#
# 도시 = New York
# | 날씨 = few clouds
# | 최저 기온 = 5.9℃
# | 최고 기온 = 11.65℃
# | 습도 = 85%
# | 기압 = 1024hPa
# | 풍속 = 1.79m/s

# %%
# API call로 가져온 부분 중 Tokyo의 위도와 경도가 맞지 않아, name이 Japan이나 Marunouchi로 출력되는 문제 발생
# Openweathermap의 Tokyo 위도, 경도 관련 정보를 직접 입렵함

import os
import sys
import pandas as pd
import re
import urllib
import json

# API call
city_list = ['Seoul,KR', 'Tokyo,JP', 'New.York,US']
city_lat = [37.5666791, 35.6895, 40.7127281]
city_lon = [126.9782914, 139.6917, -74.0060152]

# for city in city_list:
#     url = f'http://api.openweathermap.org/geo/1.0/direct?q={city}&appid=556a2e345d0fdd0fa90db44a994b009d'
#     city_coordinates = json.loads(urllib.request.urlopen(url).read())
#     city_lat.append(city_coordinates[0]['lat'])
#     city_lon.append(city_coordinates[0]['lon'])

df = pd.DataFrame({'city': city_list, 'latitude': city_lat, 'longitude': city_lon})
df.iloc[2,0] = 'New York'
print(df,'\n')
# print('위도 = ', city_lat)
# print('경도 = ', city_lon,'\n')

# API call
for lat, lon in zip(city_lat, city_lon):
    url = f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=556a2e345d0fdd0fa90db44a994b009d'
    response_dict = json.loads(urllib.request.urlopen(url).read())
    print(f"도시 = {response_dict['name']}")
    print(f"| 날씨 = {response_dict['weather'][0]['description']}")
    print(f"| 최저 기온 = {round(response_dict['main']['temp_min']-273.15, 2)}℃")
    print(f"| 최고 기온 = {round(response_dict['main']['temp_max']-273.15, 2)}℃")
    print(f"| 습도 = {response_dict['main']['humidity']}%")
    print(f"| 기압 = {response_dict['main']['pressure']}hPa")
    print(f"| 풍속 = {response_dict['wind']['speed']}m/s", '\n')
# Out:
#        city   latitude   longitude
# 0  Seoul,KR  37.566679  126.978291
# 1  Tokyo,JP  35.689500  139.691700
# 2  New York  40.712728  -74.006015
#
# 도시 = Seoul
# | 날씨 = moderate rain
# | 최저 기온 = 12.72℃
# | 최고 기온 = 12.82℃
# | 습도 = 88%
# | 기압 = 1009hPa
# | 풍속 = 4.12m/s
#
# 도시 = Tokyo
# | 날씨 = broken clouds
# | 최저 기온 = 24.75℃
# | 최고 기온 = 29.58℃
# | 습도 = 50%
# | 기압 = 1004hPa
# | 풍속 = 15.43m/s
#
# 도시 = New York
# | 날씨 = few clouds
# | 최저 기온 = 5.29℃
# | 최고 기온 = 11.64℃
# | 습도 = 86%
# | 기압 = 1024hPa
# | 풍속 = 2.24m/s

# %%
# 최종본

import pandas as pd
import urllib
import json

city_list = ['Seoul,KR', 'Tokyo,JP', 'New%20York,US']

# API call
for city in city_list:
    url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid=556a2e345d0fdd0fa90db44a994b009d'
    response_dict = json.loads(urllib.request.urlopen(url).read())
    print(f"도시 = {response_dict['name']}")
    print(f"| 날씨 = {response_dict['weather'][0]['description']}")
    print(f"| 최저 기온 = {round(response_dict['main']['temp_min']-273.15, 2)}℃")
    print(f"| 최고 기온 = {round(response_dict['main']['temp_max']-273.15, 2)}℃")
    print(f"| 습도 = {response_dict['main']['humidity']}%")
    print(f"| 기압 = {response_dict['main']['pressure']}hPa")
    print(f"| 풍속 = {response_dict['wind']['speed']}m/s", '\n')
# Out:
# 도시 = Seoul
# | 날씨 = moderate rain
# | 최저 기온 = 12.66℃
# | 최고 기온 = 12.78℃
# | 습도 = 82%
# | 기압 = 1009hPa
# | 풍속 = 5.14m/s
#
# 도시 = Tokyo
# | 날씨 = broken clouds
# | 최저 기온 = 24.75℃
# | 최고 기온 = 29.58℃
# | 습도 = 50%
# | 기압 = 1004hPa
# | 풍속 = 15.43m/s
#
# 도시 = New York
# | 날씨 = few clouds
# | 최저 기온 = 5.08℃
# | 최고 기온 = 11.64℃
# | 습도 = 86%
# | 기압 = 1024hPa
# | 풍속 = 2.06m/s

# %%
# 최종본

import pandas as pd
import urllib
import json

city_list = ['Seoul,KR', 'Tokyo,JP', 'New%20York,US']

df = pd.DataFrame(columns=['날씨', '최저 기온', '최고 기온', '습도', '기압', '풍속'])

# API call
for city in city_list:
    url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid=556a2e345d0fdd0fa90db44a994b009d'
    response_dict = json.loads(urllib.request.urlopen(url).read())
    print(f"도시 = {response_dict['name']}")
    print(f"| 날씨 = {response_dict['weather'][0]['description']}")
    print(f"| 최저 기온 = {round(response_dict['main']['temp_min']-273.15, 2)}℃")
    print(f"| 최고 기온 = {round(response_dict['main']['temp_max']-273.15, 2)}℃")
    print(f"| 습도 = {response_dict['main']['humidity']}%")
    print(f"| 기압 = {response_dict['main']['pressure']}hPa")
    print(f"| 풍속 = {response_dict['wind']['speed']}m/s", '\n')
    
    # 인덱스를 '도시'로 설정
    df.loc[response_dict['name']] = [response_dict['weather'][0]['description'], round(response_dict['main']['temp_min']-273.15, 2), round(response_dict['main']['temp_max']-273.15, 2), response_dict['main']['humidity'], response_dict['main']['pressure'], response_dict['wind']['speed']]  
    print(df)

# 인덱스를 번호로 설정
df.reset_index().rename(columns={'index':'도시'})
# Out:
# 도시 = Seoul
# | 날씨 = moderate rain
# | 최저 기온 = 12.66℃
# | 최고 기온 = 13.76℃
# | 습도 = 79%
# | 기압 = 1009hPa
# | 풍속 = 5.66m/s
#
#                   날씨  최저 기온  최고 기온  습도    기압    풍속
# Seoul  moderate rain  12.66  13.76  79  1009  5.66
# 도시 = Tokyo
# | 날씨 = broken clouds
# | 최저 기온 = 24.3℃
# | 최고 기온 = 26.95℃
# | 습도 = 53%
# | 기압 = 1003hPa
# | 풍속 = 16.98m/s
#
#                   날씨  최저 기온  최고 기온  습도    기압     풍속
# Seoul  moderate rain  12.66  13.76  79  1009   5.66
# Tokyo  broken clouds  24.30  26.95  53  1003  16.98
# 도시 = New York
# | 날씨 = clear sky
# | 최저 기온 = 5.19℃
# | 최고 기온 = 10.97℃
# | 습도 = 88%
# | 기압 = 1025hPa
# | 풍속 = 2.57m/s
#
#                      날씨  최저 기온  최고 기온  습도    기압     풍속
# Seoul     moderate rain  12.66  13.76  79  1009   5.66
# Tokyo     broken clouds  24.30  26.95  53  1003  16.98
# New York      clear sky   5.19  10.97  88  1025   2.57
#          도시             날씨  최저 기온  최고 기온  습도    기압     풍속
# 0     Seoul  moderate rain  12.66  13.76  79  1009   5.66
# 1     Tokyo  broken clouds  24.30  26.95  53  1003  16.98
# 2  New York      clear sky   5.19  10.97  88  1025   2.57

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7380\3727185865.py in <module>
# ----> 1 df.reset_index(name='도시')
#
# TypeError: reset_index() got an unexpected keyword argument 'name'

# %%
# !pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in c:\app\lib\site-packages (2.0.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\app\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: tzdata>=2022.1 in c:\app\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\app\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\app\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\app\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: Ignoring invalid distribution -andas (c:\app\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\app\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\app\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\app\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\app\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\app\lib\site-packages)
